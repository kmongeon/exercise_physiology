# %%
import os
import sys
import shutil
import pandas
import numpy
import ipystata

from ipystata.config import config_stata
config_stata('/home/kmongeon/research/stata14/stata-mp',force_batch=True)

pandas.options.display.max_columns = 50

# %%
shutil.rmtree('out')
os.mkdir('out')

# %%
# Out:
# (70 vars, 427 obs)
# (note: file ./out/di.dta not found)
# file ./out/di.dta saved
# (14 vars, 421 obs)
# (40 observations deleted)(65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (note: file ./out/dt.dta not found)
# file ./out/dt.dta saved
# . * Nota: July  2016(32 vars, 109 obs)
# (59 observations deleted)
# (note: file ./out/db1.dta not found)
# file ./out/db1.dta saved
# . import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# (34 vars, 473 obs)
# (460 observations deleted)
# (note: file ./out/db2.dta not found)
# file ./out/db2.dta saved
# . use ./out/di, clear
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                            58
#         from master                        52
#         from using                          6
#
#     matched                               375
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           383
#         from master                       383
#         from using                          0
#
#     matched                                50
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           420
#         from master                       420
#         from using                          0
#
#     matched                                13
#     -----------------------------------------
#   (all newnames==oldnames)
# . *drop if missing(rsos). *drop if missing(grip). drop if matu>5
# (7 observations deleted)
# (1 observation deleted)
#        panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 4
#                 delta:  1 unit
#   425
#
#       Source |       SS           df       MS      Number of obs   =       369
# -------------+----------------------------------   F(1, 367)       =     50.86
#        Model |  2453.58783         1  2453.58783   Prob > F        =    0.0000
#     Residual |  17704.1911       367  48.2403028   R-squared       =    0.1217
# -------------+----------------------------------   Adj R-squared   =    0.1193
#        Total |   20157.779       368  54.7765733   Root MSE        =    6.9455
#
# ------------------------------------------------------------------------------
#         grip |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         rsos |   .0253791   .0035586     7.13   0.000     .0183812    .0323769
#        _cons |   -73.3803    13.5873    -5.40   0.000     -100.099   -46.66157
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (379 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       303
# -------------+----------------------------------   F(1, 301)       =     35.74
#        Model |  92527.6306         1  92527.6306   Prob > F        =    0.0000
#     Residual |   779240.58       301  2588.83914   R-squared       =    0.1061
# -------------+----------------------------------   Adj R-squared   =    0.1032
#        Total |  871768.211       302   2886.6497   Root MSE        =    50.881
#
# ------------------------------------------------------------------------------
#        ptiso |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         tsos |   .1673486   .0279923     5.98   0.000     .1122632     .222434
#        _cons |  -491.3157   102.9306    -4.77   0.000    -693.8705   -288.7609
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (310 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       365
# -------------+----------------------------------   F(2, 362)       =     62.36
#        Model |  919097.158         2  459548.579   Prob > F        =    0.0000
#     Residual |  2667612.45       362  7369.09516   R-squared       =    0.2563
# -------------+----------------------------------   Adj R-squared   =    0.2521
#        Total |  3586709.61       364  9853.59782   Root MSE        =    85.843
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        griph |   3.049827   .8157855     3.74   0.000     1.445553    4.654101
#         matu |   16.95256   2.915195     5.82   0.000     11.21972    22.68541
#        _cons |   3762.022    21.2391   177.13   0.000     3720.255     3803.79
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (50 missing values generated)
# (50 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       404
# -------------+----------------------------------   F(2, 401)       =     69.73
#        Model |  1204939.47         2  602469.737   Prob > F        =    0.0000
#     Residual |  3464563.99       401  8639.81045   R-squared       =    0.2580
# -------------+----------------------------------   Adj R-squared   =    0.2543
#        Total |  4669503.47       403  11586.8572   Root MSE        =    92.951
#
# ------------------------------------------------------------------------------
#         tsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |   .3044852   .1230235     2.48   0.014     .0626337    .5463367
#         matu |   22.97529   2.966484     7.74   0.000     17.14348    28.80709
#        _cons |    3668.77   17.84136   205.63   0.000     3633.696    3703.845
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (14 missing values generated)
# (11 real changes made)

# %%
dm.describe()
# Out:
#                id     session    sequence         seq  nota  falk  \
# count  425.000000  425.000000  425.000000  425.000000  50.0  11.0
# mean   326.197647    1.430588    4.197647    1.868235   1.0   1.0
# std    197.549787    0.495742    1.833518    0.877686   0.0   0.0
# min    100.000000    1.000000    1.000000    1.000000   1.0   1.0
# 25%    138.000000    1.000000    3.000000    1.000000   1.0   1.0
# 50%    189.000000    1.000000    4.000000    2.000000   1.0   1.0
# 75%    530.000000    2.000000    6.000000    2.000000   1.0   1.0
# max    583.000000    2.000000    7.000000    4.000000   1.0   1.0
#
#               rsos         tsos        grip       ptiso        pt60  \
# count   415.000000   415.000000  379.000000  310.000000  310.000000
# mean   3815.551807  3687.079518   23.438074  124.041290   84.050201
# std     100.909471   109.038357    7.364498   53.311306   33.349968
# min    3542.000000  3367.000000    9.000000   32.647167   28.224886
# 25%    3746.500000  3619.000000   18.000000   84.335386   58.508888
# 50%    3820.000000  3689.000000   22.250000  114.025639   76.993565
# 75%    3878.000000  3758.000000   27.500000  156.607567  102.830297
# max    4140.000000  4015.000000   53.000000  343.836792  237.822296
#
#             godin         paq         ntxc         cint         calc  \
# count  422.000000  425.000000   385.000000   422.000000   421.000000
# mean    72.606635    3.144819   540.346619  1598.184814   976.547974
# std     39.683328    0.662686   265.354980   482.215729   455.661133
# min      0.000000    1.250000    56.308327   469.496002    51.714001
# 25%     44.000000    2.718600   369.744904  1263.682983   652.146973
# 50%     65.000000    3.197700   514.754761  1548.725037   915.741028
# 75%     92.750000    3.663800   662.435608  1878.681793  1196.994019
# max    234.000000    4.610400  1754.324463  3624.724121  2518.876953
#
#              vitd       vitd2         mvh        matu         age      gender  \
# count  421.000000  421.000000  307.000000  425.000000  425.000000  425.000000
# mean     4.703625  189.981476  106.180466   -0.893577   11.850613    0.468235
# std      3.152561  127.345634   41.705219    1.942006    2.003003    0.499578
# min      0.000000    0.000000   13.570000   -5.300000    7.500000    0.000000
# 25%      2.649000  107.401001   78.139999   -2.290000   10.340000    0.000000
# 50%      4.204000  173.792007   99.110001   -1.000000   11.850000    0.000000
# 75%      6.464000  263.270996  133.389999    0.450000   13.230000    1.000000
# max     21.211000  848.426025  235.000000    4.950000   17.549999    1.000000
#
#             griph      ptisoh        rsosh        tsosh
# count  425.000000  422.000000   425.000000   422.000000
# mean    23.412334  125.861549  3815.268311  3686.898193
# std      6.997608   46.829910    60.782661    59.051323
# min      9.000000   32.647167  3554.000000  3367.000000
# 25%     18.500000   92.210487  3780.298096  3647.084717
# 50%     22.500000  120.712017  3814.430908  3683.248779
# 75%     27.000000  150.717136  3853.525146  3724.732605
# max     53.000000  343.836792  3971.000000  3962.000000

# %%
# %%stata --output dm  --openstata
#
# import delimited ./data/IzzyLongitudinalWorkingMarch2015.csv,  case(lower) clear
# order id session sequence
# sort id sequence
# save ./out/di, replace
#
# import delimited ./data/torque.csv, case(lower) clear
# drop if session==0
# drop sequence
# rename new_sequence sequence
# order id session sequence
# sort id  sequence
# foreach var in ptiso pt60 pt240 {
# replace `var' = . if `var'==-9999
# }
# save ./out/dt, replace
#
# ** Identify potentially data with errors
# * Nota: July  2016
# import delimited ./data/NegativeIDs.csv, case(lower) clear
# keep nota id sequence
# keep if nota==1
# save ./out/db1, replace
#
# * Baraket: Nov 2016
# import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# keep falk id sequence
# keep if falk==1
# save ./out/db2, replace
#
# * merge
# use ./out/di, clear
# sort id sequence
# merge 1:1 id sequence using ./out/dt,  nogen
# merge 1:1 id sequence using ./out/db1, nogen
# merge 1:1 id sequence using ./out/db2, nogen
#
# rename radius_sos rsos
# rename tibial_sos tsos
#
# rename grip_strength_best grip
# rename mat_offset_new matu
#
# rename godin_pa godin
# rename ntxcreat ntxc
# rename caloricintake cint
# renam calcium calc
# rename vitd vitd
# rename v48 vitd2
# rename paq_total_score paq
# rename totmvh mvh
#
# global U id session sequence
# global Y rsos tsos
# global X grip ptiso pt60 godin paq ntxc cint calc vitd vitd2 mvh
# global Z matu age gender
# global D nota falk
#
# keep $U $Y $X $Z $D
#
# ***grip only
#
# *drop if missing(rsos)
# *drop if missing(tsos)
# *drop if missing(grip)
# *drop if missing(ptiso)
# drop if matu>5
# drop if id==517 & sequence==7
#
# sort id sequence
# by id: egen seq = seq()
# global U id session sequence seq
#
# order $U $D $Y $X $Z
#
# xtset id seq
# count
#
# capture drop griph
# reg grip rsos
# predict griph
# replace griph = grip if (!missing(grip) & nota!=1)
#
# reg ptiso matu
#
# capture drop ptisoh
# reg ptiso tsos
# predict ptisoh
# replace ptisoh = ptiso if !missing(ptiso)
#
# capture drop ptisoh2
# reg ptisoh matu
# predict ptisoh2
# replace ptisoh = ptisoh2 if missing(ptisoh)
# drop ptisoh2
#
# capture drop rsosh
# reg rsos griph
# predict rsosh
# replace rsosh = rsos if (!missing(rsos) & nota!=1)
#
# capture drop tsosh
# reg tsos ptisoh
# predict tsosh
# replace tsosh = tsos if (falk!=1 & !missing(tsos))
#
# capture drop mvhh
# reg mvh ptisoh
# predict mvhh
# replace mvhh = mvh if !missing(mvh)
#
# capture drop ntxch
# reg ntxc rsosh
# predict ntxh
# replace ntxh = ntxc if !missing(ntxc)
#
# capture drop godinh
# reg godin matu
# predict godinh
# replace godinh = godin if !missing(godin)
#
# capture drop paqh
# reg paq matu
# predict paqh
# replace paqh = paq if !missing(paq)
#
# capture drop calch
# reg calc matu
# predict calch
# replace calch = calc if !missing(calc)
#
# capture drop cinth
# reg cint matu
# predict cinth
# replace cinth = cint if !missing(cint)
#
# sort id seq
# by id: egen trips = max(seq)
# order trips, after(seq)
# Out:
# (70 vars, 427 obs)
# file ./out/di.dta saved
# (14 vars, 421 obs)
# (40 observations deleted)(65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# file ./out/dt.dta saved
# . * Nota: July  2016(32 vars, 109 obs)
# (59 observations deleted)
# file ./out/db1.dta saved
# . import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# (34 vars, 473 obs)
# (460 observations deleted)
# file ./out/db2.dta saved
# . use ./out/di, clear
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                            58
#         from master                        52
#         from using                          6
#
#     matched                               375
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           383
#         from master                       383
#         from using                          0
#
#     matched                                50
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           420
#         from master                       420
#         from using                          0
#
#     matched                                13
#     -----------------------------------------
#   (all newnames==oldnames)
# . *drop if missing(rsos). *drop if missing(grip). drop if matu>5
# (7 observations deleted)
# (1 observation deleted)
#        panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 4
#                 delta:  1 unit
#   425
#
#       Source |       SS           df       MS      Number of obs   =       369
# -------------+----------------------------------   F(1, 367)       =     50.86
#        Model |  2453.58783         1  2453.58783   Prob > F        =    0.0000
#     Residual |  17704.1911       367  48.2403028   R-squared       =    0.1217
# -------------+----------------------------------   Adj R-squared   =    0.1193
#        Total |   20157.779       368  54.7765733   Root MSE        =    6.9455
#
# ------------------------------------------------------------------------------
#         grip |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         rsos |   .0253791   .0035586     7.13   0.000     .0183812    .0323769
#        _cons |   -73.3803    13.5873    -5.40   0.000     -100.099   -46.66157
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (329 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       310
# -------------+----------------------------------   F(1, 308)       =    225.64
#        Model |   371332.93         1   371332.93   Prob > F        =    0.0000
#     Residual |  506874.537       308  1645.69655   R-squared       =    0.4228
# -------------+----------------------------------   Adj R-squared   =    0.4210
#        Total |  878207.466       309  2842.09536   Root MSE        =    40.567
#
# ------------------------------------------------------------------------------
#        ptiso |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   18.42263   1.226436    15.02   0.000     16.00938    20.83588
#        _cons |   140.9883   2.565451    54.96   0.000     135.9403    146.0364
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =       303
# -------------+----------------------------------   F(1, 301)       =     35.74
#        Model |  92527.6306         1  92527.6306   Prob > F        =    0.0000
#     Residual |   779240.58       301  2588.83914   R-squared       =    0.1061
# -------------+----------------------------------   Adj R-squared   =    0.1032
#        Total |  871768.211       302   2886.6497   Root MSE        =    50.881
#
# ------------------------------------------------------------------------------
#        ptiso |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         tsos |   .1673486   .0279923     5.98   0.000     .1122632     .222434
#        _cons |  -491.3157   102.9306    -4.77   0.000    -693.8705   -288.7609
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (310 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =    232.21
#        Model |  328717.627         1  328717.627   Prob > F        =    0.0000
#     Residual |  594552.429       420  1415.60102   R-squared       =    0.3560
# -------------+----------------------------------   Adj R-squared   =    0.3545
#        Total |  923270.056       421  2193.04051   Root MSE        =    37.624
#
# ------------------------------------------------------------------------------
#       ptisoh |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   14.35457    .941996    15.24   0.000     12.50295    16.20618
#        _cons |   138.6136   2.013653    68.84   0.000     134.6556    142.5717
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (3 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       415
# -------------+----------------------------------   F(1, 413)       =    105.27
#        Model |   856300.89         1   856300.89   Prob > F        =    0.0000
#     Residual |  3359345.75       413  8134.00907   R-squared       =    0.2031
# -------------+----------------------------------   Adj R-squared   =    0.2012
#        Total |  4215646.64       414  10182.7213   Root MSE        =    90.189
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        griph |   6.755054   .6583669    10.26   0.000     5.460886    8.049222
#        _cons |   3657.597   16.01867   228.33   0.000     3626.109    3689.085
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (365 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       415
# -------------+----------------------------------   F(1, 413)       =     73.06
#        Model |  739861.305         1  739861.305   Prob > F        =    0.0000
#     Residual |  4182335.07       413  10126.7193   R-squared       =    0.1503
# -------------+----------------------------------   Adj R-squared   =    0.1483
#        Total |  4922196.38       414  11889.3632   Root MSE        =    100.63
#
# ------------------------------------------------------------------------------
#         tsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |   .8981923   .1050821     8.55   0.000     .6916299    1.104755
#        _cons |   3574.166   14.10345   253.42   0.000     3546.443     3601.89
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (404 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       307
# -------------+----------------------------------   F(1, 305)       =     48.11
#        Model |  72519.0773         1  72519.0773   Prob > F        =    0.0000
#     Residual |  459714.453       305   1507.2605   R-squared       =    0.1363
# -------------+----------------------------------   Adj R-squared   =    0.1334
#        Total |  532233.531       306  1739.32526   Root MSE        =    38.823
#
# ------------------------------------------------------------------------------
#          mvh |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |  -.3581795   .0516379    -6.94   0.000    -.4597911   -.2565678
#        _cons |    148.689   6.516625    22.82   0.000     135.8657    161.5122
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (307 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       385
# -------------+----------------------------------   F(1, 383)       =     51.43
#        Model |  3200830.57         1  3200830.57   Prob > F        =    0.0000
#     Residual |  23837863.9       383  62239.8536   R-squared       =    0.1184
# -------------+----------------------------------   Adj R-squared   =    0.1161
#        Total |  27038694.5       384  70413.2669   Root MSE        =    249.48
#
# ------------------------------------------------------------------------------
#         ntxc |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        rsosh |  -1.021348   .1424219    -7.17   0.000    -1.301375   -.7413216
#        _cons |   4437.588   543.5995     8.16   0.000     3368.775    5506.401
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (385 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =     16.95
#        Model |  25712.1747         1  25712.1747   Prob > F        =    0.0000
#     Residual |  637264.527       420  1517.29649   R-squared       =    0.0388
# -------------+----------------------------------   Adj R-squared   =    0.0365
#        Total |  662976.701       421  1574.76651   Root MSE        =    38.952
#
# ------------------------------------------------------------------------------
#        godin |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |  -4.048033    .983354    -4.12   0.000    -5.980942   -2.115125
#        _cons |   68.90221   2.098877    32.83   0.000     64.77659    73.02782
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (422 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       425
# -------------+----------------------------------   F(1, 423)       =    101.79
#        Model |     36.1171         1     36.1171   Prob > F        =    0.0000
#     Residual |  150.083669       423  .354807728   R-squared       =    0.1940
# -------------+----------------------------------   Adj R-squared   =    0.1921
#        Total |  186.200769       424  .439152757   Root MSE        =    .59566
#
# ------------------------------------------------------------------------------
#          paq |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |  -.1502876   .0148958   -10.09   0.000    -.1795665   -.1210086
#        _cons |   3.010526   .0318121    94.63   0.000     2.947996    3.073055
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (425 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       421
# -------------+----------------------------------   F(1, 419)       =      0.00
#        Model |  231.166793         1  231.166793   Prob > F        =    0.9734
#     Residual |  87203144.1       419  208122.062   R-squared       =    0.0000
# -------------+----------------------------------   Adj R-squared   =   -0.0024
#        Total |  87203375.3       420  207627.084   Root MSE        =     456.2
#
# ------------------------------------------------------------------------------
#         calc |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   .3832824   11.50046     0.03   0.973     -22.2225    22.98907
#        _cons |   976.8891   24.47706    39.91   0.000      928.776    1025.002
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (421 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =      6.17
#        Model |  1417757.66         1  1417757.66   Prob > F        =    0.0134
#     Residual |  96478213.7       420  229710.033   R-squared       =    0.0145
# -------------+----------------------------------   Adj R-squared   =    0.0121
#        Total |  97895971.3       421  232531.998   Root MSE        =    479.28
#
# ------------------------------------------------------------------------------
#         cint |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   30.01276   12.08078     2.48   0.013      6.26644    53.75908
#        _cons |   1624.941   25.69685    63.24   0.000     1574.431    1675.451
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (422 real changes made)

# %%
dm['rsoshs'] = (dm['rsosh'] - dm['rsosh'].mean()) / dm['rsosh'].std()
dm['tsoshs'] = (dm['tsosh'] - dm['tsosh'].mean()) / dm['tsosh'].std()
dm['griphs'] = (dm['griph'] - dm['griph'].mean()) / dm['griph'].std()
dm['ptisohs'] = (dm['ptisoh'] - dm['ptisoh'].mean()) / dm['ptisoh'].std()
dm['ntxhs'] = (dm['ntxh'] - dm['ntxh'].mean()) / dm['ntxh'].std()
dm['mvhhs'] = (dm['mvhh'] - dm['mvhh'].mean()) / dm['mvhh'].std()
dm['godinhs'] = (dm['godinh'] - dm['godinh'].mean()) / dm['godinh'].std()
dm['cinths'] = (dm['cinth'] - dm['cinth'].mean()) / dm['cinth'].std()

# %%
# %%stata --data dm --openstata
#
# constraint 1 M1[id]=M2[id]
#
# gsem ///
# (rsosh <-  griph  matu ntxh       M1[id]) ///
# (tsosh <-  ptisoh matu ntxh mvhh  M2[id]) ///
# (griph <-   matu godinh cinth) ///
# (ptisoh <-  matu godinh cinth) , constraints(1)
# matrix b = e(b)
#
# gsem ///
# (rsoshs <-  griphs  matu ntxhs       M1[id]) ///
# (tsoshs <-  ptisohs matu ntxhs mvhhs M2[id]) ///
# (griphs <-   matu godinhs cinths) ///
# (ptisohs <-  matu godinhs cinths) , constraints(1)
# matrix b = e(b)
# Out:
# > (rsosh <-  griph  matu ntxh       M1[id]) ///
# > (tsosh <-  ptisoh matu ntxh mvhh  M2[id]) ///
# > (griph <-   matu godinh cinth) ///
# > (ptisoh <-  matu godinh cinth) , constraints(1)
# (note: constraint number 1 caused error r(111))
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8397.3011
# Iteration 1:   log likelihood = -8397.3011
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -8354.8617
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -8354.8617  (not concave)
# Iteration 1:   log likelihood =  -8314.952  (not concave)
# Iteration 2:   log likelihood = -8273.1236  (not concave)
# Iteration 3:   log likelihood = -8259.0818  (not concave)
# Iteration 4:   log likelihood = -8251.8608  (not concave)
# Iteration 5:   log likelihood = -8249.1432
# Iteration 6:   log likelihood = -8247.8279  (not concave)
# Iteration 7:   log likelihood = -8247.8103
# Iteration 8:   log likelihood = -8247.7926
# Iteration 9:   log likelihood = -8247.7709
# Iteration 10:  log likelihood = -8247.7705
# Iteration 11:  log likelihood = -8247.7705
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : tsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : griph
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -8247.7705
#
#  ( 1)  [rsosh]M1[id] = 1
#  ( 2)  [tsosh]M2[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsosh <-          |
#             griph |   3.712551   .6837857     5.43   0.000     2.372356    5.052747
#              matu |   14.61469   2.589928     5.64   0.000     9.538526    19.69086
#              ntxh |  -.0672747   .0135117    -4.98   0.000    -.0937571   -.0407923
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   3778.938   19.91355   189.77   0.000     3739.909    3817.968
# ------------------+----------------------------------------------------------------
# tsosh <-          |
#            ptisoh |   .2660039   .1037826     2.56   0.010     .0625938    .4694141
#              matu |   27.77835   3.066982     9.06   0.000     21.76717    33.78952
#              ntxh |  -.0588078   .0141652    -4.15   0.000    -.0865712   -.0310445
#              mvhh |   .2383942    .114427     2.08   0.037     .0141214     .462667
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |    3681.81   21.99144   167.42   0.000     3638.707    3724.912
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.077326   .1348627    15.40   0.000        1.813    2.341653
#            godinh |   .0282535   .0066778     4.23   0.000     .0151653    .0413416
#             cinth |   .0018846   .0005427     3.47   0.001     .0008209    .0029483
#             _cons |   20.13798   .9481701    21.24   0.000      18.2796    21.99635
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   14.25638   .9353996    15.24   0.000     12.42303    16.08973
#            godinh |   .0992885   .0463165     2.14   0.032     .0085099    .1900671
#             cinth |   .0166633   .0037643     4.43   0.000     .0092855    .0240411
#             _cons |   104.6956    6.57645    15.92   0.000     91.80598    117.5852
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   3402.909   522.6946                      2518.279    4598.295
#        var(M2[id])|   5145.956   699.6543                      3942.167    6717.336
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   2506.178   458.8333     5.46   0.000     1606.881    3405.475
# ------------------+----------------------------------------------------------------
#       var(e.rsosh)|   2695.576   248.3876                      2250.176    3229.139
#       var(e.tsosh)|     2793.5   252.3021                      2340.293    3334.472
#       var(e.griph)|   27.19957   1.865875                      23.77771    31.11386
#      var(e.ptisoh)|   1308.496    89.7621                       1143.88    1496.802
# -----------------------------------------------------------------------------------
# > (rsoshs <-  griphs  matu ntxhs mvhhs M1[id]) ///
# > (tsoshs <-  ptisohs matu ntxhs mvhhs  M2[id]) ///
# > (griphs <-   matu godinhs cinths) ///
# > (ptisohs <-  matu godinhs cinths) , constraints(1)
# (note: constraint number 1 caused error r(111))
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2050.8529
# Iteration 1:   log likelihood = -2050.8529
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -2008.6679
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -2008.6679  (not concave)
# Iteration 1:   log likelihood = -1962.8663  (not concave)
# Iteration 2:   log likelihood = -1927.5616
# Iteration 3:   log likelihood = -1912.7692
# Iteration 4:   log likelihood = -1902.3819
# Iteration 5:   log likelihood = -1901.9997
# Iteration 6:   log likelihood =  -1901.998
# Iteration 7:   log likelihood =  -1901.998
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisohs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood =  -1901.998
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsoshs <-         |
#            griphs |   .2710268   .0496508     5.46   0.000      .173713    .3683406
#              matu |   .1434648   .0314938     4.56   0.000     .0817381    .2051916
#             ntxhs |  -.1875497    .037289    -5.03   0.000    -.2606348   -.1144647
#             mvhhs |  -.0431287   .0426662    -1.01   0.312    -.1267529    .0404955
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   .1077214    .062573     1.72   0.085    -.0149194    .2303623
# ------------------+----------------------------------------------------------------
# tsoshs <-         |
#           ptisohs |   .1179998   .0460559     2.56   0.010      .027732    .2082677
#              matu |    .262065   .0292149     8.97   0.000     .2048049    .3193251
#             ntxhs |  -.1432816   .0343594    -4.17   0.000    -.2106248   -.0759384
#             mvhhs |   .0789521   .0404166     1.95   0.051     -.000263    .1581672
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   .2051513   .0636401     3.22   0.001      .080419    .3298836
# ------------------+----------------------------------------------------------------
# griphs <-         |
#              matu |    .309461   .0200906    15.40   0.000     .2700841    .3488378
#           godinhs |   .1664946   .0393512     4.23   0.000     .0893675    .2436216
#            cinths |   .1349164   .0388532     3.47   0.001     .0587656    .2110672
#             _cons |    .276527   .0417442     6.62   0.000     .1947099    .3583441
# ------------------+----------------------------------------------------------------
# ptisohs <-        |
#              matu |   .3053834    .020037    15.24   0.000     .2661115    .3446552
#           godinhs |   .0841322   .0392463     2.14   0.032     .0072108    .1610535
#            cinths |   .1715326   .0387495     4.43   0.000     .0955848    .2474803
#             _cons |   .2728835   .0416329     6.55   0.000     .1912846    .3544824
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   .3962077   .0609519                      .2930728    .5356366
#        var(M2[id])|   .4647809   .0631837                      .3560684    .6066848
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   .2561956   .0470428     5.45   0.000     .1639934    .3483977
# ------------------+----------------------------------------------------------------
#      var(e.rsoshs)|   .3147566   .0290014                       .262752    .3770542
#      var(e.tsoshs)|   .2522742   .0227808                      .2113528    .3011187
#      var(e.griphs)|   .6036209   .0414081                       .527682    .6904881
#     var(e.ptisohs)|   .6004055   .0411875                      .5248712      .68681
# -----------------------------------------------------------------------------------
#
# .

# %%
dm.head(10)
# Out:
#     id  session  sequence  seq  trips  nota  falk    rsos    tsos  grip  \
# 0  100        1         1    1    4.0   NaN   NaN  3828.0  3601.0   NaN
# 1  100        1         3    2    4.0   NaN   NaN  3898.0  3629.0  27.0
# 2  100        1         5    3    4.0   1.0   NaN  3851.0  3677.0  37.0
# 3  100        1         7    4    4.0   NaN   NaN  3952.0  3740.0  40.5
# 4  101        1         1    1    1.0   NaN   NaN  3682.0  3603.0   NaN
# 5  102        1         1    1    4.0   NaN   NaN  3935.0  3916.0   NaN
# 6  102        1         3    2    4.0   NaN   NaN  3899.0  3863.0  27.0
# 7  102        1         5    3    4.0   NaN   NaN  3878.0  3908.0  42.0
# 8  102        1         7    4    4.0   NaN   NaN  3951.0  4015.0  42.0
# 9  103        1         1    1    3.0   NaN   NaN  3768.0  3686.0   NaN
#
#         ptiso        pt60  godin     paq        ntxc         cint  \
# 0  113.928055   69.291710   37.0  2.5866  711.848145  1572.000000
# 1  136.023758   87.778656   48.0  3.1656  760.093933  2219.011963
# 2  177.053085  103.303604   44.0  3.2084  543.734619  2599.831055
# 3         NaN         NaN   66.0  2.7597  454.364349  2482.117920
# 4  133.048798   86.341110   25.0  1.7136  937.996765  1549.993042
# 5  171.360291   83.164680   45.0  2.9459  435.431000  1308.953979
# 6         NaN         NaN  102.0  3.8297  650.394531  1260.655029
# 7  210.997086  134.422821  113.0  3.3557  906.064087  2509.722900
# 8         NaN         NaN  123.0  2.4667         NaN  1685.947021
# 9  146.600281   90.861717   33.0  3.2554  737.074768  2551.882080
#
#           calc   vitd       vitd2         mvh  matu    age  gender      griph  \
# 0  1077.668945  3.382  135.274002  105.709999 -1.67  11.75       0  23.770721
# 1  1212.817993  1.025   41.018002   93.620003 -0.71  12.71       0  27.000000
# 2   874.338013  4.546  181.848007   98.139999  0.41  13.83       0  24.354441
# 3  1672.296997  5.907  236.738998   88.139999  1.17  14.74       0  40.500000
# 4  1521.052002  7.432  297.299988   89.290001 -1.63  11.45       0  20.065380
# 5   504.941986  3.238  129.501999   86.570000 -1.24  12.29       0  26.486280
# 6   771.072998  1.084   43.356998   68.709999 -0.27  13.26       0  27.000000
# 7   552.890015  1.895   89.841003   59.139999  0.77  14.30       0  42.000000
# 8   534.088013  3.337  135.897003   60.709999  2.08  15.38       0  42.000000
# 9   994.062988  3.764  150.544006  120.570000 -1.91  11.83       0  22.247978
#
#        ptisoh        rsosh   tsosh        mvhh        ntxh  godinh    paqh  \
# 0  113.928055  3828.000000  3601.0  105.709999  711.848145    37.0  2.5866
# 1  136.023758  3898.000000  3629.0   93.620003  760.093933    48.0  3.1656
# 2  177.053085  3822.112549  3677.0   98.139999  543.734619    44.0  3.2084
# 3  134.567993  3952.000000  3740.0   88.139999  454.364349    66.0  2.7597
# 4  133.048798  3682.000000  3603.0   89.290001  937.996765    25.0  1.7136
# 5  171.360291  3935.000000  3916.0   86.570000  435.431000    45.0  2.9459
# 6  155.151871  3899.000000  3863.0   68.709999  650.394531   102.0  3.8297
# 7  210.997086  3878.000000  3908.0   59.139999  906.064087   113.0  3.3557
# 8  180.588852  3951.000000  4015.0   60.709999  402.240692   123.0  2.4667
# 9  146.600281  3768.000000  3686.0  120.570000  737.074768    33.0  3.2554
#
#          calch        cinth    rsoshs    tsoshs    griphs   ptisohs     ntxhs  \
# 0  1077.668945  1572.000000  0.106119 -0.813017  0.063802 -0.254023  0.681627
# 1  1212.817993  2219.011963  0.863356 -0.546909  0.544870  0.219285  0.870666
# 2   874.338013  2599.831055  0.042431 -0.090723  0.150759  1.098167  0.022918
# 3  1672.296997  2482.117920  1.447509  0.508021  2.555976  0.188102 -0.327256
# 4  1521.052002  1549.993042 -1.473259 -0.794009 -0.488186  0.155559  1.567732
# 5   504.941986  1308.953979  1.263609  2.180701  0.468341  0.976223 -0.401441
# 6   771.072998  1260.655029  0.874173  1.676996  0.544870  0.629025  0.440837
# 7   552.890015  2509.722900  0.647002  2.104671  2.779432  1.825276  1.442612
# 8   534.088013  1685.947021  1.436692  3.121584  2.779432  1.173906 -0.531489
# 9   994.062988  2551.882080 -0.542940 -0.005188 -0.163043  0.445843  0.780471
#
#       mvhhs   godinhs    cinths
# 0  0.056194 -0.897923 -0.054358
# 1 -0.271182 -0.619845  1.292007
# 2 -0.148788 -0.720964  2.084451
# 3 -0.419571 -0.164810  1.839503
# 4 -0.388431 -1.201280 -0.100152
# 5 -0.462084 -0.695685 -0.601729
# 6 -0.945701  0.745262 -0.702234
# 7 -1.204840  1.023339  1.896946
# 8 -1.162327  1.276137  0.182754
# 9  0.458576 -0.999042  1.984675

# %%
dm.describe()
# Out:
#                id     session    sequence         seq       trips  nota  falk  \
# count  425.000000  425.000000  425.000000  425.000000  425.000000  50.0  11.0
# mean   326.197647    1.430588    4.197647    1.868235    2.736471   1.0   1.0
# std    197.549787    0.495742    1.833518    0.877686    0.827711   0.0   0.0
# min    100.000000    1.000000    1.000000    1.000000    1.000000   1.0   1.0
# 25%    138.000000    1.000000    3.000000    1.000000    2.000000   1.0   1.0
# 50%    189.000000    1.000000    4.000000    2.000000    3.000000   1.0   1.0
# 75%    530.000000    2.000000    6.000000    2.000000    3.000000   1.0   1.0
# max    583.000000    2.000000    7.000000    4.000000    4.000000   1.0   1.0
#
#               rsos         tsos        grip       ptiso        pt60  \
# count   415.000000   415.000000  379.000000  310.000000  310.000000
# mean   3815.551807  3687.079518   23.438074  124.041290   84.050201
# std     100.909471   109.038357    7.364498   53.311306   33.349968
# min    3542.000000  3367.000000    9.000000   32.647167   28.224886
# 25%    3746.500000  3619.000000   18.000000   84.335386   58.508888
# 50%    3820.000000  3689.000000   22.250000  114.025639   76.993565
# 75%    3878.000000  3758.000000   27.500000  156.607567  102.830297
# max    4140.000000  4015.000000   53.000000  343.836792  237.822296
#
#             godin         paq         ntxc         cint         calc  \
# count  422.000000  425.000000   385.000000   422.000000   421.000000
# mean    72.606635    3.144819   540.346619  1598.184814   976.547974
# std     39.683328    0.662686   265.354980   482.215729   455.661133
# min      0.000000    1.250000    56.308327   469.496002    51.714001
# 25%     44.000000    2.718600   369.744904  1263.682983   652.146973
# 50%     65.000000    3.197700   514.754761  1548.725037   915.741028
# 75%     92.750000    3.663800   662.435608  1878.681793  1196.994019
# max    234.000000    4.610400  1754.324463  3624.724121  2518.876953
#
#              vitd       vitd2         mvh        matu         age      gender  \
# count  421.000000  421.000000  307.000000  425.000000  425.000000  425.000000
# mean     4.703625  189.981476  106.180466   -0.893577   11.850613    0.468235
# std      3.152561  127.345634   41.705219    1.942006    2.003003    0.499578
# min      0.000000    0.000000   13.570000   -5.300000    7.500000    0.000000
# 25%      2.649000  107.401001   78.139999   -2.290000   10.340000    0.000000
# 50%      4.204000  173.792007   99.110001   -1.000000   11.850000    0.000000
# 75%      6.464000  263.270996  133.389999    0.450000   13.230000    1.000000
# max     21.211000  848.426025  235.000000    4.950000   17.549999    1.000000
#
#             griph      ptisoh        rsosh        tsosh        mvhh  \
# count  425.000000  425.000000   425.000000   425.000000  425.000000
# mean    23.342438  125.786736  3818.190186  3686.545898  103.634758
# std      6.712725   46.683552    92.441414   105.220322   36.930027
# min      9.000000   32.647167  3542.000000  3381.000000   13.570000
# 25%     19.000000   92.666969  3767.000000  3623.699951   82.000000
# 50%     22.654043  120.684532  3820.000000  3686.000000   98.931030
# 75%     26.486280  150.466110  3872.000000  3751.000000  119.959816
# max     53.000000  343.836792  4140.000000  4015.000000  235.000000
#
#               ntxh      godinh        paqh        calch        cinth  \
# count   425.000000  425.000000  425.000000   425.000000   425.000000
# mean    537.885498   72.519432    3.144819   976.546631  1598.122314
# std     255.216660   39.557331    0.662686   453.506714   480.562256
# min      56.308327    0.000000    1.250000    51.714001   469.496002
# 25%     380.352814   44.000000    2.718600   661.242004  1264.697021
# 50%     513.239929   65.000000    3.197700   920.513977  1549.993042
# 75%     650.394531   92.000000    3.663800  1196.979004  1878.453003
# max    1754.324463  234.000000    4.610400  2518.876953  3624.724121
#
#            rsoshs      tsoshs        griphs       ptisohs         ntxhs  \
# count  425.000000  425.000000  4.250000e+02  4.250000e+02  4.250000e+02
# mean     0.000003   -0.000001 -6.731819e-08  1.032212e-07 -1.234167e-07
# std      1.000000    1.000000  1.000000e+00  1.000000e+00  1.000000e+00
# min     -2.987732   -2.903868 -2.136604e+00 -1.995126e+00 -1.886935e+00
# 25%     -0.553758   -0.597280 -6.468964e-01 -7.094526e-01 -6.172508e-01
# 50%      0.019578   -0.005188 -1.025507e-01 -1.092934e-01 -9.656724e-02
# 75%      0.582096    0.612563  4.683408e-01  5.286525e-01  4.408374e-01
# max      3.481230    3.121584  4.418110e+00  4.670811e+00  4.766299e+00
#
#               mvhhs       godinhs        cinths
# count  4.250000e+02  4.250000e+02  4.250000e+02
# mean  -1.436121e-07  2.692727e-08  7.180606e-08
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.438795e+00 -1.833274e+00 -2.348554e+00
# 25%   -5.858311e-01 -7.209645e-01 -6.938233e-01
# 50%   -1.273686e-01 -1.900895e-01 -1.001520e-01
# 75%    4.420538e-01  4.924642e-01  5.833390e-01
# max    3.557139e+00  4.082191e+00  4.217147e+00

# %%
dm.columns
# Out:
# Index(['id', 'session', 'sequence', 'seq', 'trips', 'nota', 'falk', 'rsos',
#        'tsos', 'grip', 'ptiso', 'pt60', 'godin', 'paq', 'ntxc', 'cint', 'calc',
#        'vitd', 'vitd2', 'mvh', 'matu', 'age', 'gender', 'griph', 'ptisoh',
#        'rsosh', 'tsosh', 'mvhh', 'ntxh', 'godinh', 'paqh', 'calch', 'cinth',
#        'rsoshs', 'tsoshs', 'griphs', 'ptisohs', 'ntxhs', 'mvhhs', 'godinhs'],
#       dtype='object')

# %%
# %%stata --data dm --openstata
#
# constraint 1 M1[id]=M2[id]
#
# gsem ///
# (rsosh <-  griph  matu ntxh       M1[id]) ///
# (tsosh <-  ptisoh matu ntxh mvhh  M2[id]) ///
# (griph <-   matu godinh cinth) ///
# (ptisoh <-  matu godinh cinth) , constraints(1)
# matrix b = e(b)
# Out:
# > (rsosh <-  griph  matu ntxh mvhh  M1[id]) ///
# > (tsosh <-  ptisoh matu ntxh mvhh  M2[id]) ///
# > (griph <-   matu godinh cinth) ///
# > (ptisoh <-  matu godinh cinth) ,constraints(1)
# (note: constraint number 1 caused error r(111))
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8396.1149
# Iteration 1:   log likelihood = -8396.1149
#
# Refining starting values:
#
# Grid node 0:   log likelihood =   -8353.93
#
# Fitting full model:
#
# Iteration 0:   log likelihood =   -8353.93  (not concave)
# Iteration 1:   log likelihood = -8314.3246  (not concave)
# Iteration 2:   log likelihood = -8272.3864  (not concave)
# Iteration 3:   log likelihood = -8258.4659  (not concave)
# Iteration 4:   log likelihood = -8251.2939  (not concave)
# Iteration 5:   log likelihood = -8249.0693
# Iteration 6:   log likelihood = -8247.9025  (not concave)
# Iteration 7:   log likelihood = -8247.6797
# Iteration 8:   log likelihood = -8247.5023  (not concave)
# Iteration 9:   log likelihood = -8247.3273
# Iteration 10:  log likelihood = -8247.3255  (not concave)
# Iteration 11:  log likelihood =  -8247.292
# Iteration 12:  log likelihood = -8247.2733
# Iteration 13:  log likelihood = -8247.2645
# Iteration 14:  log likelihood = -8247.2602
# Iteration 15:  log likelihood = -8247.2601
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : tsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : griph
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -8247.2601
#
#  ( 1)  [rsosh]M1[id] = 1
#  ( 2)  [tsosh]M2[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsosh <-          |
#             griph |    3.73266   .6836642     5.46   0.000     2.392703    5.072617
#              matu |   13.26146   2.911346     4.56   0.000     7.555322    18.96759
#              ntxh |   -.067931   .0135061    -5.03   0.000    -.0944026   -.0414595
#              mvhh |  -.1079587   .1067992    -1.01   0.312    -.3172814    .1013639
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   3788.746   22.16393   170.94   0.000     3745.305    3832.186
# ------------------+----------------------------------------------------------------
# tsosh <-          |
#            ptisoh |   .2659652   .1038056     2.56   0.010     .0625099    .4694204
#              matu |   27.57449   3.073999     8.97   0.000     21.54957    33.59942
#              ntxh |   -.059072   .0141656    -4.17   0.000    -.0868362   -.0313078
#              mvhh |   .2249494   .1151543     1.95   0.051    -.0007488    .4506476
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   3683.138   22.01122   167.33   0.000     3639.997     3726.28
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.077326   .1348627    15.40   0.000        1.813    2.341653
#            godinh |   .0282535   .0066778     4.23   0.000     .0151653    .0413416
#             cinth |   .0018846   .0005427     3.47   0.001     .0008209    .0029483
#             _cons |   20.13798   .9481701    21.24   0.000      18.2796    21.99635
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   14.25638   .9353996    15.24   0.000     12.42303    16.08973
#            godinh |   .0992885   .0463165     2.14   0.032     .0085099    .1900671
#             cinth |   .0166633   .0037643     4.43   0.000     .0092855    .0240411
#             _cons |   104.6956    6.57645    15.92   0.000     91.80598    117.5852
# ------------------+----------------------------------------------------------------
#        var(M1[id])|    3385.81   520.8482                      2504.494    4577.256
#        var(M2[id])|   5145.735   699.5263                      3942.144    6716.797
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   2491.932   457.5729     5.45   0.000     1595.106    3388.759
# ------------------+----------------------------------------------------------------
#       var(e.rsosh)|    2689.67   247.7907                      2245.331     3221.94
#       var(e.tsosh)|   2793.008   252.2132                      2339.954    3333.781
#       var(e.griph)|   27.19957   1.865875                      23.77771    31.11386
#      var(e.ptisoh)|   1308.496    89.7621                       1143.88    1496.802
# -----------------------------------------------------------------------------------
#
# .

# %%
# %%stata --graph -d dm
#
# graph twoway (scatter tsosh mvhh)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="./temp_graph.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%stata --data dm --openstata
#
# drop if trips==1
#
# gsem ///
# (rsosh <-  griph  matu ntxh M1[id]) ///
# (tsosh <-  ptisoh matu mvhh M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   )
# matrix b = e(b)
#
# gsem ///
# (rsosh <-  griph  matu  ntxh M1[id]) ///
# (tsosh <-  ptisoh matu  mvhh M2[id]) ///
# (griph <-   matu M3[id]) ///
# (ptisoh <-  matu M4[id]) , from(b, skip)
#
# gsem ///
# (rsoshs <-  griphs  matu ntxhs M1[id]) ///
# (tsoshs <-  ptisohs matu mvhhs M2[id]) ///
# (griphs <-   matu   ) ///
# (ptisohs <-  matu   )
# matrix b = e(b)
#
# gsem ///
# (rsoshs <-  griphs  matu ntxhs M1[id]) ///
# (tsoshs <-  ptisohs matu mvhhs M2[id]) ///
# (griph <-   matu M3[id]) ///
# (ptisoh <-  matu M4[id]) , from(b, skip)
# Out:
# 'Failed to open Stata'

# %%
# %%stata --data dm --openstata
#
# keep id seq trips rsosh tsosh griph ptisoh ntxh mvhh matu
# drop if missing(rsosh)
# drop if missing(tsosh)
# drop if missing(griph)
# drop if missing(ptisoh)
# drop if missing(ntxh)
# drop if missing(mvhh)
# drop if missing(matu)
#
# drop if trips==1
# count
#
# gsem ///
# (rsosh <-  griph  matu ntxh M1[id]) ///
# (tsosh <-  ptisoh matu mvhh M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   )
# matrix b = e(b)
#
# gsem ///
# (rsosh <-  griph  matu  ntxh M1[id]) ///
# (tsosh <-  ptisoh matu  mvhh M2[id]) ///
# (griph <-   matu M3[id]) ///
# (ptisoh <-  matu M4[id]) , from(b, skip)
# Out:
# . keep id rsosh tsosh griph ptisoh ntxh mvhh matu
# (0 observations deleted)
# (10 observations deleted)
# (0 observations deleted)
# (0 observations deleted)
# (0 observations deleted)
# (0 observations deleted)
# (0 observations deleted)
#   415
# > (rsosh <-  griph  matu ntxh M1[id]) ///
# > (tsosh <-  ptisoh matu mvhh M2[id]) ///
# > (griph <-   matu   ) ///
# > (ptisoh <-  matu   )
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8172.5731
# Iteration 1:   log likelihood = -8172.5731
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -8142.0646
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -8142.0646  (not concave)
# Iteration 1:   log likelihood = -8086.9295  (not concave)
# Iteration 2:   log likelihood = -8073.0673  (not concave)
# Iteration 3:   log likelihood = -8054.6206  (not concave)
# Iteration 4:   log likelihood = -8043.7581
# Iteration 5:   log likelihood = -8037.2353  (not concave)
# Iteration 6:   log likelihood = -8035.9737
# Iteration 7:   log likelihood = -8035.8983
# Iteration 8:   log likelihood = -8035.8914
# Iteration 9:   log likelihood = -8035.8913
#
# Generalized structural equation model           Number of obs     =        415
#
# Response       : rsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : tsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : griph
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -8035.8913
#
#  ( 1)  [rsosh]M1[id] = 1
#  ( 2)  [tsosh]M2[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsosh <-          |
#             griph |    2.47901   .7819861     3.17   0.002     .9463459    4.011675
#              matu |   14.73718   3.151538     4.68   0.000     8.560283    20.91408
#              ntxh |  -.0690912   .0151343    -4.57   0.000    -.0987539   -.0394284
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |    3805.13   22.57735   168.54   0.000      3760.88    3849.381
# ------------------+----------------------------------------------------------------
# tsosh <-          |
#            ptisoh |   .9042966   .1236617     7.31   0.000     .6619241    1.146669
#              matu |   27.65862   2.742262    10.09   0.000     22.28388    33.03335
#              mvhh |   .2825697   .1081423     2.61   0.009     .0706147    .4945247
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   3559.031   21.49254   165.59   0.000     3516.907    3601.156
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.236719   .1376062    16.25   0.000     1.967016    2.506422
#             _cons |   25.39479    .294538    86.22   0.000     24.81751    25.97208
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   8.177211   .7733292    10.57   0.000     6.661514    9.692909
#             _cons |   138.9721   1.655266    83.96   0.000     135.7279    142.2164
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   4407.832   653.7373                      3295.954    5894.799
#        var(M2[id])|   4490.998   642.5893                      3392.733    5944.784
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   2474.773   490.0276     5.05   0.000     1514.336    3435.209
# ------------------+----------------------------------------------------------------
#       var(e.rsosh)|   3414.102   310.4373                      2856.792    4080.135
#       var(e.tsosh)|   2503.937   232.9164                      2086.626    3004.708
#       var(e.griph)|   29.93558   2.078159                      26.12742    34.29881
#      var(e.ptisoh)|    945.455   65.63444                      825.1817    1083.259
# -----------------------------------------------------------------------------------
# > (rsosh <-  griph  matu  ntxh M1[id]) ///
# > (tsosh <-  ptisoh matu  mvhh M2[id]) ///
# > (griph <-   matu M3[id]) ///
# > (ptisoh <-  matu M4[id]) , from(b, skip)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8172.5731
# Iteration 1:   log likelihood = -8172.5731
#
# Refining starting values:
#
# Grid node 0:   log likelihood =  -7995.929
#
# Fitting full model:
#
# Iteration 0:   log likelihood =  -7995.929  (not concave)
# Iteration 1:   log likelihood = -7977.8489  (not concave)
# Iteration 2:   log likelihood = -7947.3522
# Iteration 3:   log likelihood =  -7933.112  (not concave)
# Iteration 4:   log likelihood =  -7897.057  (not concave)
# Iteration 5:   log likelihood = -7894.7368
# Iteration 6:   log likelihood = -7893.8654  (not concave)
# Iteration 7:   log likelihood = -7893.4216  (not concave)
# Iteration 8:   log likelihood = -7893.3199
# Iteration 9:   log likelihood = -7893.1868
# Iteration 10:  log likelihood = -7893.1866
#
# Generalized structural equation model           Number of obs     =        415
#
# Response       : rsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : tsosh
# Family         : Gaussian
# Link           : identity
#
# Response       : griph
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -7893.1866
#
#  ( 1)  [rsosh]M1[id] = 1
#  ( 2)  [tsosh]M2[id] = 1
#  ( 3)  [griph]M3[id] = 1
#  ( 4)  [ptisoh]M4[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsosh <-          |
#             griph |   2.925197   1.096137     2.67   0.008     .7768074    5.073586
#              matu |   13.36189   3.896107     3.43   0.001     5.725663    20.99812
#              ntxh |  -.0650926   .0150245    -4.33   0.000    -.0945401   -.0356452
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   3791.494   30.03336   126.24   0.000      3732.63    3850.359
# ------------------+----------------------------------------------------------------
# tsosh <-          |
#            ptisoh |   .6923076   .1584271     4.37   0.000     .3817962    1.002819
#              matu |    29.5203   2.887685    10.22   0.000     23.86054    35.18006
#              mvhh |   .2866677   .1079284     2.66   0.008      .075132    .4982033
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   3588.388   25.62792   140.02   0.000     3538.158    3638.617
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.536233   .1469071    17.26   0.000     2.248301    2.824166
#                   |
#            M3[id] |          1  (constrained)
#                   |
#             _cons |   25.72331   .3942203    65.25   0.000     24.95065    26.49597
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   9.383258   .8270905    11.34   0.000     7.762191    11.00433
#                   |
#            M4[id] |          1  (constrained)
#                   |
#             _cons |   140.2664   2.185779    64.17   0.000     135.9823    144.5504
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   4424.792   653.7031                      3312.374    5910.801
#        var(M2[id])|   4684.829    677.475                       3528.59    6219.942
#        var(M3[id])|     18.422   2.597568                       13.9738    24.28618
#        var(M4[id])|   531.3639   84.31261                       389.341    725.1936
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   2562.346   503.2269     5.09   0.000      1576.04    3548.653
# cov(M3[id],M1[id])|  -15.56163   38.40428    -0.41   0.685    -90.83263    59.70938
# cov(M4[id],M1[id])|   586.5735   180.0889     3.26   0.001     233.6056    939.5413
# cov(M3[id],M2[id])|   20.55916   30.38382     0.68   0.499    -38.99203    80.11035
# cov(M4[id],M2[id])|    631.962   207.7464     3.04   0.002     224.7865    1039.137
# cov(M4[id],M3[id])|   60.16945   11.17054     5.39   0.000      38.2756     82.0633
# ------------------+----------------------------------------------------------------
#       var(e.rsosh)|   3405.114   308.3829                        2851.3    4066.497
#       var(e.tsosh)|   2503.433   232.9326                      2086.103    3004.251
#       var(e.griph)|   11.60171   1.050409                      9.715272    13.85444
#      var(e.ptisoh)|   438.0425    41.3363                      364.0758    527.0365
# -----------------------------------------------------------------------------------

# %%
dm.describe()
# Out:
#                id     session    sequence         seq       trips  nota  falk  \
# count  425.000000  425.000000  425.000000  425.000000  425.000000  50.0  11.0
# mean   326.197647    1.430588    4.197647    1.868235    2.736471   1.0   1.0
# std    197.549787    0.495742    1.833518    0.877686    0.827711   0.0   0.0
# min    100.000000    1.000000    1.000000    1.000000    1.000000   1.0   1.0
# 25%    138.000000    1.000000    3.000000    1.000000    2.000000   1.0   1.0
# 50%    189.000000    1.000000    4.000000    2.000000    3.000000   1.0   1.0
# 75%    530.000000    2.000000    6.000000    2.000000    3.000000   1.0   1.0
# max    583.000000    2.000000    7.000000    4.000000    4.000000   1.0   1.0
#
#               rsos         tsos        grip     ...              mvh  \
# count   415.000000   415.000000  379.000000     ...       307.000000
# mean   3815.551807  3687.079518   23.438074     ...       106.180466
# std     100.909471   109.038357    7.364498     ...        41.705219
# min    3542.000000  3367.000000    9.000000     ...        13.570000
# 25%    3746.500000  3619.000000   18.000000     ...        78.139999
# 50%    3820.000000  3689.000000   22.250000     ...        99.110001
# 75%    3878.000000  3758.000000   27.500000     ...       133.389999
# max    4140.000000  4015.000000   53.000000     ...       235.000000
#
#              matu         age      gender       griph      ptisoh  \
# count  425.000000  425.000000  425.000000  425.000000  415.000000
# mean    -0.893577   11.850613    0.468235   23.412334  131.787201
# std      1.942006    2.003003    0.499578    6.997608   34.685455
# min     -5.300000    7.500000    0.000000    9.000000   72.146973
# 25%     -2.290000   10.340000    0.000000   18.500000  114.988209
# 50%     -1.000000   11.850000    0.000000   22.500000  126.535263
# 75%      0.450000   13.230000    1.000000   27.000000  138.835381
# max      4.950000   17.549999    1.000000   53.000000  343.836792
#
#              rsosh        tsosh        mvhh        ntxch
# count   425.000000   415.000000  420.000000   420.000000
# mean   3815.268311  3687.079590  104.799309   538.985962
# std      60.782661    71.749718   36.542171   255.051041
# min    3554.000000  3367.000000   13.570000    56.308327
# 25%    3780.298096  3646.712646   83.287502   384.042091
# 50%    3814.430908  3676.513672  102.535000   521.473938
# 75%    3853.525146  3713.966064  118.456932   648.279327
# max    3971.000000  4016.659912  235.000000  1754.324463
#
# [8 rows x 29 columns]

# %%
# %%stata --data dm --openstata
#
# *sum rsosh tsosh griph ptisoh ntxh
#
# tab trips
# drop if trips==1
#
# constraint 1 M1[id]=M2[id]
#
# gsem ///
# (rsos <-  griph  matu  M1[id]) ///
# (tsos <-  ptisoh matu  M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   ) ,  constraints(1)
# matrix b = e(b)
#
#
# gsem ///
# (rsos <-  griph  matu ntxh M1[id]) ///
# (tsos <-  ptisoh matu mvhh M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   ) , from(b, skip)  constraints(1)
# matrix b = e(b)
#
#
#
# gsem ///
# (rsos <-  griph  matu  ntxh M1[id]) ///
# (tsos <-  ptisoh matu  mvhh M2[id]) ///
# (griph <-   matu   M3[id]) ///
# (ptisoh <-  matu   M4[id]) , from(b, skip) constraints(1)

# %%
# %%stata --data dm --openstata
#
# *sum rsosh tsosh griph ptisoh ntxh
#
# tab trips
# drop if trips==1
#
# constraint 1 M1[id]=M2[id]
#
# gsem ///
# (rsos <-  griph  matu  M1[id]) ///
# (tsos <-  ptisoh matu  M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   ) ,  constraints(1)
# matrix b = e(b)
#
#
# gsem ///
# (rsos <-  griph  matu ntxh M1[id]) ///
# (tsos <-  ptisoh matu mvhh M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   ) , from(b, skip)  constraints(1)
# matrix b = e(b)
#
#
#
# gsem ///
# (rsos <-  griph  matu  ntxh M1[id]) ///
# (tsos <-  ptisoh matu  mvhh M2[id]) ///
# (griph <-   matu   M3[id]) ///
# (ptisoh <-  matu   M4[id]) , from(b, skip) constraints(1)
# Out:
# 'Failed to open Stata'

# %%
# %%stata --data dm --openstata
#
# *sum rsosh tsosh griph ptisoh ntxh
#
# tab trips
# drop if trips==1
#
# gsem ///
# (rsos <-  griph  matu  M1[id]) ///
# (tsos <-  ptisoh matu  M1[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   )
# matrix b = e(b)
#
#
# gsem ///
# (rsos <-  griph  matu  		M1[id]) ///
# (tsos <-  ptisoh matu mvhh  M2[id]) ///
# (griph <-   matu   ) ///
# (ptisoh <-  matu   ) , from(b, skip)
# matrix b = e(b)
#
#
# gsem ///
# (rsos <-  griph  matu  ntxh M1[id]) ///
# (tsos <-  ptisoh matu  mvhh M2[id]) ///
# (griph <-   matu   M3[id]) ///
# (ptisoh <-  matu   M4[id]) , from(b, skip)
# Out:
# . gsem ///
# > (rsos <-  griph  matu  M1[id]) ///
# > (tsos <-  ptisoh matu  M1[id]) ///
# > (griph <-   matu   ) ///
# > (ptisoh <-  matu   )
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8225.7985
# Iteration 1:   log likelihood = -8225.7985
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -8225.7739
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -8225.7739  (not concave)
# Iteration 1:   log likelihood =  -8190.627  (not concave)
# Iteration 2:   log likelihood = -8152.3166  (not concave)
# Iteration 3:   log likelihood = -8141.4184
# Iteration 4:   log likelihood = -8130.7432
# Iteration 5:   log likelihood = -8130.5141  (not concave)
# Iteration 6:   log likelihood = -8126.7435  (not concave)
# Iteration 7:   log likelihood = -8124.8415
# Iteration 8:   log likelihood = -8121.9066
# Iteration 9:   log likelihood =  -8115.588
# Iteration 10:  log likelihood = -8111.1424  (not concave)
# Iteration 11:  log likelihood = -8109.8758
# Iteration 12:  log likelihood = -8109.0065
# Iteration 13:  log likelihood = -8108.7915
# Iteration 14:  log likelihood = -8108.7796
# Iteration 15:  log likelihood = -8108.7779
# Iteration 16:  log likelihood = -8108.7779
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsos                           Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Response       : tsos                           Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Response       : griph                          Number of obs     =        425
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh                         Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -8108.7779
#
#  ( 1)  [rsos]M1[id] = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsos <-      |
#        griph |   2.597929    .755963     3.44   0.001     1.116268    4.079589
#         matu |   18.06071   2.946243     6.13   0.000     12.28618    23.83524
#              |
#       M1[id] |          1  (constrained)
#              |
#        _cons |    3768.69   20.08507   187.64   0.000     3729.324    3808.056
# -------------+----------------------------------------------------------------
# tsos <-      |
#       ptisoh |   .8117562   .1196926     6.78   0.000      .577163    1.046349
#         matu |   26.95262   2.523178    10.68   0.000     22.00728    31.89795
#              |
#       M1[id] |   1.554718   .1872185     8.30   0.000     1.187776    1.921659
#              |
#        _cons |    3601.17   17.91057   201.06   0.000     3566.066    3636.274
# -------------+----------------------------------------------------------------
# griph <-     |
#         matu |   2.233787   .1371465    16.29   0.000     1.964984    2.502589
#        _cons |   25.40839   .2928966    86.75   0.000     24.83432    25.98246
# -------------+----------------------------------------------------------------
# ptisoh <-    |
#         matu |   8.177211   .7733292    10.57   0.000     6.661514    9.692909
#        _cons |   138.9721   1.655266    83.96   0.000     135.7279    142.2164
# -------------+----------------------------------------------------------------
#   var(M1[id])|    2042.48   485.1448                      1282.255     3253.43
# -------------+----------------------------------------------------------------
#   var(e.rsos)|   6330.704   507.7999                      5409.725    7408.474
#   var(e.tsos)|   2436.505   255.0201                       1984.61    2991.297
#  var(e.griph)|   30.07711   2.063273                      26.29325    34.40552
# var(e.ptisoh)|    945.455   65.63444                      825.1817    1083.259
# ------------------------------------------------------------------------------
# > (rsos <-  griph  matu           M1[id]) ///
# > (tsos <-  ptisoh matu mvhh  M2[id]) ///
# > (griph <-   matu   ) ///
# > (ptisoh <-  matu   ) , from(b, skip)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8225.3279
# Iteration 1:   log likelihood = -8225.3279
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -8406.8468
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -8406.8468  (not concave)
# Iteration 1:   log likelihood =  -8343.138  (not concave)
# Iteration 2:   log likelihood = -8290.5182  (not concave)
# Iteration 3:   log likelihood =  -8159.262  (not concave)
# Iteration 4:   log likelihood = -8116.8663
# Iteration 5:   log likelihood = -8100.3982
# Iteration 6:   log likelihood = -8080.0464
# Iteration 7:   log likelihood = -8072.8618  (not concave)
# Iteration 8:   log likelihood = -8071.7336
# Iteration 9:   log likelihood = -8071.6116
# Iteration 10:  log likelihood = -8071.6028
# Iteration 11:  log likelihood = -8071.6027
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsos                           Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Response       : tsos                           Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Response       : griph                          Number of obs     =        425
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh                         Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -8071.6027
#
#  ( 1)  [rsos]M1[id] = 1
#  ( 2)  [tsos]M2[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsos <-           |
#             griph |   2.650791   .8002969     3.31   0.001     1.082238    4.219344
#              matu |    18.2421   3.175807     5.74   0.000     12.01763    24.46657
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   3768.616   21.55971   174.80   0.000      3726.36    3810.873
# ------------------+----------------------------------------------------------------
# tsos <-           |
#            ptisoh |   .8921349   .1204538     7.41   0.000     .6560498     1.12822
#              matu |   30.05601   2.699674    11.13   0.000     24.76474    35.34727
#              mvhh |   .2954259   .1035516     2.85   0.004     .0924685    .4983833
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   3561.961   20.97501   169.82   0.000     3520.851    3603.072
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.233787   .1371465    16.29   0.000     1.964984    2.502589
#             _cons |   25.40839   .2928966    86.75   0.000     24.83432    25.98246
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   8.177211   .7733292    10.57   0.000     6.661514    9.692909
#             _cons |   138.9721   1.655266    83.96   0.000     135.7279    142.2164
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   4714.301   692.3998                      3535.082     6286.88
#        var(M2[id])|   5148.468   700.1707                      3943.829    6721.063
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|   2677.414   530.5334     5.05   0.000     1637.588    3717.241
# ------------------+----------------------------------------------------------------
#        var(e.rsos)|   3590.312   326.1818                      3004.692    4290.069
#        var(e.tsos)|   2192.981   204.1504                      1827.234    2631.937
#       var(e.griph)|   30.07711   2.063273                      26.29325    34.40552
#      var(e.ptisoh)|    945.455   65.63444                      825.1817    1083.259
# -----------------------------------------------------------------------------------
# > (rsos <-  griph  matu  ntxh M1[id]) ///
# > (tsos <-  ptisoh matu  mvhh M2[id]) ///
# > (griph <-   matu   M3[id]) ///
# > (ptisoh <-  matu   M4[id]) , from(b, skip)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -8195.7669
# Iteration 1:   log likelihood = -8195.7669
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -8075.9706
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -8075.9706  (not concave)
# Iteration 1:   log likelihood =  -7976.026  (not concave)
# Iteration 2:   log likelihood = -7924.2726
# Iteration 3:   log likelihood = -7904.2813
# Iteration 4:   log likelihood = -7898.5104
# Iteration 5:   log likelihood = -7898.3854
# Iteration 6:   log likelihood =  -7898.385
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsos                           Number of obs     =        412
# Family         : Gaussian
# Link           : identity
#
# Response       : tsos                           Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Response       : griph                          Number of obs     =        425
# Family         : Gaussian
# Link           : identity
#
# Response       : ptisoh                         Number of obs     =        415
# Family         : Gaussian
# Link           : identity
#
# Log likelihood =  -7898.385
#
#  ( 1)  [rsos]M1[id] = 1
#  ( 2)  [tsos]M2[id] = 1
#  ( 3)  [griph]M3[id] = 1
#  ( 4)  [ptisoh]M4[id] = 1
# -----------------------------------------------------------------------------------
#                   |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ------------------+----------------------------------------------------------------
# rsos <-           |
#             griph |   2.889889   1.100557     2.63   0.009     .7328357    5.046941
#              matu |    13.6233   3.939695     3.46   0.001     5.901641    21.34496
#              ntxh |  -.0662278   .0151232    -4.38   0.000    -.0958687   -.0365869
#                   |
#            M1[id] |          1  (constrained)
#                   |
#             _cons |   3793.467    30.1682   125.74   0.000     3734.338    3852.595
# ------------------+----------------------------------------------------------------
# tsos <-           |
#            ptisoh |   .7025891   .1486042     4.73   0.000     .4113303    .9938479
#              matu |   31.47136   2.812834    11.19   0.000     25.95831    36.98441
#              mvhh |   .3003054   .1034424     2.90   0.004      .097562    .5030488
#                   |
#            M2[id] |          1  (constrained)
#                   |
#             _cons |   3587.441    24.2613   147.87   0.000      3539.89    3634.992
# ------------------+----------------------------------------------------------------
# griph <-          |
#              matu |   2.557807   .1465894    17.45   0.000     2.270497    2.845117
#                   |
#            M3[id] |          1  (constrained)
#                   |
#             _cons |   25.73714   .3916958    65.71   0.000     24.96943    26.50485
# ------------------+----------------------------------------------------------------
# ptisoh <-         |
#              matu |   9.482365   .8283059    11.45   0.000     7.858915    11.10581
#                   |
#            M4[id] |          1  (constrained)
#                   |
#             _cons |   140.3422   2.183601    64.27   0.000     136.0625     144.622
# ------------------+----------------------------------------------------------------
#        var(M1[id])|   4453.393   658.5339                      3332.897    5950.593
#        var(M2[id])|   5307.669    728.254                      4056.134     6945.37
#        var(M3[id])|   18.40951   2.572804                      13.99856    24.21035
#        var(M4[id])|   531.9446   84.37633                      389.8073    725.9101
# ------------------+----------------------------------------------------------------
# cov(M2[id],M1[id])|    2659.33   524.8852     5.07   0.000     1630.574    3688.086
# cov(M3[id],M1[id])|  -14.11686   38.56423    -0.37   0.714    -89.70137    61.46764
# cov(M4[id],M1[id])|   588.5029    180.905     3.25   0.001     233.9357    943.0701
# cov(M3[id],M2[id])|   20.15348   31.29987     0.64   0.520    -41.19315    81.50011
# cov(M4[id],M2[id])|    666.191   209.8873     3.17   0.002     254.8195    1077.562
# cov(M4[id],M3[id])|   60.47643   11.12888     5.43   0.000     38.66423    82.28864
# ------------------+----------------------------------------------------------------
#        var(e.rsos)|   3418.209   311.2725                      2859.471    4086.125
#        var(e.tsos)|    2199.29   205.1449                      1831.826    2640.466
#       var(e.griph)|   11.65735   1.042754                      9.782717    13.89121
#      var(e.ptisoh)|   438.3095   41.37477                      364.2761    527.3891
# -----------------------------------------------------------------------------------

# %%
# %%stata -d dm -gr
#
# histogram ptisoh
# Out:
# (bin=20, start=32.647167, width=15.559481)
#         <iframe
#             width="700"
#             height="400"
#             src="./temp_graph.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
