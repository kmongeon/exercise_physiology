# %%
import os
import sys
import shutil
import pandas
import numpy
import ipystata
import matplotlib.pyplot as plt

from ipystata.config import config_stata
config_stata('/home/kmongeon/research/stata14/stata-mp',force_batch=True)

from ipystata.config import config_syntax_higlight    
config_syntax_higlight(True)  

pandas.options.display.max_columns = 100

from IPython.display import display, HTML, Image

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pandas.options.display.float_format = '{:.2f}'.format
# Out:
# IPyStata is loaded in batch mode.

# %%
pwd
# Out:
# '/home/kmongeon/research/exercise_physiology/scripts'

# %%
try: 
    shutil.rmtree('out')
    os.mkdir('out')
except:
    pass

# %%
# %%stata --output dm
#
# import delimited ./data/IzzyLongitudinalWorkingMarch2015.csv,  case(lower) clear
# order id session sequence
# sort id sequence
# save ./out/di, replace
#
# import delimited ./data/torque.csv, case(lower) clear
# drop if session==0
# drop sequence
# rename new_sequence sequence
# order id session sequence
# sort id  sequence
# foreach var in ptiso pt60 pt240 {
# replace `var' = . if `var'==-9999
# }
# save ./out/dt, replace
#
# ** Identify potentially data with errors
# * Nota: July  2016
# import delimited ./data/NegativeIDs.csv, case(lower) clear
# keep nota id sequence
# keep if nota==1
# save ./out/db1, replace
#
# * Baraket: Nov 2016
# import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# keep falk id sequence
# keep if falk==1
# save ./out/db2, replace
#
# ** additional ptiso data
# import delimited ./data/Spring_2013_knee_extension.csv, case(lower) clear
# save ./out/dk, replace
#
# * merge
# use ./out/di, clear
# sort id sequence
# merge 1:1 id sequence using ./out/dt,  nogen
# merge 1:1 id sequence using ./out/db1, nogen
# merge 1:1 id sequence using ./out/db2, nogen
# merge 1:1 id sequence using ./out/dk
# drop if _merge==2
# drop _merge
# count
#
# save ./out/dm, replace
# Out:
# (70 vars, 427 obs)
# (note: file ./out/di.dta not found)
# file ./out/di.dta saved
# (14 vars, 421 obs)
# (40 observations deleted)(65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (note: file ./out/dt.dta not found)
# file ./out/dt.dta saved
# . * Nota: July  2016(32 vars, 109 obs)
# (59 observations deleted)
# (note: file ./out/db1.dta not found)
# file ./out/db1.dta saved
# . import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# (34 vars, 473 obs)
# (460 observations deleted)
# (note: file ./out/db2.dta not found)
# file ./out/db2.dta saved
# . import delimited ./data/Spring_2013_knee_extension.csv, case(lower) clear
# (4 vars, 50 obs)
# (note: file ./out/dk.dta not found)
# file ./out/dk.dta saved
# . use ./out/di, clear
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                            58
#         from master                        52
#         from using                          6
#
#     matched                               375
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           383
#         from master                       383
#         from using                          0
#
#     matched                                50
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           420
#         from master                       420
#         from using                          0
#
#     matched                                13
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           385
#         from master                       384  (_merge==1)
#         from using                          1  (_merge==2)
#
#     matched                                49  (_merge==3)
#     -----------------------------------------
# (1 observation deleted)
#   433
# (note: file ./out/dm.dta not found)
# file ./out/dm.dta saved

# %%
# %%stata --output dm
#
# use ./out/dm
#
# rename radius_sos rsos
# rename tibial_sos tsos
#
# rename grip_strength_best grip
# rename mat_offset_new matu
#
# rename godin_pa godin
# rename ntxcreat ntxc
# rename caloricintake cint
# renam calcium calc
# rename vitd vitd
# rename v48 vitd2
# rename paq_total_score paq
# rename totmvh mvh
#
# rename forearm_length flength
# rename thigh_length   tlength
#
# global U id session sequence
# global Y rsos tsos
# global X grip ptiso pt60 godin paq ntxc cint calc vitd vitd2 mvh
# global Z matu age gender
# global D nota falk
#
# drop if matu>5
# drop if id==517 & sequence==7
#
# sort id sequence
# by id: egen seq = seq()
#
# global U id session sequence seq
#
# order $U $D $Y $X $Z
#
# sort id sequence
#
# gen boy = 1 if gender==0
# gen girl = 1 if gender==1
#
# replace grip = . if nota==1
# replace rsos = . if nota==1
# *replace tsos = . if falk==1
# *replace ptiso = . if falk==1
#
# keep id sequence session seq   ///
#     nota falk rsos tsos grip ptiso ntx mvh godin paq cint matu gender
# *********************************************************************************
# sum *
# Out:
#   (all newnames==oldnames)
# (7 observations deleted)
# (1 observation deleted)
# . global U id session sequence seq
# (199 missing values generated)
# (226 missing values generated)
# (50 real changes made, 50 to missing)
# (50 real changes made, 50 to missing)
# . *replace ptiso = . if falk==1>     nota falk rsos tsos grip ptiso ntx mvh godin paq cint matu gender
# . sum *
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#           id |        425    326.1976    197.5498        100        583
#      session |        425    1.430588    .4957421          1          2
#     sequence |        425    4.197647    1.833518          1          7
#          seq |        425    1.868235    .8776861          1          4
#         nota |         50           1           0          1          1
# -------------+---------------------------------------------------------
#         falk |         11           1           0          1          1
#         rsos |        365    3819.567    99.26529       3542       4140
#         tsos |        415     3687.08    109.0384       3367       4015
#         grip |        329     23.4583    7.499687          9         53
#        ptiso |        310    124.0413    53.31131   32.64717   343.8368
# -------------+---------------------------------------------------------
#        godin |        422    72.60664    39.68333          0        234
#          paq |        425    3.144819     .662686       1.25     4.6104
#         cint |        422    1598.185    482.2157    469.496   3624.724
#          mvh |        307    106.1805    41.70522      13.57        235
#         matu |        425   -.8935765    1.942006       -5.3       4.95
# -------------+---------------------------------------------------------
#       gender |        425    .4682353    .4995781          0          1
#          ntx |        386    6018.579    4157.419     69.575    24694.7

# %%
dm['rsoss'] = (dm['rsos'] - dm['rsos'].mean()) / dm['rsos'].std()
dm['tsoss'] = (dm['tsos'] - dm['tsos'].mean()) / dm['tsos'].std()
dm['grips'] = (dm['grip'] - dm['grip'].mean()) / dm['grip'].std()
dm['torqs'] = (dm['ptiso'] - dm['ptiso'].mean()) / dm['ptiso'].std()

dm['ntxs'] = (dm['ntx'] - dm['ntx'].mean()) / dm['ntx'].std()
dm['mvhs'] = (dm['mvh'] - dm['mvh'].mean()) / dm['mvh'].std()
dm['gods'] = (dm['godin'] - dm['godin'].mean()) / dm['godin'].std()
dm['paqs'] = (dm['paq'] - dm['paq'].mean()) / dm['paq'].std()

dm['cints'] = (dm['cint'] - dm['cint'].mean()) / dm['cint'].std()
dm['matus'] = (dm['matu'] - dm['matu'].mean()) / dm['matu'].std()

dm.head(2)
# Out:
#     id  session  sequence  seq  nota  falk    rsos    tsos  grip  ptiso  \
# 0  100        1         1    1   nan   nan 3828.00 3601.00   nan 113.93
# 1  100        1         3    2   nan   nan 3898.00 3629.00 27.00 136.02
#
#    godin  paq    cint    mvh  matu  gender     ntx  rsoss  tsoss  grips  \
# 0  37.00 2.59 1572.00 105.71 -1.67       0 1443.05   0.08  -0.79    nan
# 1  48.00 3.17 2219.01  93.62 -0.71       0 3738.62   0.79  -0.53   0.47
#
#    torqs  ntxs  mvhs  gods  paqs  cints  matus
# 0  -0.19 -1.10 -0.01 -0.90 -0.84  -0.05  -0.40
# 1   0.22 -0.55 -0.30 -0.62  0.03   1.29   0.09

# %%
dm['gender'].value_counts()
# Out:
# 0    226
# 1    199
# Name: gender, dtype: int64

# %% [markdown]
# # Table 1. Summary statatisitcs

# %%
ds = dm.groupby('sequence')['rsos', 'tsos', 'grip', 'ptiso', 'ntx', 'matu', 'mvh', 'cint'].agg(['count','mean','std']).rename(columns={'count':'N', 'rsos': 'radial', 'tsos': 'tibial', 'grip': 'grip strength', 'ptiso': 'torque', 'ntx': 'Ntx/creatine', 'matu': 'maturity offset', 'mvh': 'mvh', 'cint': 'caloric intake'})
ds.to_csv('./out/t1.csv')
ds
# Out:
#          radial               tibial                grip strength             \
#               N    mean   std      N    mean    std             N  mean  std
# sequence
# 1            44 3800.25 92.54     44 3641.68 112.28             0   nan  nan
# 2            25 3735.68 90.99     35 3653.37  92.76            28 18.88 4.56
# 3            62 3787.92 87.98     77 3659.39  98.78            64 20.39 5.84
# 4            62 3822.73 95.99     67 3680.94  97.28            65 22.67 6.89
# 5            57 3817.28 90.99     71 3683.92 108.66            59 25.01 7.41
# 6            70 3858.73 98.75     72 3725.81 103.32            70 24.81 8.04
# 7            45 3866.29 93.92     49 3751.51 114.83            43 27.88 8.04
#
#          torque              Ntx/creatine                 maturity offset  \
#               N   mean   std            N    mean     std               N
# sequence
# 1            40 110.18 36.57           42 7527.43 4640.81              44
# 2            24  82.16 22.92           35 6202.38 3870.35              38
# 3            68 115.37 52.99           76 5650.88 3629.47              77
# 4            49 127.84 54.41           61 6004.85 4174.06              71
# 5            65 137.75 53.85           69 5867.24 3926.38              71
# 6            64 140.80 58.05           69 5881.87 4739.04              74
# 7             0    nan   nan           34 5396.64 4007.94              50
#
#                     mvh              caloric intake
#           mean  std   N   mean   std              N    mean    std
# sequence
# 1        -1.82 1.16  35 119.14 37.14             42 1553.59 531.33
# 2        -1.93 1.77  32 109.35 45.91             38 1460.20 413.63
# 3        -1.34 1.58  66 121.53 38.44             77 1627.92 473.41
# 4        -1.00 2.17  61  90.05 37.14             71 1555.37 457.41
# 5        -0.49 1.74  48 101.25 40.73             71 1623.32 480.45
# 6        -0.49 2.23  40 112.63 42.79             74 1566.04 480.86
# 7         0.38 1.66  25  81.98 39.09             49 1770.87 514.11

# %% [markdown]
# Obtain estimation sample

# %%
# %%stata --data dm --output de --noprint
# set processors 28
#
# xtset id seq
#
# quietly: gsem ///
#     (grips matus ntxs  -> rsoss, ) ///
#     (torqs matus ntxs mvhs -> tsoss, ) ///
#     (cints matus -> grips ,) ///
#     (cints matus -> torqs ,)
#
# gen sall = 1 if e(sample)==1
# by id: egen aseq = seq() if sall==1
# tab sall
#
# quietly: gsem (grips matus ntxs  -> rsoss, )
# gen srsos = 1 if e(sample)==1
# by id: egen rseq = seq() if srsos==1
#
# tab srsos
#
# quietly: gsem (torqs matus ntxs mvhs -> tsoss, )
# gen stsos = 1 if e(sample)==1
# by id: egen tseq = seq() if stsos==1
#
# tab srsos
#
# quietly: gsem (cints matus -> grips ,)
# gen sgrip = 1 if e(sample)==1
# by id: egen gseq = seq() if sgrip==1
# tab sgrip
#
# quietly: gsem (cints matus -> torqs ,)
# gen storq = 1 if e(sample)==1
# by id: egen qseq = seq() if storq==1
# tab storq
#
# order id session sequence seq aseq rseq tseq gseq qseq

# %%
# %%stata --data de
# set processors 28
#
# sum sequence seq aseq rseq tseq gseq qseq
# Out:
#     The maximum number of processors or cores being used is changed from 32 to
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#     sequence |        425    4.197647    1.833518          1          7
#          seq |        425    1.868235    .8776861          1          4
#         aseq |        405     1.82716    .8587079          1          4
#         rseq |        286    1.562937    .6605875          1          3
#         tseq |        220    1.495455    .6374731          1          3
# -------------+---------------------------------------------------------
#         gseq |        329    1.656535    .7245445          1          3
#         qseq |        309    1.621359    .7041137          1          3

# %%
d1 = de.groupby('rseq')['rsos'].agg(['count','mean','std']).rename(columns={'count':'n'})
dt = de.groupby(['gender', 'rseq'])['rsos'].agg(['count','mean','std']).rename(columns={'count':'n'})
d1 = d1.append(dt)

d2 = de.groupby('tseq')['tsos'].agg(['count','mean','std']).rename(columns={'count':'n'})
dt = de.groupby(['gender', 'tseq'])['tsos'].agg(['count','mean','std']).rename(columns={'count':'n'})
d2 = d2.append(dt)

d3 = de.groupby('gseq')['grip'].agg(['count','mean','std']).rename(columns={'count':'n'})
dt = de.groupby(['gender', 'gseq'])['grip'].agg(['count','mean','std']).rename(columns={'count':'n'})
d3 = d3.append(dt)

d4 = de.groupby('qseq')['qseq'].agg(['count','mean','std']).rename(columns={'count':'n'})
dt = de.groupby(['gender', 'gseq'])['qseq'].agg(['count','mean','std']).rename(columns={'count':'n'})
d4 = d4.append(dt)

da = pandas.merge(d1, d2, right_index=True, left_index=True, suffixes=('_radial', '_tibial'))
db = pandas.merge(d3, d4, right_index=True, left_index=True, suffixes=('_grip', '_torque'))
d0 = pandas.merge(da, db, right_index=True, left_index=True)

d0.index.name = 'measurement occassion'

# %% [markdown]
# # Table 2. Summary data by participant measurement-occasion

# %%
d0
# Out:
#                        n_radial  mean_radial  std_radial  n_tibial  \
# measurement occassion
# 1.0                         152      3792.14       92.25       128
# 2.0                         107      3843.69       89.86        75
# 3.0                          27      3876.04       98.62        17
# (0, 1.0)                     75      3783.87       93.35        61
# (0, 2.0)                     51      3825.78       82.98        32
# (0, 3.0)                     13      3875.77      104.88         8
# (1, 1.0)                     77      3800.19       91.04        67
# (1, 2.0)                     56      3860.00       93.47        43
# (1, 3.0)                     14      3876.29       96.42         9
#
#                        mean_tibial  std_tibial  n_grip  mean_grip  std_grip  \
# measurement occassion
# 1.0                        3645.57       99.08     162      21.27      6.60
# 2.0                        3680.57      108.03     118      24.58      7.18
# 3.0                        3690.35       92.25      49      27.97      8.51
# (0, 1.0)                   3643.87       91.95      84      22.38      7.35
# (0, 2.0)                   3668.44      112.68      59      25.82      8.52
# (0, 3.0)                   3651.62       80.10      23      30.87     10.73
# (1, 1.0)                   3647.12      105.83      78      20.08      5.49
# (1, 2.0)                   3689.60      104.86      59      23.35      5.32
# (1, 3.0)                   3724.78       92.59      26      25.40      4.80
#
#                        n_torque  mean_torque  std_torque
# measurement occassion
# 1.0                         157         1.00        0.00
# 2.0                         112         2.00        0.00
# 3.0                          40         3.00        0.00
# (0, 1.0)                     58         1.33        0.51
# (0, 2.0)                     42         2.12        0.63
# (0, 3.0)                     11         2.36        0.67
# (1, 1.0)                     66         1.29        0.46
# (1, 2.0)                     49         2.27        0.53
# (1, 3.0)                      7         2.14        1.07

# %% [markdown]
# Percent changes: all participants

# %%
((d0.iloc[2]['mean_radial']/d0.iloc[0]['mean_radial']-1)*100).round(2)
((d0.iloc[2]['mean_tibial']/d0.iloc[6]['mean_tibial']-1)*100).round(2)
((d0.iloc[2]['mean_grip']/d0.iloc[0]['mean_grip']-1)*100).round(2)
((d0.iloc[2]['mean_torque']/d0.iloc[0]['mean_torque']-1)*100).round(2)
# Out:
# 2.21
# 1.1899999999999999
# 31.48
# 200.0

# %% [markdown]
# Percent changes: boys

# %%
((d0.iloc[5]['mean_radial']/d0.iloc[3]['mean_radial']-1)*100).round(2)
((d0.iloc[5]['mean_tibial']/d0.iloc[3]['mean_tibial']-1)*100).round(2)
((d0.iloc[5]['mean_grip']/d0.iloc[3]['mean_grip']-1)*100).round(2)
((d0.iloc[5]['mean_torque']/d0.iloc[3]['mean_torque']-1)*100).round(2)
# Out:
# 2.4300000000000002
# 0.20999999999999999
# 37.950000000000003
# 78.040000000000006

# %% [markdown]
# Percent change: girls

# %%
((d0.iloc[8]['mean_radial']/d0.iloc[6]['mean_radial']-1)*100).round(2)
((d0.iloc[8]['mean_tibial']/d0.iloc[6]['mean_tibial']-1)*100).round(2)
((d0.iloc[8]['mean_grip']/d0.iloc[6]['mean_grip']-1)*100).round(2)
((d0.iloc[8]['mean_torque']/d0.iloc[6]['mean_torque']-1)*100).round(2)
# Out:
# 2.0
# 2.1299999999999999
# 26.489999999999998
# 66.390000000000001

# %% [markdown]
# endogenity test

# %%
# %%stata --data de
# set processors 28
#
# xtset id sequence
#
# gsem (rsoss  <- grips ntxs matus X[id]) (ntxs <- X[id]@1)
#
# gsem (rsoss  <- grips ntxs matus X[id]) (ntxs <- X[id]@1) ///
# , var( X[id]@1)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -897.50787
# Iteration 1:   log likelihood = -897.50787
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -915.94612
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -915.94612  (not concave)
# Iteration 1:   log likelihood = -897.40438  (not concave)
# Iteration 2:   log likelihood = -886.25649  (not concave)
# Iteration 3:   log likelihood = -867.85404
# Iteration 4:   log likelihood = -856.72278
# Iteration 5:   log likelihood = -852.91807
# Iteration 6:   log likelihood = -848.97431
# Iteration 7:   log likelihood = -848.01941
# Iteration 8:   log likelihood = -846.60071  (not concave)
# Iteration 9:   log likelihood = -846.50575
# Iteration 10:  log likelihood = -846.22232
# Iteration 11:  log likelihood = -845.43351  (not concave)
# Iteration 12:  log likelihood = -845.32703  (not concave)
# Iteration 13:  log likelihood = -845.30626
# Iteration 14:  log likelihood =  -845.2568
# Iteration 15:  log likelihood = -845.09177  (not concave)
# Iteration 16:  log likelihood = -845.06705
# Iteration 17:  log likelihood =  -845.0556
# Iteration 18:  log likelihood = -845.02424  (not concave)
# Iteration 19:  log likelihood = -845.02282
# Iteration 20:  log likelihood = -845.01379
# Iteration 21:  log likelihood = -845.00306
# Iteration 22:  log likelihood = -844.98818
# Iteration 23:  log likelihood = -844.98576
# Iteration 24:  log likelihood = -844.98281
# Iteration 25:  log likelihood = -844.97901
# Iteration 26:  log likelihood =  -844.9785
# Iteration 27:  log likelihood = -844.97759
# Iteration 28:  log likelihood = -844.97746
# Iteration 29:  log likelihood = -844.97743
#
# Generalized structural equation model           Number of obs     =        386
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Response       : ntxs                           Number of obs     =        386
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -844.97743
#
#  ( 1)  [ntxs]X[id] = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsoss <-     |
#         ntxs |   -.058216   .0507526    -1.15   0.251    -.1576892    .0412572
#        grips |   .4123817   .0723929     5.70   0.000     .2704943    .5542692
#        matus |   .3781923   .0736845     5.13   0.000     .2337732    .5226113
#              |
#        X[id] |  -18.23118   35.06748    -0.52   0.603    -86.96217    50.49981
#              |
#        _cons |  -.0130595   .0674086    -0.19   0.846     -.145178    .1190589
# -------------+----------------------------------------------------------------
# ntxs <-      |
#        X[id] |          1  (constrained)
#              |
#        _cons |   .0011898   .0509384     0.02   0.981    -.0986477    .1010273
# -------------+----------------------------------------------------------------
#    var(X[id])|   .0017497   .0067363                      9.24e-07    3.311917
# -------------+----------------------------------------------------------------
#  var(e.rsoss)|   .1637392   .0217537                      .1262017    .2124417
#   var(e.ntxs)|   .9957054   .0718735                      .8643472    1.147027
# ------------------------------------------------------------------------------
# > , var( X[id]@1)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -897.50787
# Iteration 1:   log likelihood = -897.50787
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -915.94612
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -915.94612  (not concave)
# Iteration 1:   log likelihood = -906.17965  (not concave)
# Iteration 2:   log likelihood = -906.05374  (not concave)
# Iteration 3:   log likelihood = -905.51816  (not concave)
# Iteration 4:   log likelihood = -905.27801  (not concave)
# Iteration 5:   log likelihood = -904.86953  (not concave)
# Iteration 6:   log likelihood = -904.41948  (not concave)
# Iteration 7:   log likelihood = -903.06515
# Iteration 8:   log likelihood = -899.82135
# Iteration 9:   log likelihood =   -899.308
# Iteration 10:  log likelihood =  -899.2586
# Iteration 11:  log likelihood = -899.25857
#
# Generalized structural equation model           Number of obs     =        386
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Response       : ntxs                           Number of obs     =        386
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -899.25857
#
#  ( 1)  [ntxs]X[id] = 1
#  ( 2)  [var(X[id])]_cons = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsoss <-     |
#         ntxs |   .1881479   .0524694     3.59   0.000     .0853098    .2909859
#        grips |   .2728595   .0777261     3.51   0.000     .1205192    .4251998
#        matus |   .3671317    .066953     5.48   0.000     .2359062    .4983571
#              |
#        X[id] |  -1.000152   .1124389    -8.90   0.000    -1.220528   -.7797754
#              |
#        _cons |  -.0295555   .0849361    -0.35   0.728    -.1960272    .1369162
# -------------+----------------------------------------------------------------
# ntxs <-      |
#        X[id] |          1  (constrained)
#              |
#        _cons |   .0057232   .0906559     0.06   0.950    -.1719591    .1834055
# -------------+----------------------------------------------------------------
#    var(X[id])|          1  (constrained)
# -------------+----------------------------------------------------------------
#  var(e.rsoss)|   .3006381   .0668363                      .1944506    .4648135
#   var(e.ntxs)|   .8944562   .0978492                      .7218412    1.108349
# ------------------------------------------------------------------------------

# %%
# %%stata --data de
# set processors 28
#
# xtset id sequence
# reg grip ntx
#
# reg torq matu ntx cint
# predict tsos_hat, res
#
# gsem (tsos <- torq matu ntx tsos_hat M[id])
# test tsos_hat
#
# ivregress 2sls tsos  matu ntx mvh (torq = cint matu) , first
# estat endogenous
#
# ivregress 2sls rsoss matus  (ntxs  = grips  cints matus) , first
# estat endogenous
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
#
#       Source |       SS           df       MS      Number of obs   =       294
# -------------+----------------------------------   F(1, 292)       =      2.88
#        Model |  155.423233         1  155.423233   Prob > F        =    0.0907
#     Residual |  15756.4104       292  53.9603094   R-squared       =    0.0098
# -------------+----------------------------------   Adj R-squared   =    0.0064
#        Total |  15911.8336       293  54.3065993   Root MSE        =    7.3458
#
# ------------------------------------------------------------------------------
#         grip |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          ntx |  -.0001823   .0001074    -1.70   0.091    -.0003938    .0000291
#        _cons |   24.02967   .7562326    31.78   0.000     22.54131    25.51802
# ------------------------------------------------------------------------------
#
#       Source |       SS           df       MS      Number of obs   =       293
# -------------+----------------------------------   F(3, 289)       =     83.33
#        Model |  132.903169         3  44.3010565   Prob > F        =    0.0000
#     Residual |  153.639592       289  .531624885   R-squared       =    0.4638
# -------------+----------------------------------   Adj R-squared   =    0.4583
#        Total |  286.542761       292  .981310826   Root MSE        =    .72913
#
# ------------------------------------------------------------------------------
#        torqs |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   .3299636   .0226773    14.55   0.000     .2853301    .3745972
#          ntx |  -3.22e-06   9.94e-06    -0.32   0.746    -.0000228    .0000164
#         cint |   .0004723   .0000944     5.00   0.000     .0002865     .000658
#        _cons |  -.4357943   .1649871    -2.64   0.009     -.760523   -.1110655
# ------------------------------------------------------------------------------
# (132 missing values generated)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -1722.0814
# Iteration 1:   log likelihood = -1722.0814
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1713.6377
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1713.6377  (not concave)
# Iteration 1:   log likelihood = -1674.9435
# Iteration 2:   log likelihood = -1664.3778
# Iteration 3:   log likelihood = -1663.3223
# Iteration 4:   log likelihood =  -1663.159
# Iteration 5:   log likelihood = -1663.1589
#
# Generalized structural equation model           Number of obs     =        290
# Response       : tsos
# Family         : Gaussian
# Link           : identity
# Log likelihood = -1663.1589
#
#  ( 1)  [tsos]M[id] = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# tsos <-      |
#        torqs |   -8.09282   20.43877    -0.40   0.692    -48.15207    31.96642
#         matu |   32.76343   7.896612     4.15   0.000     17.28636    48.24051
#          ntx |  -.0016684   .0009743    -1.71   0.087     -.003578    .0002413
#     tsos_hat |   13.28389   20.73956     0.64   0.522    -27.36491    53.93268
#              |
#        M[id] |          1  (constrained)
#              |
#        _cons |   3714.509   11.50841   322.76   0.000     3691.953    3737.065
# -------------+----------------------------------------------------------------
#    var(M[id])|   6229.149     889.85                      4707.956    8241.856
# -------------+----------------------------------------------------------------
#   var(e.tsos)|   2195.396   263.8473                      1734.658    2778.511
# ------------------------------------------------------------------------------
#
#  ( 1)  [tsos]tsos_hat = 0
#
#            chi2(  1) =    0.41
#          Prob > chi2 =    0.5218
#
# First-stage regressions
# -----------------------
#
#                                                 Number of obs     =        219
#                                                 F(   4,    214)   =      50.12
#                                                 Prob > F          =     0.0000
#                                                 R-squared         =     0.4837
#                                                 Adj R-squared     =     0.4740
#                                                 Root MSE          =     0.6332
#
# ------------------------------------------------------------------------------
#        torqs |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |    .335353   .0317423    10.56   0.000     .2727854    .3979205
#          ntx |  -1.50e-06     .00001    -0.15   0.881    -.0000213    .0000183
#          mvh |   .0016728   .0013709     1.22   0.224    -.0010294    .0043751
#         cint |   .0004321   .0000969     4.46   0.000     .0002411     .000623
#        _cons |  -.6555859   .2231318    -2.94   0.004    -1.095404   -.2157682
# ------------------------------------------------------------------------------
#
#
# Instrumental variables (2SLS) regression          Number of obs   =        219
#                                                   Wald chi2(4)    =      44.52
#                                                   Prob > chi2     =     0.0000
#                                                   R-squared       =     0.1460
#                                                   Root MSE        =     94.143
#
# ------------------------------------------------------------------------------
#         tsos |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        torqs |   38.73359   33.33037     1.16   0.245    -26.59274    104.0599
#         matu |   10.21629    12.3656     0.83   0.409    -14.01985    34.45243
#          ntx |  -.0005382    .001492    -0.36   0.718    -.0034626    .0023861
#          mvh |  -.0607019   .2071197    -0.29   0.769     -.466649    .3452453
#        _cons |   3690.204   22.92001   161.00   0.000     3645.281    3735.126
# ------------------------------------------------------------------------------
# Instrumented:  torqs
# Instruments:   matu ntx mvh cint
#
#   Tests of endogeneity
#   Ho: variables are exogenous
#
#   Durbin (score) chi2(1)          =  .708279  (p = 0.4000)
#   Wu-Hausman F(1,213)             =  .691109  (p = 0.4067)
#
# First-stage regressions
# -----------------------
#
#                                                 Number of obs     =        286
#                                                 F(   3,    282)   =       1.48
#                                                 Prob > F          =     0.2208
#                                                 R-squared         =     0.0155
#                                                 Adj R-squared     =     0.0050
#                                                 Root MSE          =     0.9366
#
# ------------------------------------------------------------------------------
#         ntxs |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        matus |  -.0638523   .0706404    -0.90   0.367    -.2029017    .0751971
#        grips |  -.0655213   .0766061    -0.86   0.393    -.2163136    .0852711
#        cints |   .0215068   .0597256     0.36   0.719    -.0960578    .1390714
#        _cons |  -.0744767   .0558568    -1.33   0.183    -.1844258    .0354725
# ------------------------------------------------------------------------------
#
#
# Instrumental variables (2SLS) regression          Number of obs   =        286
#                                                   Wald chi2(2)    =      18.03
#                                                   Prob > chi2     =     0.0001
#                                                   R-squared       =          .
#                                                   Root MSE        =     1.9659
#
# ------------------------------------------------------------------------------
#        rsoss |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         ntxs |  -2.047273   2.417099    -0.85   0.397      -6.7847    2.690153
#        matus |   .2564422   .2714626     0.94   0.345    -.2756147    .7884992
#        _cons |  -.1634939    .202582    -0.81   0.420    -.5605474    .2335596
# ------------------------------------------------------------------------------
# Instrumented:  ntxs
# Instruments:   matus grips cints
#
#   Tests of endogeneity
#   Ho: variables are exogenous
#
#   Durbin (score) chi2(1)          =  3.50126  (p = 0.0613)
#   Wu-Hausman F(1,282)             =  3.49508  (p = 0.0626)
# .

# %% [markdown]
# Breusch–Pagan Lagrange multiplier test

# %%
# %%stata --data dm
# set processors 28
#
# xtset id
#
# xtreg rsoss grips matus ntxs, re
# estimates store rsoss_re
# xttest0
#
# xtreg tsoss torqs matus ntxs, re
# estimates store tsoss_re
# xttest0
#
# ***fixed
# xtreg rsoss grips matus ntxs, fe
# estimates store rsoss_fe
#
# xtreg tsoss torqs matus ntxs, fe
# estimates store tsoss_fe
#
# hausman rsoss_fe rsoss_re, sigmamore
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#
# Random-effects GLS regression                   Number of obs     =        286
# Group variable: id                              Number of groups  =        152
#
# R-sq:                                           Obs per group:
#      within  = 0.6688                                         min =          1
#      between = 0.2178                                         avg =        1.9
#      overall = 0.2664                                         max =          3
#
#                                                 Wald chi2(3)      =     235.77
# corr(u_i, X)   = 0 (assumed)                    Prob > chi2       =     0.0000
#
# ------------------------------------------------------------------------------
#        rsoss |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        grips |   .4083869   .0685637     5.96   0.000     .2740046    .5427693
#        matus |    .376113   .0737113     5.10   0.000     .2316415    .5205845
#         ntxs |   -.074546   .0417271    -1.79   0.074    -.1563296    .0072375
#        _cons |  -.0106752   .0670967    -0.16   0.874    -.1421823     .120832
# -------------+----------------------------------------------------------------
#      sigma_u |  .70466052
#      sigma_e |  .38240189
#          rho |   .7725011   (fraction of variance due to u_i)
# ------------------------------------------------------------------------------
#
# Breusch and Pagan Lagrangian multiplier test for random effects
#
#         rsoss[id,t] = Xb + u[id] + e[id,t]
#
#         Estimated results:
#                          |       Var     sd = sqrt(Var)
#                 ---------+-----------------------------
#                    rsoss |   .9459474       .9725983
#                        e |   .1462312       .3824019
#                        u |   .4965464       .7046605
#
#         Test:   Var(u) = 0
#                              chibar2(01) =    66.89
#                           Prob > chibar2 =   0.0000
#
# Random-effects GLS regression                   Number of obs     =        291
# Group variable: id                              Number of groups  =        150
#
# R-sq:                                           Obs per group:
#      within  = 0.3721                                         min =          1
#      between = 0.2067                                         avg =        1.9
#      overall = 0.2207                                         max =          3
#
#                                                 Wald chi2(3)      =     110.84
# corr(u_i, X)   = 0 (assumed)                    Prob > chi2       =     0.0000
#
# ------------------------------------------------------------------------------
#        tsoss |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        torqs |   .0409251   .0659046     0.62   0.535    -.0882455    .1700956
#        matus |   .5152352   .0704385     7.31   0.000     .3771784    .6532921
#         ntxs |  -.0577468   .0386877    -1.49   0.136    -.1335733    .0180797
#        _cons |  -.1118253    .065361    -1.71   0.087    -.2399305    .0162798
# -------------+----------------------------------------------------------------
#      sigma_u |  .71305699
#      sigma_e |  .44850026
#          rho |  .71652804   (fraction of variance due to u_i)
# ------------------------------------------------------------------------------
#
# Breusch and Pagan Lagrangian multiplier test for random effects
#
#         tsoss[id,t] = Xb + u[id] + e[id,t]
#
#         Estimated results:
#                          |       Var     sd = sqrt(Var)
#                 ---------+-----------------------------
#                    tsoss |   .9257265       .9621468
#                        e |   .2011525       .4485003
#                        u |   .5084503        .713057
#
#         Test:   Var(u) = 0
#                              chibar2(01) =    95.12
#                           Prob > chibar2 =   0.0000
# . xtreg rsoss grips matus ntxs, fe
#
# Fixed-effects (within) regression               Number of obs     =        286
# Group variable: id                              Number of groups  =        152
#
# R-sq:                                           Obs per group:
#      within  = 0.6761                                         min =          1
#      between = 0.2120                                         avg =        1.9
#      overall = 0.2592                                         max =          3
#
#                                                 F(3,131)          =      91.15
# corr(u_i, Xb)  = -0.5436                        Prob > F          =     0.0000
#
# ------------------------------------------------------------------------------
#        rsoss |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        grips |   .5702454   .1034752     5.51   0.000     .3655469     .774944
#        matus |   .5248826   .1326175     3.96   0.000     .2625337    .7872316
#         ntxs |  -.0221135    .045876    -0.48   0.631    -.1128672    .0686402
#        _cons |   .0084195   .0257167     0.33   0.744    -.0424543    .0592934
# -------------+----------------------------------------------------------------
#      sigma_u |  .95395922
#      sigma_e |  .38240189
#          rho |   .8615588   (fraction of variance due to u_i)
# ------------------------------------------------------------------------------
# F test that all u_i=0: F(151, 131) = 7.92                    Prob > F = 0.0000
#
# Fixed-effects (within) regression               Number of obs     =        291
# Group variable: id                              Number of groups  =        150
#
# R-sq:                                           Obs per group:
#      within  = 0.3742                                         min =          1
#      between = 0.2050                                         avg =        1.9
#      overall = 0.2186                                         max =          3
#
#                                                 F(3,138)          =      27.51
# corr(u_i, Xb)  = -0.2947                        Prob > F          =     0.0000
#
# ------------------------------------------------------------------------------
#        tsoss |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        torqs |   .0126516   .0976702     0.13   0.897     -.180472    .2057752
#        matus |   .7022955   .1110751     6.32   0.000     .4826663    .9219248
#         ntxs |  -.0504142   .0441971    -1.14   0.256    -.1378054    .0369769
#        _cons |  -.0902419   .0263629    -3.42   0.001    -.1423694   -.0381143
# -------------+----------------------------------------------------------------
#      sigma_u |   .8359155
#      sigma_e |  .44850026
#          rho |  .77647419   (fraction of variance due to u_i)
# ------------------------------------------------------------------------------
# F test that all u_i=0: F(149, 138) = 6.05                    Prob > F = 0.0000
#
#                  ---- Coefficients ----
#              |      (b)          (B)            (b-B)     sqrt(diag(V_b-V_B))
#              |    rsoss_fe     rsoss_re      Difference          S.E.
# -------------+----------------------------------------------------------------
#        grips |    .5702454     .4083869        .1618585         .087747
#        matus |    .5248826      .376113        .1487697        .1222114
#         ntxs |   -.0221135     -.074546        .0524325        .0263879
# ------------------------------------------------------------------------------
#                            b = consistent under Ho and Ha; obtained from xtreg
#             B = inconsistent under Ha, efficient under Ho; obtained from xtreg
#
#     Test:  Ho:  difference in coefficients not systematic
#
#                   chi2(3) = (b-B)'[(V_b-V_B)^(-1)](b-B)
#                           =       40.50
#                 Prob>chi2 =      0.0000

# %% [markdown]
# # Results
#  * Kevin to describe model with equations.

# %% [markdown]
#  Unconstrained specification (not in manuscript)

# %%
# %%stata --data dm
# set processors 28
#
# xtset id sequence
#
# gsem ///
#     (M1[id] grips matus ntxs  -> rsoss, ) ///
#     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
#     (M2[id] cints matus -> grips ,) ///
#     (M2[id] cints matus -> torqs ,) ///
#     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id] grips matus ntxs  -> rsoss, ) ///
# >     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
# >     (M2[id] cints matus -> grips ,) ///
# >     (M2[id] cints matus -> torqs ,) ///
# >     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -1327.4497  (not concave)
# Iteration 1:   log likelihood = -1275.5679
# Iteration 2:   log likelihood = -1255.0658
# Iteration 3:   log likelihood = -1254.2172
# Iteration 4:   log likelihood = -1254.2075
# Iteration 5:   log likelihood = -1254.2075
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1315.4744
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1315.4744  (not concave)
# Iteration 1:   log likelihood = -1262.1271  (not concave)
# Iteration 2:   log likelihood = -1237.7932  (not concave)
# Iteration 3:   log likelihood = -1217.2927  (not concave)
# Iteration 4:   log likelihood = -1192.0185  (not concave)
# Iteration 5:   log likelihood =  -1162.919  (not concave)
# Iteration 6:   log likelihood = -1138.3935  (not concave)
# Iteration 7:   log likelihood = -1113.9861  (not concave)
# Iteration 8:   log likelihood = -1098.7826
# Iteration 9:   log likelihood = -1097.9963
# Iteration 10:  log likelihood = -1086.1211
# Iteration 11:  log likelihood = -1083.2335
# Iteration 12:  log likelihood =  -1082.939
# Iteration 13:  log likelihood = -1082.9349
# Iteration 14:  log likelihood = -1082.9347
# Iteration 15:  log likelihood = -1082.9347
# Iteration 16:  log likelihood = -1082.9347
#
# Generalized structural equation model           Number of obs     =        405
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        219
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        329
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        309
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1082.9347
#
#  ( 1)  [rsoss]M1[id] = 1
#  ( 2)  [grips]M2[id] = 1
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .2891121   .0964823     3.00   0.003     .1000104    .4782139
#               matus |   .4040187   .0839417     4.81   0.000      .239496    .5685413
#                ntxs |  -.1178327   .0415646    -2.83   0.005    -.1992978   -.0363677
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |   -.037107   .0604734    -0.61   0.539    -.1556327    .0814186
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .2504414   .0974982     2.57   0.010     .0593485    .4415342
#               matus |   .4351382   .1146523     3.80   0.000     .2104237    .6598526
#                ntxs |   -.016154   .0446676    -0.36   0.718    -.1037009    .0713929
#                mvhs |   .0780712   .0595463     1.31   0.190    -.0386373    .1947797
#                     |
#              M1[id] |    1.04729   .1519541     6.89   0.000     .7494652    1.345114
#                     |
#               _cons |  -.1823437   .0687681    -2.65   0.008    -.3171267   -.0475607
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0418211   .0308962     1.35   0.176    -.0187344    .1023766
#               matus |   .7780504   .0469994    16.55   0.000     .6859333    .8701675
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |  -.0532904   .0542345    -0.98   0.326    -.1595881    .0530073
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0836478   .0347576     2.41   0.016     .0155242    .1517715
#               matus |   .8144562   .0446504    18.24   0.000     .7269429    .9019694
#                     |
#              M2[id] |   .9182559   .0823109    11.16   0.000     .7569295    1.079582
#                     |
#               _cons |   .0561121   .0530437     1.06   0.290    -.0478516    .1600759
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .4248758   .0863137                      .2853251    .6326797
#          var(M2[id])|   .4141105   .0623599                      .3082732    .5562841
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0428693   .0575538    -0.74   0.456    -.1556727    .0699341
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .2525912    .049718                      .1717412    .3715025
#         var(e.tsoss)|   .2829657   .0632486                      .1825883    .4385252
#         var(e.grips)|   .1532619   .0223762                      .1151222    .2040373
#         var(e.torqs)|   .2194162   .0290542                      .1692607    .2844338
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.0996008   .0279211    -3.57   0.000    -.1543253   -.0448764
# cov(e.torqs,e.grips)|  -.0395337   .0153717    -2.57   0.010    -.0696616   -.0094058
# -------------------------------------------------------------------------------------
#
# ----------------------------
#                       (1)
#                     rsoss
# ----------------------------
# rsoss
# grips               0.289**
#                    (3.00)
#
# matus               0.404***
#                    (4.81)
#
# ntxs               -0.118**
#                   (-2.83)
#
# M1[id]                  1
#                       (.)
#
# _cons             -0.0371
#                   (-0.61)
# ----------------------------
# tsoss
# torqs               0.250*
#                    (2.57)
#
# matus               0.435***
#                    (3.80)
#
# ntxs              -0.0162
#                   (-0.36)
#
# mvhs               0.0781
#                    (1.31)
#
# M1[id]              1.047***
#                    (6.89)
#
# _cons              -0.182**
#                   (-2.65)
# ----------------------------
# grips
# cints              0.0418
#                    (1.35)
#
# matus               0.778***
#                   (16.55)
#
# M2[id]                  1
#                       (.)
#
# _cons             -0.0533
#                   (-0.98)
# ----------------------------
# torqs
# cints              0.0836*
#                    (2.41)
#
# matus               0.814***
#                   (18.24)
#
# M2[id]              0.918***
#                   (11.16)
#
# _cons              0.0561
#                    (1.06)
# ----------------------------
# var(M1[id])
# _cons               0.425***
#                    (4.92)
# ----------------------------
# var(M2[id])
# _cons               0.414***
#                    (6.64)
# ----------------------------
# cov(M2[id]~)
# _cons             -0.0429
#                   (-0.74)
# ----------------------------
# var(e.rsoss)
# _cons               0.253***
#                    (5.08)
# ----------------------------
# var(e.tsoss)
# _cons               0.283***
#                    (4.47)
# ----------------------------
# var(e.grips)
# _cons               0.153***
#                    (6.85)
# ----------------------------
# var(e.torqs)
# _cons               0.219***
#                    (7.55)
# ----------------------------
# cov(e.tsos~)
# _cons             -0.0996***
#                   (-3.57)
# ----------------------------
# cov(e.torq~)
# _cons             -0.0395*
#                   (-2.57)
# ----------------------------
# N                     405
# ----------------------------
# t statistics in parentheses
# * p<0.05, ** p<0.01, *** p<0.001

# %% [markdown]
# # Table 3. Impact of muscle strength on bone properties
#
#  * results also presented in Figure 2

# %%
# %%stata --data dm
# set processors 28
#
# xtset id sequence
#
# gsem ///
#     (M1[id]@1 grips@a matus@b ntxs@c gender@g -> rsoss, ) ///
#     (M1[id]@1 torqs@a matus@b ntxs@c mvhs gender@g -> tsoss, ) ///
#     (M2[id]@1 cints@n matus@m gender@k -> grips  ,) ///
#     (M2[id]@1 cints@n matus@m gender@k -> torqs ,) ///
#     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
#     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id]@1 grips@a matus@b ntxs@c gender@g -> rsoss, ) ///
# >     (M1[id]@1 torqs@a matus@b ntxs@c mvhs gender@g -> tsoss, ) ///
# >     (M2[id]@1 cints@n matus@m gender@k -> grips  ,) ///
# >     (M2[id]@1 cints@n matus@m gender@k -> torqs ,) ///
# >     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
# >     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -1211.8512
# Iteration 1:   log likelihood = -1181.0201
# Iteration 2:   log likelihood = -1165.6036
# Iteration 3:   log likelihood = -1164.1734
# Iteration 4:   log likelihood = -1164.1721
# Iteration 5:   log likelihood = -1164.1721
#
# Refining starting values:
#
# Grid node 0:   log likelihood =  -1223.904
#
# Fitting full model:
#
# Iteration 0:   log likelihood =  -1223.904  (not concave)
# Iteration 1:   log likelihood = -1174.6514  (not concave)
# Iteration 2:   log likelihood = -1148.9331  (not concave)
# Iteration 3:   log likelihood =  -1129.856  (not concave)
# Iteration 4:   log likelihood = -1078.0727  (not concave)
# Iteration 5:   log likelihood = -1043.0426
# Iteration 6:   log likelihood = -1030.5184
# Iteration 7:   log likelihood = -1028.3264
# Iteration 8:   log likelihood = -1028.2744
# Iteration 9:   log likelihood = -1028.2743
#
# Generalized structural equation model           Number of obs     =        405
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        219
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        329
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        309
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1028.2743
#
#  ( 1)  [rsoss]grips - [tsoss]torqs = 0
#  ( 2)  [rsoss]matus - [tsoss]matus = 0
#  ( 3)  [rsoss]ntxs - [tsoss]ntxs = 0
#  ( 4)  [rsoss]gender - [tsoss]gender = 0
#  ( 5)  [rsoss]M1[id] = 1
#  ( 6)  [tsoss]M1[id] = 1
#  ( 7)  [grips]cints - [torqs]cints = 0
#  ( 8)  [grips]matus - [torqs]matus = 0
#  ( 9)  [grips]gender - [torqs]gender = 0
#  (10)  [grips]M2[id] = 1
#  (11)  [torqs]M2[id] = 1
#  (12)  [var(e.rsoss)]_cons - [var(e.tsoss)]_cons = 0
#  (13)  [var(e.grips)]_cons - [var(e.torqs)]_cons = 0
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .2471322   .0690878     3.58   0.000     .1117226    .3825418
#               matus |     .45634   .0802649     5.69   0.000     .2990237    .6136563
#                ntxs |  -.0714543   .0319574    -2.24   0.025    -.1340896   -.0088191
#              gender |  -.0717611   .1400201    -0.51   0.608    -.3461955    .2026732
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.0004576   .0889215    -0.01   0.996    -.1747405    .1738252
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .2471322   .0690878     3.58   0.000     .1117226    .3825418
#               matus |     .45634   .0802649     5.69   0.000     .2990237    .6136563
#                ntxs |  -.0714543   .0319574    -2.24   0.025    -.1340896   -.0088191
#                mvhs |   .0767118   .0474498     1.62   0.106    -.0162882    .1697117
#              gender |  -.0717611   .1400201    -0.51   0.608    -.3461955    .2026732
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |   -.135374   .0978041    -1.38   0.166    -.3270666    .0563185
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0361857   .0234405     1.54   0.123     -.009757    .0821283
#               matus |   .8614517   .0319912    26.93   0.000     .7987502    .9241533
#              gender |   -.980892   .0795743   -12.33   0.000    -1.136855   -.8249293
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |   .3962455   .0549095     7.22   0.000     .2886248    .5038663
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0361857   .0234405     1.54   0.123     -.009757    .0821283
#               matus |   .8614517   .0319912    26.93   0.000     .7987502    .9241533
#              gender |   -.980892   .0795743   -12.33   0.000    -1.136855   -.8249293
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |   .5093381   .0562894     9.05   0.000     .3990128    .6196634
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .4387376   .0607413                      .3344719    .5755063
#          var(M2[id])|    .184671   .0253411                      .1411218    .2416592
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0335169    .031292    -1.07   0.284     -.094848    .0278142
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .2686255   .0208876                      .2306534    .3128488
#         var(e.tsoss)|   .2686255   .0208876                      .2306534    .3128488
#         var(e.grips)|   .1813858   .0119771                      .1593667    .2064473
#         var(e.torqs)|   .1813858   .0119771                      .1593667    .2064473
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.1009602   .0277551    -3.64   0.000    -.1553591   -.0465612
# cov(e.torqs,e.grips)|  -.0439794   .0138525    -3.17   0.001    -.0711297   -.0168291
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Table 4. Boys and girls specific results

# %% [markdown]
# Boys: unconstrained model  (not in manuscript)

# %%
# %%stata --data dm
# set processors 28
#
# gen boy = (gender==1)
# gen gir = (gender==0)
#
#
#
# xtset id sequence
# gsem ///
#     (M1[id] grips matus ntxs  -> rsoss, ) ///
#     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
#     (M2[id] cints matus -> grips ,) ///
#     (M2[id] cints matus -> torqs ,) ///
#     if boy==1, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to
# .        panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id] grips matus ntxs  -> rsoss, ) ///
# >     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
# >     (M2[id] cints matus -> grips ,) ///
# >     (M2[id] cints matus -> torqs ,) ///
# >     if boy==1, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -527.85039
# Iteration 1:   log likelihood = -518.44552
# Iteration 2:   log likelihood =  -510.1365
# Iteration 3:   log likelihood = -508.91229
# Iteration 4:   log likelihood =  -508.9038
# Iteration 5:   log likelihood =  -508.9038
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -554.07142
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -554.07142  (not concave)
# Iteration 1:   log likelihood = -507.12832  (not concave)
# Iteration 2:   log likelihood = -495.70146  (not concave)
# Iteration 3:   log likelihood = -476.85712  (not concave)
# Iteration 4:   log likelihood = -454.63452  (not concave)
# Iteration 5:   log likelihood = -443.98957
# Iteration 6:   log likelihood = -439.07993
# Iteration 7:   log likelihood =  -436.4178
# Iteration 8:   log likelihood = -435.31251
# Iteration 9:   log likelihood =  -435.2022
# Iteration 10:  log likelihood = -435.19835
# Iteration 11:  log likelihood = -435.19832
#
# Generalized structural equation model           Number of obs     =        191
#
# Response       : rsoss                          Number of obs     =        147
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        118
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        163
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        150
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -435.19832
#
#  ( 1)  [rsoss]M1[id] = 1
#  ( 2)  [grips]M2[id] = 1
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .1238847   .1609709     0.77   0.442    -.1916125     .439382
#               matus |   .7760062   .1437587     5.40   0.000     .4942444    1.057768
#                ntxs |  -.0400516   .0499086    -0.80   0.422    -.1378706    .0577674
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.2533397   .1335391    -1.90   0.058    -.5150715     .008392
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .1711121   .1307335     1.31   0.191    -.0851208    .4273451
#               matus |   .6523915     .14574     4.48   0.000     .3667463    .9380366
#                ntxs |   .0001079   .0575018     0.00   0.999    -.1125935    .1128094
#                mvhs |  -.0011128    .084008    -0.01   0.989    -.1657655    .1635399
#                     |
#              M1[id] |   .8594572   .1804169     4.76   0.000     .5058466    1.213068
#                     |
#               _cons |  -.2912331   .1051939    -2.77   0.006    -.4974094   -.0850568
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |  -.0168721   .0292909    -0.58   0.565    -.0742813    .0405371
#               matus |   .8438448   .0467078    18.07   0.000     .7522992    .9353904
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |  -.6180682   .0557284   -11.09   0.000    -.7272938   -.5088425
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0932423    .048083     1.94   0.052    -.0009987    .1874833
#               matus |   .7351272   .0502219    14.64   0.000     .6366941    .8335603
#                     |
#              M2[id] |   .2690423   .1393935     1.93   0.054     -.004164    .5422485
#                     |
#               _cons |  -.3605797   .0492898    -7.32   0.000    -.4571859   -.2639735
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .5017884    .124918                      .3080476    .8173789
#          var(M2[id])|   .1603042   .0327474                      .1074135    .2392384
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0094766   .0468149    -0.20   0.840    -.1012321    .0822789
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .1645193   .0499913                      .0906919    .2984457
#         var(e.tsoss)|   .3160909   .0822848                      .1897698     .526498
#         var(e.grips)|   .0574225   .0091528                      .0420151    .0784799
#         var(e.torqs)|   .2418527   .0291319                      .1909946    .3062532
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.0812179   .0389797    -2.08   0.037    -.1576168   -.0048191
# cov(e.torqs,e.grips)|   .0260401   .0176922     1.47   0.141    -.0086361    .0607163
# -------------------------------------------------------------------------------------
# .

# %% [markdown]
# Girls: unconstrained model (not in manuscript)

# %%
# %%stata --data dm
# set processors 28
#
# gen boy = (gender==1)
# gen gir = (gender==0)
#
# xtset id sequence
# gsem ///
#     (M1[id] grips matus ntxs  -> rsoss, ) ///
#     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
#     (M2[id] cints matus -> grips ,) ///
#     (M2[id] cints matus -> torqs ,) ///
#     if boy==0, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to
# .        panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id] grips matus ntxs  -> rsoss, ) ///
# >     (M1[id] torqs matus ntxs mvhs  -> tsoss, ) ///
# >     (M2[id] cints matus -> grips ,) ///
# >     (M2[id] cints matus -> torqs ,) ///
# >     if boy==0, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -629.82957
# Iteration 1:   log likelihood = -615.43395
# Iteration 2:   log likelihood = -610.21977
# Iteration 3:   log likelihood = -609.78413
# Iteration 4:   log likelihood = -609.78354
# Iteration 5:   log likelihood = -609.78354
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -644.03039
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -644.03039  (not concave)
# Iteration 1:   log likelihood = -640.90369  (not concave)
# Iteration 2:   log likelihood = -618.75264  (not concave)
# Iteration 3:   log likelihood = -611.34899  (not concave)
# Iteration 4:   log likelihood = -597.72582  (not concave)
# Iteration 5:   log likelihood = -588.97112  (not concave)
# Iteration 6:   log likelihood = -577.22861  (not concave)
# Iteration 7:   log likelihood = -567.24606  (not concave)
# Iteration 8:   log likelihood = -557.82914  (not concave)
# Iteration 9:   log likelihood = -554.91411  (not concave)
# Iteration 10:  log likelihood = -554.36284  (not concave)
# Iteration 11:  log likelihood = -554.07981  (not concave)
# Iteration 12:  log likelihood = -553.56233  (not concave)
# Iteration 13:  log likelihood = -553.19786  (not concave)
# Iteration 14:  log likelihood = -552.69309  (not concave)
# Iteration 15:  log likelihood = -551.69619  (not concave)
# Iteration 16:  log likelihood = -548.55095  (not concave)
# Iteration 17:  log likelihood = -545.11555
# Iteration 18:  log likelihood = -541.89459
# Iteration 19:  log likelihood =  -540.6846
# Iteration 20:  log likelihood = -538.32214
# Iteration 21:  log likelihood =  -538.0119
# Iteration 22:  log likelihood = -537.96473
# Iteration 23:  log likelihood = -537.95377
# Iteration 24:  log likelihood = -537.95362
# Iteration 25:  log likelihood =  -537.9536
#
# Generalized structural equation model           Number of obs     =        214
#
# Response       : rsoss                          Number of obs     =        139
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        101
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        166
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        159
# Family         : Gaussian
# Link           : identity
#
# Log likelihood =  -537.9536
#
#  ( 1)  [rsoss]M1[id] = 1
#  ( 2)  [grips]M2[id] = 1
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .3517738   .1153371     3.05   0.002     .1257172    .5778305
#               matus |   .1524489   .1226699     1.24   0.214    -.0879797    .3928775
#                ntxs |  -.1968173   .0646103    -3.05   0.002    -.3234512   -.0701833
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.1383216   .1001098    -1.38   0.167    -.3345331    .0578899
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .2347269   .1436699     1.63   0.102    -.0468609    .5163146
#               matus |   .3264019   .1776202     1.84   0.066    -.0217274    .6745312
#                ntxs |    .002482   .0663441     0.04   0.970      -.12755    .1325139
#                mvhs |   .1588089   .0798949     1.99   0.047     .0022178       .3154
#                     |
#              M1[id] |   1.342667    .259231     5.18   0.000     .8345836     1.85075
#                     |
#               _cons |  -.2363135    .128645    -1.84   0.066    -.4884531     .015826
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0348289   .0446625     0.78   0.435    -.0527079    .1223658
#               matus |   .9140658   .0531067    17.21   0.000     .8099785    1.018153
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |   .4607281   .0635319     7.25   0.000     .3362079    .5852482
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0644673   .0454907     1.42   0.156    -.0246928    .1536274
#               matus |   .9510544    .065138    14.60   0.000     .8233862    1.078723
#                     |
#              M2[id] |   1.341071   .2381565     5.63   0.000     .8742925    1.807849
#                     |
#               _cons |   .4973668   .0773536     6.43   0.000     .3457566     .648977
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .3179317   .1053008                      .1661158    .6084946
#          var(M2[id])|   .1852641   .0513303                      .1076347     .318882
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0129834   .0395069    -0.33   0.742    -.0904155    .0644488
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .3473516    .077497                      .2243154    .5378726
#         var(e.tsoss)|   .1862915   .0628109                      .0962051    .3607347
#         var(e.grips)|   .2259143   .0381532                      .1622518    .3145558
#         var(e.torqs)|   .1851328   .0387297                      .1228606     .278968
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.1135628   .0488769    -2.32   0.020    -.2093598   -.0177658
# cov(e.torqs,e.grips)|  -.0630054   .0250647    -2.51   0.012    -.1121313   -.0138795
# -------------------------------------------------------------------------------------
# .

# %% [markdown]
# Boys: constrained model (Table 4)

# %%
# %%stata --data dm
# set processors 28
#
# gen boy = (gender==1)
# gen gir = (gender==0)
#
# xtset id sequence
#
# gsem ///
#     (M1[id]@1 grips@a matus@b ntxs@c -> rsoss, ) ///
#     (M1[id]@1 torqs@a matus@b ntxs@c mvhs  -> tsoss, ) ///
#     (M2[id]@1 cints@n matus@m  -> grips  ,) ///
#     (M2[id]@1 cints@n matus@m  -> torqs ,) ///
#     if boy==1, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
#     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id]@1 grips@a matus@b ntxs@c -> rsoss, ) ///
# >     (M1[id]@1 torqs@a matus@b ntxs@c mvhs  -> tsoss, ) ///
# >     (M2[id]@1 cints@n matus@m  -> grips  ,) ///
# >     (M2[id]@1 cints@n matus@m  -> torqs ,) ///
# >     if boy==1, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
# >     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -530.85849
# Iteration 1:   log likelihood =  -519.4208
# Iteration 2:   log likelihood = -513.28611
# Iteration 3:   log likelihood = -512.43216
# Iteration 4:   log likelihood = -512.42942
# Iteration 5:   log likelihood = -512.42942
#
# Refining starting values:
#
# Grid node 0:   log likelihood =  -560.8887
#
# Fitting full model:
#
# Iteration 0:   log likelihood =  -560.8887  (not concave)
# Iteration 1:   log likelihood = -536.77875  (not concave)
# Iteration 2:   log likelihood = -525.40608  (not concave)
# Iteration 3:   log likelihood = -507.77788  (not concave)
# Iteration 4:   log likelihood = -483.43034  (not concave)
# Iteration 5:   log likelihood = -462.06191
# Iteration 6:   log likelihood =  -454.5661
# Iteration 7:   log likelihood = -453.34692
# Iteration 8:   log likelihood = -453.33396
# Iteration 9:   log likelihood = -453.33396
#
# Generalized structural equation model           Number of obs     =        191
#
# Response       : rsoss                          Number of obs     =        147
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        118
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        163
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        150
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -453.33396
#
#  ( 1)  [rsoss]grips - [tsoss]torqs = 0
#  ( 2)  [rsoss]matus - [tsoss]matus = 0
#  ( 3)  [rsoss]ntxs - [tsoss]ntxs = 0
#  ( 4)  [rsoss]M1[id] = 1
#  ( 5)  [tsoss]M1[id] = 1
#  ( 6)  [grips]cints - [torqs]cints = 0
#  ( 7)  [grips]matus - [torqs]matus = 0
#  ( 8)  [grips]M2[id] = 1
#  ( 9)  [torqs]M2[id] = 1
#  (10)  [var(e.rsoss)]_cons - [var(e.tsoss)]_cons = 0
#  (11)  [var(e.grips)]_cons - [var(e.torqs)]_cons = 0
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .1473422   .0983778     1.50   0.134    -.0454748    .3401592
#               matus |   .6987133   .1069324     6.53   0.000     .4891296     .908297
#                ntxs |  -.0230604   .0398586    -0.58   0.563    -.1011818     .055061
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.2065496    .110531    -1.87   0.062    -.4231864    .0100872
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .1473422   .0983778     1.50   0.134    -.0454748    .3401592
#               matus |   .6987133   .1069324     6.53   0.000     .4891296     .908297
#                ntxs |  -.0230604   .0398586    -0.58   0.563    -.1011818     .055061
#                mvhs |   .0363211   .0637647     0.57   0.569    -.0886554    .1612976
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.3023168    .098718    -3.06   0.002    -.4958006    -.108833
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0179353   .0311128     0.58   0.564    -.0430446    .0789153
#               matus |   .7468025   .0408286    18.29   0.000       .66678     .826825
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |  -.5685851   .0516347   -11.01   0.000    -.6697873   -.4673829
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0179353   .0311128     0.58   0.564    -.0430446    .0789153
#               matus |   .7468025   .0408286    18.29   0.000       .66678     .826825
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |  -.3879167   .0503922    -7.70   0.000    -.4866836   -.2891499
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .4230832   .0833969                      .2875011    .6226043
#          var(M2[id])|   .0897562   .0213884                      .0562636    .1431861
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|   -.033654    .032433    -1.04   0.299    -.0972214    .0299135
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .2338739   .0249171                       .189799    .2881837
#         var(e.tsoss)|   .2338739   .0249171                       .189799    .2881837
#         var(e.grips)|   .1461919   .0139619                      .1212356    .1762855
#         var(e.torqs)|   .1461919   .0139619                      .1212356    .1762855
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.0939259   .0312817    -3.00   0.003    -.1552369    -.032615
# cov(e.torqs,e.grips)|  -.0150086   .0149971    -1.00   0.317    -.0444023    .0143851
# -------------------------------------------------------------------------------------

# %% [markdown]
# Girls: constrained model (Table 4)

# %%
# %%stata --data dm
# set processors 28
#
# gen boy = (gender==1)
# gen gir = (gender==0)
#
# xtset id sequence
#
# gsem ///
#     (M1[id]@1 grips@a matus@b ntxs@c -> rsoss, ) ///
#     (M1[id]@1 torqs@a matus@b ntxs@c mvhs  -> tsoss, ) ///
#     (M2[id]@1 cints@n matus@m  -> grips  ,) ///
#     (M2[id]@1 cints@n matus@m  -> torqs ,) ///
#     if boy==0, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
#     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id]@1 grips@a matus@b ntxs@c -> rsoss, ) ///
# >     (M1[id]@1 torqs@a matus@b ntxs@c mvhs  -> tsoss, ) ///
# >     (M2[id]@1 cints@n matus@m  -> grips  ,) ///
# >     (M2[id]@1 cints@n matus@m  -> torqs ,) ///
# >     if boy==0, cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
# >     var(M1[id]@v M2[id]@u e.rsoss@y e.tsoss@y e.grips@z e.torqs@z)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -633.55131
# Iteration 1:   log likelihood = -631.63543
# Iteration 2:   log likelihood = -615.19479
# Iteration 3:   log likelihood = -614.65426
# Iteration 4:   log likelihood = -614.64529
# Iteration 5:   log likelihood = -614.64529
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -640.41422
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -640.41422  (not concave)
# Iteration 1:   log likelihood = -614.00071  (not concave)
# Iteration 2:   log likelihood = -601.13746  (not concave)
# Iteration 3:   log likelihood =  -585.6017  (not concave)
# Iteration 4:   log likelihood = -560.98091  (not concave)
# Iteration 5:   log likelihood = -545.60571
# Iteration 6:   log likelihood = -544.18557
# Iteration 7:   log likelihood = -544.02813
# Iteration 8:   log likelihood =  -544.0273
# Iteration 9:   log likelihood =  -544.0273
#
# Generalized structural equation model           Number of obs     =        214
#
# Response       : rsoss                          Number of obs     =        139
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        101
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        166
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        159
# Family         : Gaussian
# Link           : identity
#
# Log likelihood =  -544.0273
#
#  ( 1)  [rsoss]grips - [tsoss]torqs = 0
#  ( 2)  [rsoss]matus - [tsoss]matus = 0
#  ( 3)  [rsoss]ntxs - [tsoss]ntxs = 0
#  ( 4)  [rsoss]M1[id] = 1
#  ( 5)  [tsoss]M1[id] = 1
#  ( 6)  [grips]cints - [torqs]cints = 0
#  ( 7)  [grips]matus - [torqs]matus = 0
#  ( 8)  [grips]M2[id] = 1
#  ( 9)  [torqs]M2[id] = 1
#  (10)  [var(e.rsoss)]_cons - [var(e.tsoss)]_cons = 0
#  (11)  [var(e.grips)]_cons - [var(e.torqs)]_cons = 0
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |    .394983   .0955744     4.13   0.000     .2076606    .5823053
#               matus |   .1732891   .1180456     1.47   0.142    -.0580762    .4046543
#                ntxs |  -.1041794   .0491092    -2.12   0.034    -.2004317    -.007927
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.1281886   .1026151    -1.25   0.212    -.3293106    .0729334
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |    .394983   .0955744     4.13   0.000     .2076606    .5823053
#               matus |   .1732891   .1180456     1.47   0.142    -.0580762    .4046543
#                ntxs |  -.1041794   .0491092    -2.12   0.034    -.2004317    -.007927
#                mvhs |   .1188645   .0705322     1.69   0.092    -.0193762    .2571051
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |  -.2752524   .1128772    -2.44   0.015    -.4964877   -.0540172
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0487155   .0340361     1.43   0.152    -.0179941     .115425
#               matus |   .9399838   .0469047    20.04   0.000     .8480523    1.031915
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |   .4631351   .0667895     6.93   0.000       .33223    .5940402
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0487155   .0340361     1.43   0.152    -.0179941     .115425
#               matus |   .9399838   .0469047    20.04   0.000     .8480523    1.031915
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |   .4963846   .0690863     7.18   0.000      .360978    .6317913
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .4349329   .0845344                      .2971537    .6365953
#          var(M2[id])|    .249731   .0447438                      .1757779    .3547976
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0375047   .0494751    -0.76   0.448    -.1344742    .0594648
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .2850723   .0325708                      .2278774    .3566225
#         var(e.tsoss)|   .2850723   .0325708                      .2278774    .3566225
#         var(e.grips)|   .2113364   .0195711                      .1762575    .2533966
#         var(e.torqs)|   .2113364   .0195711                      .1762575    .2533966
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.1420527   .0428639    -3.31   0.001    -.2260644   -.0580411
# cov(e.torqs,e.grips)|  -.0728079   .0231538    -3.14   0.002    -.1181885   -.0274273
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Figure 3. Constrained specification results.

# %%
d0 = dm[dm['gender']==0].groupby('seq')['rsos', 'tsos', 'grip', 'ptiso'].mean()
d1 = dm[dm['gender']==1].groupby('seq')['rsos', 'tsos', 'grip', 'ptiso'].mean()

t1 = ds.append(d0)
t1 = t1.append(d1)
#t1.to_csv("./out/t1.csv")
t1

# %%
# %%stata --data dm
# set processors 28
#
# xtset id sequence
#
#
# gsem ///
#     (M1[id] grips matus ntxs  -> rsoss, ) ///
#     (M1[id] torqs matus ntxs mvhs -> tsoss, ) ///
#     (M2[id] cints matus -> grips  ,) ///
#     (M2[id] cints matus -> torqs ,) ///
#     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
#
# matrix b = e(b)
#
# gsem ///
#     (M1[id] grips matus ntxs  -> rsoss, ) ///
#     (M1[id] torqs matus ntxs mvhs -> tsoss, ) ///
#     (M2[id] cints matus -> grips  ,) ///
#     (M2[id] cints matus -> torqs ,) ///
#     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
#     var(M1[id]@x Md[id]@x)
#
# gsem ///
#     (M1[id]  grips@a matus@b ntxs@c  -> rsoss, ) ///
#     (M1[id]  torqs@a matus@b ntxs@c mvhs -> tsoss, ) ///
#     (M2[id] cints@n matus@m -> grips  ,) ///
#     (M2[id] cints@n matus@m -> torqs ,) ///
#     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
# matrix b = e(b)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# >     (M1[id] grips matus ntxs  -> rsoss, ) ///
# >     (M1[id] torqs matus ntxs mvhs -> tsoss, ) ///
# >     (M2[id] cints matus -> grips  ,) ///
# >     (M2[id] cints matus -> torqs ,) ///
# >     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -1327.4497  (not concave)
# Iteration 1:   log likelihood = -1275.5679
# Iteration 2:   log likelihood = -1255.0658
# Iteration 3:   log likelihood = -1254.2172
# Iteration 4:   log likelihood = -1254.2075
# Iteration 5:   log likelihood = -1254.2075
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1315.4744
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1315.4744  (not concave)
# Iteration 1:   log likelihood = -1262.1271  (not concave)
# Iteration 2:   log likelihood = -1237.7932  (not concave)
# Iteration 3:   log likelihood = -1217.2927  (not concave)
# Iteration 4:   log likelihood = -1192.0185  (not concave)
# Iteration 5:   log likelihood =  -1162.919  (not concave)
# Iteration 6:   log likelihood = -1138.3935  (not concave)
# Iteration 7:   log likelihood = -1113.9861  (not concave)
# Iteration 8:   log likelihood = -1098.7826
# Iteration 9:   log likelihood = -1097.9963
# Iteration 10:  log likelihood = -1086.1211
# Iteration 11:  log likelihood = -1083.2335
# Iteration 12:  log likelihood =  -1082.939
# Iteration 13:  log likelihood = -1082.9349
# Iteration 14:  log likelihood = -1082.9347
# Iteration 15:  log likelihood = -1082.9347
# Iteration 16:  log likelihood = -1082.9347
#
# Generalized structural equation model           Number of obs     =        405
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoss                          Number of obs     =        219
# Family         : Gaussian
# Link           : identity
#
# Response       : grips                          Number of obs     =        329
# Family         : Gaussian
# Link           : identity
#
# Response       : torqs                          Number of obs     =        309
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1082.9347
#
#  ( 1)  [rsoss]M1[id] = 1
#  ( 2)  [grips]M2[id] = 1
# -------------------------------------------------------------------------------------
#                     |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# --------------------+----------------------------------------------------------------
# rsoss <-            |
#               grips |   .2891121   .0964823     3.00   0.003     .1000104    .4782139
#               matus |   .4040187   .0839417     4.81   0.000      .239496    .5685413
#                ntxs |  -.1178327   .0415646    -2.83   0.005    -.1992978   -.0363677
#                     |
#              M1[id] |          1  (constrained)
#                     |
#               _cons |   -.037107   .0604734    -0.61   0.539    -.1556327    .0814186
# --------------------+----------------------------------------------------------------
# tsoss <-            |
#               torqs |   .2504414   .0974982     2.57   0.010     .0593485    .4415342
#               matus |   .4351382   .1146523     3.80   0.000     .2104237    .6598526
#                ntxs |   -.016154   .0446676    -0.36   0.718    -.1037009    .0713929
#                mvhs |   .0780712   .0595463     1.31   0.190    -.0386373    .1947797
#                     |
#              M1[id] |    1.04729   .1519541     6.89   0.000     .7494652    1.345114
#                     |
#               _cons |  -.1823437   .0687681    -2.65   0.008    -.3171267   -.0475607
# --------------------+----------------------------------------------------------------
# grips <-            |
#               cints |   .0418211   .0308962     1.35   0.176    -.0187344    .1023766
#               matus |   .7780504   .0469994    16.55   0.000     .6859333    .8701675
#                     |
#              M2[id] |          1  (constrained)
#                     |
#               _cons |  -.0532904   .0542345    -0.98   0.326    -.1595881    .0530073
# --------------------+----------------------------------------------------------------
# torqs <-            |
#               cints |   .0836478   .0347576     2.41   0.016     .0155242    .1517715
#               matus |   .8144562   .0446504    18.24   0.000     .7269429    .9019694
#                     |
#              M2[id] |   .9182559   .0823109    11.16   0.000     .7569295    1.079582
#                     |
#               _cons |   .0561121   .0530437     1.06   0.290    -.0478516    .1600759
# --------------------+----------------------------------------------------------------
#          var(M1[id])|   .4248758   .0863137                      .2853251    .6326797
#          var(M2[id])|   .4141105   .0623599                      .3082732    .5562841
# --------------------+----------------------------------------------------------------
#   cov(M2[id],M1[id])|  -.0428693   .0575538    -0.74   0.456    -.1556727    .0699341
# --------------------+----------------------------------------------------------------
#         var(e.rsoss)|   .2525912    .049718                      .1717412    .3715025
#         var(e.tsoss)|   .2829657   .0632486                      .1825883    .4385252
#         var(e.grips)|   .1532619   .0223762                      .1151222    .2040373
#         var(e.torqs)|   .2194162   .0290542                      .1692607    .2844338
# --------------------+----------------------------------------------------------------
# cov(e.tsoss,e.rsoss)|  -.0996008   .0279211    -3.57   0.000    -.1543253   -.0448764
# cov(e.torqs,e.grips)|  -.0395337   .0153717    -2.57   0.010    -.0696616   -.0094058
# -------------------------------------------------------------------------------------
# . matrix b = e(b)
# >     (M1[id] grips matus ntxs  -> rsoss, ) ///
# >     (M1[id] torqs matus ntxs mvhs -> tsoss, ) ///
# >     (M2[id] cints matus -> grips  ,) ///
# >     (M2[id] cints matus -> torqs ,) ///
# >     , cov(e.rsoss*e.tsoss) cov(e.grips*e.torqs) ///
# >     var(M1[id]@x Md[id]@x)
# latent variable Md not found;
# 'Md[id]' specifies a latent variable at level '[id]'.
# For 'Md[id]' to be a valid latent variable specification, 'Md' must appear in the latent() option.
# r(111);
#
# end of do-file
#
# r(111);

# %%
# %%stata --data dm
# set processors 28
#
# xtset id sequence
# gsem ///
# ( X[id]@1 -> ntxs) ///
# (X[id] ntxs grips matus -> rsoss) ///
# , var(X[id]@1)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  sequence, 1 to 7, but with gaps
#                 delta:  1 unit
# > ( X[id]@1 -> ntxs) ///
# > (X[id] ntxs grips matus -> rsoss) ///
# > , var(X[id]@1)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -897.50787
# Iteration 1:   log likelihood = -897.50787
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -915.94612
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -915.94612  (not concave)
# Iteration 1:   log likelihood = -906.17965  (not concave)
# Iteration 2:   log likelihood = -906.05374  (not concave)
# Iteration 3:   log likelihood = -905.51816  (not concave)
# Iteration 4:   log likelihood = -905.27801  (not concave)
# Iteration 5:   log likelihood = -904.86953  (not concave)
# Iteration 6:   log likelihood = -904.41948  (not concave)
# Iteration 7:   log likelihood = -903.06515
# Iteration 8:   log likelihood = -899.82135
# Iteration 9:   log likelihood =   -899.308
# Iteration 10:  log likelihood =  -899.2586
# Iteration 11:  log likelihood = -899.25857
#
# Generalized structural equation model           Number of obs     =        386
#
# Response       : ntxs                           Number of obs     =        386
# Family         : Gaussian
# Link           : identity
#
# Response       : rsoss                          Number of obs     =        286
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -899.25857
#
#  ( 1)  [ntxs]X[id] = 1
#  ( 2)  [var(X[id])]_cons = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# ntxs <-      |
#        X[id] |          1  (constrained)
#              |
#        _cons |   .0057232   .0906559     0.06   0.950    -.1719591    .1834055
# -------------+----------------------------------------------------------------
# rsoss <-     |
#         ntxs |   .1881479   .0524694     3.59   0.000     .0853098    .2909859
#        grips |   .2728595   .0777261     3.51   0.000     .1205192    .4251998
#        matus |   .3671317    .066953     5.48   0.000     .2359062    .4983571
#              |
#        X[id] |  -1.000152   .1124389    -8.90   0.000    -1.220528   -.7797754
#              |
#        _cons |  -.0295555   .0849361    -0.35   0.728    -.1960272    .1369162
# -------------+----------------------------------------------------------------
#    var(X[id])|          1  (constrained)
# -------------+----------------------------------------------------------------
#   var(e.ntxs)|   .8944562   .0978492                      .7218412    1.108349
#  var(e.rsoss)|   .3006381   .0668363                      .1944506    .4648135
# ------------------------------------------------------------------------------

# %%
len(dm.groupby('id'))
len(dm[dm.gender==0].groupby('id'))
len(dm[dm.gender==1].groupby('id'))
# Out:
# 81

# %%
dm.groupby(['session'])['sequence'].value_counts()
# Out:
# session  sequence
# 1        3           75
#          5           70
#          7           43
#          1           39
# 2        6           73
#          4           70
#          2           35
# Name: sequence, dtype: int64
