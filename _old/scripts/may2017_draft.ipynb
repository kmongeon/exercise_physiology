# %%
import os
import sys
import shutil
import pandas
import numpy
import ipystata
import matplotlib.pyplot as plt

from ipystata.config import config_stata
config_stata('/home/kmongeon/research/stata14/stata-mp',force_batch=True)

from ipystata.config import config_syntax_higlight    
config_syntax_higlight(True)  

pandas.options.display.max_columns = 100

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pandas.options.display.float_format = '{:.2f}'.format
# Out:
# IPyStata is loaded in batch mode.

# %%
pwd
# Out:
# '/home/kmongeon/research/exercise_physiology/scripts'

# %%
try: 
    shutil.rmtree('out')
    os.mkdir('out')
except:
    pass

# %%
# %%stata --output dm
#
# import delimited ./data/IzzyLongitudinalWorkingMarch2015.csv,  case(lower) clear
# order id session sequence
# sort id sequence
# save ./out/di, replace
#
# import delimited ./data/torque.csv, case(lower) clear
# drop if session==0
# drop sequence
# rename new_sequence sequence
# order id session sequence
# sort id  sequence
# foreach var in ptiso pt60 pt240 {
# replace `var' = . if `var'==-9999
# }
# save ./out/dt, replace
#
# ** Identify potentially data with errors
# * Nota: July  2016
# import delimited ./data/NegativeIDs.csv, case(lower) clear
# keep nota id sequence
# keep if nota==1
# save ./out/db1, replace
#
# * Baraket: Nov 2016
# import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# keep falk id sequence
# keep if falk==1
# save ./out/db2, replace
#
# * merge
# use ./out/di, clear
# sort id sequence
# merge 1:1 id sequence using ./out/dt,  nogen
# merge 1:1 id sequence using ./out/db1, nogen
# merge 1:1 id sequence using ./out/db2, nogen
#
#
# rename radius_sos rsos
# rename tibial_sos tsos
#
# rename grip_strength_best grip
# rename mat_offset_new matu
#
# rename godin_pa godin
# rename ntxcreat ntxc
# rename caloricintake cint
# renam calcium calc
# rename vitd vitd
# rename v48 vitd2
# rename paq_total_score paq
# rename totmvh mvh
#
# rename forearm_length flength
# rename thigh_length   tlength
#
# global U id session sequence
# global Y rsos tsos
# global X grip ptiso pt60 godin paq ntxc cint calc vitd vitd2 mvh
# global Z matu age gender
# global D nota falk
#
# *keep $U $Y $X $Z $D
#
# ***grip only
#
# *drop if missing(rsos)
# *drop if missing(tsos)
# *drop if missing(grip)
# *drop if missing(ptiso)
# drop if matu>5
# drop if id==517 & sequence==7
#
# sort id sequence
# by id: egen seq = seq()
# global U id session sequence seq
#
# order $U $D $Y $X $Z
# sum *
# xtset id seq
# count
#
# capture drop griph
# reg grip rsos
# predict griph
# replace griph = grip if (!missing(grip) & nota!=1)
#
# reg ptiso matu
#
# capture drop ptisoh
# *replace ptiso =. if ptiso>250
# reg ptiso tsos
# predict ptisoh
# replace ptisoh = ptiso if !missing(ptiso)
#
# capture drop ptisoh2
# reg ptisoh matu
# predict ptisoh2
# replace ptisoh = ptisoh2 if missing(ptisoh)
# drop ptisoh2
#
# capture drop rsosh
# reg rsos griph
# predict rsosh
# replace rsosh = rsos if (!missing(rsos) & nota!=1)
#
# capture drop tsosh
# reg tsos ptisoh
# predict tsosh
# replace tsosh = tsos if (falk!=1 & !missing(tsos))
#
# capture drop flengthh
# reg flength rsosh
# predict flengthh
# replace flengthh = flength if !missing(flength)
#
# capture drop tlengthh
# reg tlength tsosh
# predict tlengthh
# replace tlengthh = tlength if !missing(tlength)
#
#
# capture drop mvhh
# reg mvh ptisoh
# predict mvhh
# replace mvhh = mvh if !missing(mvh)
#
# capture drop sedh
# reg totsedetary ptisoh
# predict sedh
# replace sedh = totsedetary if !missing(mvh)
#
# capture drop ntxch
# reg ntxc rsosh
# predict ntxh
# replace ntxh = ntxc if !missing(ntxc)
#
# capture drop godinh
# reg godin tsosh
# predict godinh
# replace godinh = godin if !missing(godin)
#
# capture drop paqh
# reg paq matu
# predict paqh
# replace paqh = paq if !missing(paq)
#
# capture drop paqprvnth
# reg paqprvnt matu
# predict paqprvnth
# replace paqprvnth = paqprvnt if !missing(paqprvnt)
#
# capture drop calch
# reg calc matu
# predict calch
# replace calch = calc if !missing(calc)
#
# capture drop cinth
# reg cint matu
# predict cinth
# replace cinth = cint if !missing(cint)
#
# capture drop vitdh
# reg vitd matu
# predict vitdh
# replace vitdh = vitd if !missing(vitd)
#
# sort id seq
# by id: egen trips = max(seq)
# order trips, after(seq)
#
# gen boy = 1 if gender==0
# gen girl = 1 if gender==1
# Out:
# (70 vars, 427 obs)
# (note: file ./out/di.dta not found)
# file ./out/di.dta saved
# (14 vars, 421 obs)
# (40 observations deleted)(65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (note: file ./out/dt.dta not found)
# file ./out/dt.dta saved
# . * Nota: July  2016(32 vars, 109 obs)
# (59 observations deleted)
# (note: file ./out/db1.dta not found)
# file ./out/db1.dta saved
# . import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# (34 vars, 473 obs)
# (460 observations deleted)
# (note: file ./out/db2.dta not found)
# file ./out/db2.dta saved
# . use ./out/di, clear
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                            58
#         from master                        52
#         from using                          6
#
#     matched                               375
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           383
#         from master                       383
#         from using                          0
#
#     matched                                50
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           420
#         from master                       420
#         from using                          0
#
#     matched                                13
#     -----------------------------------------
# . rename radius_sos rsos
#   (all newnames==oldnames)
# . ***grip only. *drop if missing(tsos). *drop if missing(ptiso) (7 observations deleted)
# (1 observation deleted)
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#           id |        425    326.1976    197.5498        100        583
#      session |        425    1.430588    .4957421          1          2
#     sequence |        425    4.197647    1.833518          1          7
#          seq |        425    1.868235    .8776861          1          4
#         nota |         50           1           0          1          1
# -------------+---------------------------------------------------------
#         falk |         11           1           0          1          1
#         rsos |        415    3815.552    100.9095       3542       4140
#         tsos |        415     3687.08    109.0384       3367       4015
#         grip |        379    23.43807    7.364498          9         53
#        ptiso |        310    124.0413    53.31131   32.64717   343.8368
# -------------+---------------------------------------------------------
#         pt60 |        310     84.0502    33.34997   28.22489   237.8223
#        godin |        422    72.60664    39.68333          0        234
#          paq |        425    3.144819     .662686       1.25     4.6104
#         ntxc |        385    540.3466     265.355   56.30833   1754.324
#         cint |        422    1598.185    482.2157    469.496   3624.724
# -------------+---------------------------------------------------------
#         calc |        421     976.548    455.6612     51.714   2518.877
#         vitd |        421    4.703625    3.152561          0     21.211
#        vitd2 |        421    189.9815    127.3456          0    848.426
#          mvh |        307    106.1805    41.70522      13.57        235
#         matu |        425   -.8935765    1.942006       -5.3       4.95
# -------------+---------------------------------------------------------
#          age |        425    11.85061    2.003003        7.5      17.55
#       gender |        425    .4682353    .4995781          0          1
#       height |        425    152.3381    13.62715      122.8      187.6
# seatedheight |        425    79.04447     6.47194       62.7       96.8
#    leglength |        425    73.29365    7.584868       56.8         92
# -------------+---------------------------------------------------------
#       weight |        425    46.72212    14.72043       20.5      116.9
# bf_slaughter |        422    19.93012     8.30639       6.63      51.63
#      bia_pbf |        418    19.48469    9.503182          3       51.5
#          bmi |        425    19.75887    3.934393      12.04      37.32
#        lbmkg |        424    36.73215    9.793644      17.72      75.52
# -------------+---------------------------------------------------------
# yearsfroma~v |        425   -.8585882    1.830455      -4.77       4.73
#   age_at_phv |        425    12.70958    1.023705       9.75      15.24
#     bone_age |        424    12.05722    2.358381       6.16      19.24
#       tanner |        422    2.559242     1.45071          1          6
#     menarche |        199     .321608    .4682715          0          1
# -------------+---------------------------------------------------------
# age_first_~d |          0
# period_fre~y |          0
#  medications |        424    .1981132    .3990488          0          1
#     vitamins |        424          .5    .5005907          0          1
#     fracture |        425    .2047059    .4039621          0          1
# -------------+---------------------------------------------------------
#     radius_z |        414    .0851208     .949203       -4.7        2.5
#     tibial_z |        411   -.1329684    1.065141       -3.4        3.3
# wrist_flex~t |        377    11.66377    5.917117       1.79      39.72
#      flength |        341    23.75821    2.445137       18.5         29
# forearm_le~a |        340    31.52493    7.880664     15.258     62.916
# -------------+---------------------------------------------------------
# forearm_us~a |        341    13.36229    4.044909       6.21     29.319
# anterior_csa |        341    11.24566    3.334169      5.949     25.111
# anteriorra~s |        341    33.67557    4.587365         25      49.44
#  ant_rad_csa |        341    9.071408    2.575626       4.91       19.2
# anteriorulna |        342    16.33942    3.223975       9.07      27.44
# -------------+---------------------------------------------------------
# ant_ulna_csa |        342    2.177719    .8973823        .65       5.91
#    posterior |        342    16.22637    3.031222       9.62      40.66
#     post_csa |        342    2.140117    .9450404        .73      12.98
# tibialisan~r |        139    22.47863    3.294312      15.47      35.11
#          ntx |        386    6018.579    4157.419     69.575    24694.7
# -------------+---------------------------------------------------------
#   creatinine |        386    11.31804    5.252412    .608534   35.06646
#     caffeine |        422    7.730109    19.34601          0    178.573
#  totsedetary |        307    69.30417    13.35791      24.07     112.65
#     totlight |        307    170.8188    37.00813      53.18      307.5
#       totmod |        307    86.60974    32.21017      13.29     180.71
# -------------+---------------------------------------------------------
#      tothard |        307    15.42228    9.285675        .29      47.64
#     totvhard |        307    4.148371    4.094438          0      20.43
#    totaltime |        307    758.7447    100.5932     363.23    1099.29
#     paqprvnt |        424    .0966981    .2958954          0          1
# training_d~a |        425    .6823529    .4661101          0          1
# -------------+---------------------------------------------------------
# upperarm_l~h |        425    28.51976     2.98213       22.2       35.5
# arm_circum~e |        425    24.03953    3.813115       17.2       39.6
# arm_lean_csa |        424     34.9635    10.50455   17.68274   87.72049
#      tlength |        425       34.64    3.964619       23.3       49.4
# thigh_circ~e |        422    44.81588    6.395066       27.4       69.8
# -------------+---------------------------------------------------------
# thigh_lean~a |        421    118.1382    32.06992   40.00218   291.8873
# bicepsbrac~i |        424    21.61723    4.362678      14.15      38.78
#          v68 |        424    3.819363    1.653379       1.57      11.81
#        quads |        425    34.31661    5.828232       22.8      58.63
#          v70 |        425    9.518941    3.446264       4.08         27
# -------------+---------------------------------------------------------
#    biodex_id |          0
#    visit_one |          0
#    visit_two |          0
#          dob |          0
#      agedays |        374    4263.636    713.8922       2739       6410
# -------------+---------------------------------------------------------
#     ageyears |        374    11.67334    1.954406        7.5      17.55
#        pt240 |        310    48.36097    19.31782   16.62068   137.8996
#        panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 4
#                 delta:  1 unit
#   425
#
#       Source |       SS           df       MS      Number of obs   =       369
# -------------+----------------------------------   F(1, 367)       =     50.86
#        Model |  2453.58783         1  2453.58783   Prob > F        =    0.0000
#     Residual |  17704.1911       367  48.2403028   R-squared       =    0.1217
# -------------+----------------------------------   Adj R-squared   =    0.1193
#        Total |   20157.779       368  54.7765733   Root MSE        =    6.9455
#
# ------------------------------------------------------------------------------
#         grip |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         rsos |   .0253791   .0035586     7.13   0.000     .0183812    .0323769
#        _cons |   -73.3803    13.5873    -5.40   0.000     -100.099   -46.66157
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (329 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       310
# -------------+----------------------------------   F(1, 308)       =    225.64
#        Model |   371332.93         1   371332.93   Prob > F        =    0.0000
#     Residual |  506874.537       308  1645.69655   R-squared       =    0.4228
# -------------+----------------------------------   Adj R-squared   =    0.4210
#        Total |  878207.466       309  2842.09536   Root MSE        =    40.567
#
# ------------------------------------------------------------------------------
#        ptiso |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   18.42263   1.226436    15.02   0.000     16.00938    20.83588
#        _cons |   140.9883   2.565451    54.96   0.000     135.9403    146.0364
# ------------------------------------------------------------------------------
# . reg ptiso tsos
#
#       Source |       SS           df       MS      Number of obs   =       303
# -------------+----------------------------------   F(1, 301)       =     35.74
#        Model |  92527.6306         1  92527.6306   Prob > F        =    0.0000
#     Residual |   779240.58       301  2588.83914   R-squared       =    0.1061
# -------------+----------------------------------   Adj R-squared   =    0.1032
#        Total |  871768.211       302   2886.6497   Root MSE        =    50.881
#
# ------------------------------------------------------------------------------
#        ptiso |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         tsos |   .1673486   .0279923     5.98   0.000     .1122632     .222434
#        _cons |  -491.3157   102.9306    -4.77   0.000    -693.8705   -288.7609
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (10 missing values generated)
# (310 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =    232.21
#        Model |  328717.627         1  328717.627   Prob > F        =    0.0000
#     Residual |  594552.429       420  1415.60102   R-squared       =    0.3560
# -------------+----------------------------------   Adj R-squared   =    0.3545
#        Total |  923270.056       421  2193.04051   Root MSE        =    37.624
#
# ------------------------------------------------------------------------------
#       ptisoh |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   14.35457    .941996    15.24   0.000     12.50295    16.20618
#        _cons |   138.6136   2.013653    68.84   0.000     134.6556    142.5717
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (3 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       415
# -------------+----------------------------------   F(1, 413)       =    105.27
#        Model |   856300.89         1   856300.89   Prob > F        =    0.0000
#     Residual |  3359345.75       413  8134.00907   R-squared       =    0.2031
# -------------+----------------------------------   Adj R-squared   =    0.2012
#        Total |  4215646.64       414  10182.7213   Root MSE        =    90.189
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        griph |   6.755054   .6583669    10.26   0.000     5.460886    8.049222
#        _cons |   3657.597   16.01867   228.33   0.000     3626.109    3689.085
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (365 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       415
# -------------+----------------------------------   F(1, 413)       =     73.06
#        Model |  739861.305         1  739861.305   Prob > F        =    0.0000
#     Residual |  4182335.07       413  10126.7193   R-squared       =    0.1503
# -------------+----------------------------------   Adj R-squared   =    0.1483
#        Total |  4922196.38       414  11889.3632   Root MSE        =    100.63
#
# ------------------------------------------------------------------------------
#         tsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |   .8981923   .1050821     8.55   0.000     .6916299    1.104755
#        _cons |   3574.166   14.10345   253.42   0.000     3546.443     3601.89
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (404 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       341
# -------------+----------------------------------   F(1, 339)       =     35.39
#        Model |  192.147088         1  192.147088   Prob > F        =    0.0000
#     Residual |  1840.60991       339  5.42952775   R-squared       =    0.0945
# -------------+----------------------------------   Adj R-squared   =    0.0919
#        Total |    2032.757       340  5.97869705   Root MSE        =    2.3301
#
# ------------------------------------------------------------------------------
#      flength |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        rsosh |   .0082616   .0013888     5.95   0.000     .0055299    .0109933
#        _cons |  -7.859183   5.316338    -1.48   0.140    -18.31635    2.597981
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (341 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       425
# -------------+----------------------------------   F(1, 423)       =    104.03
#        Model |  1315.46361         1  1315.46361   Prob > F        =    0.0000
#     Residual |  5349.05649       423  12.6455236   R-squared       =    0.1974
# -------------+----------------------------------   Adj R-squared   =    0.1955
#        Total |   6664.5201       424  15.7182078   Root MSE        =    3.5561
#
# ------------------------------------------------------------------------------
#      tlength |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        tsosh |   .0167401   .0016413    10.20   0.000      .013514    .0199662
#        _cons |  -27.07297   6.053156    -4.47   0.000    -38.97099   -15.17496
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (425 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       307
# -------------+----------------------------------   F(1, 305)       =     48.11
#        Model |  72519.0773         1  72519.0773   Prob > F        =    0.0000
#     Residual |  459714.453       305   1507.2605   R-squared       =    0.1363
# -------------+----------------------------------   Adj R-squared   =    0.1334
#        Total |  532233.531       306  1739.32526   Root MSE        =    38.823
#
# ------------------------------------------------------------------------------
#          mvh |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |  -.3581795   .0516379    -6.94   0.000    -.4597911   -.2565678
#        _cons |    148.689   6.516625    22.82   0.000     135.8657    161.5122
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (307 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       307
# -------------+----------------------------------   F(1, 305)       =      7.60
#        Model |  1326.86783         1  1326.86783   Prob > F        =    0.0062
#     Residual |  53273.8541       305  174.668374   R-squared       =    0.0243
# -------------+----------------------------------   Adj R-squared   =    0.0211
#        Total |  54600.7219       306  178.433732   Root MSE        =    13.216
#
# ------------------------------------------------------------------------------
#  totsedetary |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#       ptisoh |  -.0484494   .0175785    -2.76   0.006    -.0830399   -.0138589
#        _cons |   75.05411   2.218379    33.83   0.000     70.68885    79.41938
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (307 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       385
# -------------+----------------------------------   F(1, 383)       =     51.43
#        Model |  3200830.57         1  3200830.57   Prob > F        =    0.0000
#     Residual |  23837863.9       383  62239.8536   R-squared       =    0.1184
# -------------+----------------------------------   Adj R-squared   =    0.1161
#        Total |  27038694.5       384  70413.2669   Root MSE        =    249.48
#
# ------------------------------------------------------------------------------
#         ntxc |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        rsosh |  -1.021348   .1424219    -7.17   0.000    -1.301375   -.7413216
#        _cons |   4437.588   543.5995     8.16   0.000     3368.775    5506.401
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (385 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =      0.01
#        Model |  11.6379811         1  11.6379811   Prob > F        =    0.9316
#     Residual |  662965.063       420  1578.48825   R-squared       =    0.0000
# -------------+----------------------------------   Adj R-squared   =   -0.0024
#        Total |  662976.701       421  1574.76651   Root MSE        =     39.73
#
# ------------------------------------------------------------------------------
#        godin |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        tsosh |   .0015794   .0183942     0.09   0.932    -.0345767    .0377355
#        _cons |   66.78493   67.82797     0.98   0.325    -66.53966    200.1095
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (422 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       425
# -------------+----------------------------------   F(1, 423)       =    101.79
#        Model |     36.1171         1     36.1171   Prob > F        =    0.0000
#     Residual |  150.083669       423  .354807728   R-squared       =    0.1940
# -------------+----------------------------------   Adj R-squared   =    0.1921
#        Total |  186.200769       424  .439152757   Root MSE        =    .59566
#
# ------------------------------------------------------------------------------
#          paq |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |  -.1502876   .0148958   -10.09   0.000    -.1795665   -.1210086
#        _cons |   3.010526   .0318121    94.63   0.000     2.947996    3.073055
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (425 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       424
# -------------+----------------------------------   F(1, 422)       =      7.79
#        Model |  .671208585         1  .671208585   Prob > F        =    0.0055
#     Residual |  36.3641688       422  .086171016   R-squared       =    0.0181
# -------------+----------------------------------   Adj R-squared   =    0.0158
#        Total |  37.0353774       423  .087554084   Root MSE        =    .29355
#
# ------------------------------------------------------------------------------
#     paqprvnt |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   .0204989   .0073448     2.79   0.005     .0060619    .0349359
#        _cons |   .1150789   .0157038     7.33   0.000     .0842116    .1459463
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (424 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       421
# -------------+----------------------------------   F(1, 419)       =      0.00
#        Model |  231.166793         1  231.166793   Prob > F        =    0.9734
#     Residual |  87203144.1       419  208122.062   R-squared       =    0.0000
# -------------+----------------------------------   Adj R-squared   =   -0.0024
#        Total |  87203375.3       420  207627.084   Root MSE        =     456.2
#
# ------------------------------------------------------------------------------
#         calc |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   .3832824   11.50046     0.03   0.973     -22.2225    22.98907
#        _cons |   976.8891   24.47706    39.91   0.000      928.776    1025.002
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (421 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       422
# -------------+----------------------------------   F(1, 420)       =      6.17
#        Model |  1417757.66         1  1417757.66   Prob > F        =    0.0134
#     Residual |  96478213.7       420  229710.033   R-squared       =    0.0145
# -------------+----------------------------------   Adj R-squared   =    0.0121
#        Total |  97895971.3       421  232531.998   Root MSE        =    479.28
#
# ------------------------------------------------------------------------------
#         cint |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |   30.01276   12.08078     2.48   0.013      6.26644    53.75908
#        _cons |   1624.941   25.69685    63.24   0.000     1574.431    1675.451
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (422 real changes made)
#
#       Source |       SS           df       MS      Number of obs   =       421
# -------------+----------------------------------   F(1, 419)       =      0.53
#        Model |  5.23359824         1  5.23359824   Prob > F        =    0.4687
#     Residual |  4168.99612       419  9.94987141   R-squared       =    0.0013
# -------------+----------------------------------   Adj R-squared   =   -0.0011
#        Total |  4174.22972       420  9.93864218   Root MSE        =    3.1543
#
# ------------------------------------------------------------------------------
#         vitd |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#         matu |  -.0576708   .0795179    -0.73   0.469    -.2139745    .0986329
#        _cons |   4.652295   .1692423    27.49   0.000     4.319625    4.984965
# ------------------------------------------------------------------------------
# (option xb assumed; fitted values)
# (421 real changes made)
# (199 missing values generated)
# (226 missing values generated)

# %%
dm['rsoshs'] = (dm['rsosh'] - dm['rsosh'].mean()) / dm['rsosh'].std()
dm['tsoshs'] = (dm['tsosh'] - dm['tsosh'].mean()) / dm['tsosh'].std()
dm['griphs'] = (dm['griph'] - dm['griph'].mean()) / dm['griph'].std()
dm['ptisohs'] = (dm['ptisoh'] - dm['ptisoh'].mean()) / dm['ptisoh'].std()
dm['ntxhs'] = (dm['ntxh'] - dm['ntxh'].mean()) / dm['ntxh'].std()

dm['mvhhs'] = (dm['mvhh'] - dm['mvhh'].mean()) / dm['mvhh'].std()
dm['sedhs'] = (dm['sedh'] - dm['sedh'].mean()) / dm['sedh'].std()

dm['godhs'] = (dm['godinh'] - dm['godinh'].mean()) / dm['godinh'].std()
dm['paqhs'] = (dm['paqh'] - dm['paqh'].mean()) / dm['paqh'].std()

dm['cinths'] = (dm['cinth'] - dm['cinth'].mean()) / dm['cinth'].std()
dm['vitdhs'] = (dm['vitdh'] - dm['vitdh'].mean()) / dm['vitdh'].std()
dm['calchs'] = (dm['calch'] - dm['calch'].mean()) / dm['calch'].std()

dm['flengthhs'] = (dm['flengthh'] - dm['flengthh'].mean()) / dm['flengthh'].std()
dm['tlengthhs'] = (dm['tlengthh'] - dm['tlengthh'].mean()) / dm['tlengthh'].std()

dm['heights'] = (dm['height'] - dm['height'].mean()) / dm['height'].std()
dm['weights'] = (dm['weight'] - dm['weight'].mean()) / dm['weight'].std()

dm['matus'] = (dm['matu'] - dm['matu'].mean()) / dm['matu'].std()
dm['bages'] = (dm['bone_age'] - dm['bone_age'].mean()) / dm['bone_age'].std()

dm['matu2']  = dm['matu']**2
dm['matu3']  = dm['matu']**3
dm['matu4']  = dm['matu']**4

dm['ntxhs_g'] = dm['ntxhs']
dm['ntxhs_t'] = dm['ntxhs']
dm['torqhs'] = dm['ptisohs']
dm['paqp'] = dm['paqprvnth']
dm['paqps'] = (dm['paqp'] - dm['paqp'].mean()) / dm['paqp'].std()
dm['bmis'] = (dm['bmi'] - dm['bmi'].mean()) / dm['bmi'].std()
dm['lbmkgs'] = (dm['lbmkg'] - dm['lbmkg'].mean()) / dm['lbmkg'].std()


dm['griphs_boy'] = dm['griphs']*dm['boy']
dm['griphs_gir'] = dm['griphs']*dm['girl']

dm['torqhs_boy'] = dm['torqhs']*dm['boy']
dm['torqhs_gir'] = dm['torqhs']*dm['girl']

dm['rsoshs_boy'] = dm['rsoshs']*dm['boy']
dm['rsoshs_gir'] = dm['rsoshs']*dm['girl']

dm['tsoshs_boy'] = dm['tsoshs']*dm['boy']
dm['tsoshs_gir'] = dm['tsoshs']*dm['girl']

dm.head(2)
# Out:
#     id  session  sequence  seq  trips  nota  falk    rsos    tsos  grip  \
# 0  100        1         1    1   4.00   nan   nan 3828.00 3601.00   nan
# 1  100        1         3    2   4.00   nan   nan 3898.00 3629.00 27.00
#
#    ptiso  pt60  godin  paq   ntxc    cint    calc  vitd  vitd2    mvh  matu  \
# 0 113.93 69.29  37.00 2.59 711.85 1572.00 1077.67  3.38 135.27 105.71 -1.67
# 1 136.02 87.78  48.00 3.17 760.09 2219.01 1212.82  1.02  41.02  93.62 -0.71
#
#     age  gender  height  seatedheight  leglength  weight  bf_slaughter  \
# 0 11.75       0  152.00         75.20      76.80   44.20         22.81
# 1 12.71       0  160.80         79.60      81.20   48.80         17.24
#
#    bia_pbf   bmi  lbmkg  yearsfromaphv  age_at_phv  bone_age  tanner  \
# 0    21.90 19.13  34.12          -2.13       13.88     11.16    2.00
# 1    14.90 18.87  40.39          -1.21       13.92     12.41    4.00
#
#    menarche age_first_period period_frequency  medications  vitamins  \
# 0       nan                                           0.00      0.00
# 1       nan                                           0.00      0.00
#
#    fracture  radius_z  tibial_z  wrist_flexion_best  flength  \
# 0         0      0.80     -0.75                 nan      nan
# 1         0      1.00     -0.70               13.65    25.60
#
#    forearm_lean_csa  forearm_us_csa  anterior_csa  anteriorradius  \
# 0               nan             nan           nan             nan
# 1             30.41           14.49         11.97           34.74
#
#    ant_rad_csa     ...       tsosh  flengthh  tlengthh   mvhh  sedh   ntxh  \
# 0          nan     ...     3601.00     23.77     35.50 105.71 78.43 711.85
# 1         9.48     ...     3629.00     25.60     36.50  93.62 75.55 760.09
#
#    godinh  paqh  paqprvnth   calch   cinth  vitdh  boy  girl  rsoshs  tsoshs  \
# 0   37.00  2.59       1.00 1077.67 1572.00   3.38 1.00   nan    0.11   -0.81
# 1   48.00  3.17       1.00 1212.82 2219.01   1.02 1.00   nan    0.86   -0.55
#
#    griphs  ptisohs  ntxhs  mvhhs  sedhs  godhs  paqhs  cinths  vitdhs  calchs  \
# 0    0.06    -0.25   0.68   0.06   0.83  -0.90  -0.84   -0.05   -0.42    0.22
# 1    0.54     0.22   0.87  -0.27   0.58  -0.62   0.03    1.29   -1.17    0.52
#
#   flengthhs tlengthhs heights weights  matus  bages  matu2  matu3  matu4  \
# 0      0.04      0.22   -0.02   -0.17  -0.40  -0.38   2.79  -4.66   7.78
# 1      0.86      0.47    0.62    0.14   0.09   0.15   0.50  -0.36   0.25
#
#    ntxhs_g  ntxhs_t  torqhs  paqp  paqps  bmis  lbmkgs  griphs_boy  \
# 0     0.68     0.68   -0.25  1.00   3.06 -0.16   -0.27        0.06
# 1     0.87     0.87    0.22  1.00   3.06 -0.23    0.37        0.54
#
#    griphs_gir  torqhs_boy  torqhs_gir  rsoshs_boy  rsoshs_gir  tsoshs_boy  \
# 0         nan       -0.25         nan        0.11         nan       -0.81
# 1         nan        0.22         nan        0.86         nan       -0.55
#
#    tsoshs_gir
# 0         nan
# 1         nan
#
# [2 rows x 136 columns]

# %%
# %%stata --data dm
# set processors 20
#
# save ./out/dm, replace
# Out:
#     The maximum number of processors or cores being used is changed from 32 to(note: file ./out/dm.dta not found)
# file ./out/dm.dta saved

# %% [markdown]
# # Table 1. Summary statatisitcs

# %%
ds = dm.groupby('seq')['rsosh', 'tsosh', 'griph', 'ptisoh'].mean()
d0 = dm[dm['gender']==0].groupby('seq')['rsosh', 'tsosh', 'griph', 'ptisoh'].mean()
d1 = dm[dm['gender']==1].groupby('seq')['rsosh', 'tsosh', 'griph', 'ptisoh'].mean()

t1 = ds.append(d0)
t1 = t1.append(d1)
t1.to_csv("./out/t1.csv")
t1
# Out:
#       rsosh   tsosh  griph  ptisoh
# seq
# 1   3790.33 3655.38  21.94  114.36
# 2   3825.27 3689.77  22.84  127.47
# 3   3850.35 3722.46  25.64  142.55
# 4   3884.24 3800.12  30.41  144.63
# 1   3789.40 3653.24  22.27  118.40
# 2   3813.99 3680.17  24.09  129.80
# 3   3835.70 3705.18  27.41  150.16
# 4   3850.76 3788.75  34.44  142.73
# 1   3791.44 3657.93  21.54  109.51
# 2   3837.56 3700.21  21.47  124.94
# 3   3867.15 3742.26  23.61  133.82
# 4   3914.00 3810.22  26.83  146.32

# %%
ds.iloc[3]/ds.iloc[0]-1
d0.iloc[3]/d0.iloc[0]-1
d1.iloc[3]/d1.iloc[0]-1
# Out:
# rsosh    0.02
# tsosh    0.04
# griph    0.39
# ptisoh   0.26
# dtype: float32
# rsosh    0.02
# tsosh    0.04
# griph    0.55
# ptisoh   0.21
# dtype: float32
# rsosh    0.03
# tsosh    0.04
# griph    0.25
# ptisoh   0.34
# dtype: float32

# %% [markdown]
# # Table 2a. Impact of muscle strength on bone properties

# %% [markdown]
# without godin; jun25

# %%
# %%stata --data dm
# set processors 20
#
# xtset id seq
#
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (cinths matus  -> griphs,)  ///
#     (cinths matus  -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
#
# lincom [griphs]matus - [torqhs]matus
# lincom [griphs]cinths - [torqhs]cinths
#
# lincom [rsoshs]griphs - [tsoshs]torqhs
# lincom [rsoshs]matus - [tsoshs]matus
# lincom [rsoshs]ntxhs - [tsoshs]ntxhs
# lincom [rsoshs]paqps - [tsoshs]mvhhs
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 4
#                 delta:  1 unit
# >     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (cinths matus  -> griphs,)  ///
# >     (cinths matus  -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2061.3767  (not concave)
# Iteration 1:   log likelihood = -1996.3098
# Iteration 2:   log likelihood = -1988.1463
# Iteration 3:   log likelihood = -1980.2482
# Iteration 4:   log likelihood =  -1979.682
# Iteration 5:   log likelihood =  -1979.679
# Iteration 6:   log likelihood =  -1979.679
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1957.1282
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1957.1282  (not concave)
# Iteration 1:   log likelihood = -1920.4675  (not concave)
# Iteration 2:   log likelihood = -1903.9254  (not concave)
# Iteration 3:   log likelihood = -1884.2989
# Iteration 4:   log likelihood = -1868.0053
# Iteration 5:   log likelihood = -1864.2514
# Iteration 6:   log likelihood = -1863.5354
# Iteration 7:   log likelihood = -1863.5008
# Iteration 8:   log likelihood = -1863.5004
# Iteration 9:   log likelihood = -1863.5004
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1863.5004
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2369239   .1170688     2.02   0.043     .0074732    .4663746
#                 matus |   .3110776   .0832481     3.74   0.000     .1479143    .4742408
#                 ntxhs |  -.1787327   .0376957    -4.74   0.000     -.252615   -.1048504
#                 paqps |   .0552181   .0319636     1.73   0.084    -.0074294    .1178656
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183741   .0555845    -0.33   0.741    -.1273177    .0905696
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3964436   .1225212     3.24   0.001     .1563064    .6365807
#                 matus |   .3235394   .0915651     3.53   0.000     .1440752    .5030036
#                 ntxhs |  -.1438853   .0347486    -4.14   0.000    -.2119913   -.0757793
#                 mvhhs |   .0822619   .0386127     2.13   0.033     .0065823    .1579414
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264097   .0582056    -0.45   0.650    -.1404906    .0876712
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                cinths |   .1717336   .0389652     4.41   0.000     .0953631     .248104
#                 matus |   .5634218   .0387779    14.53   0.000     .4874184    .6394252
#                 _cons |  -8.73e-08   .0384436    -0.00   1.000    -.0753481     .075348
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                cinths |    .173377   .0378169     4.58   0.000     .0992573    .2474967
#                 matus |   .5761128    .038279    15.05   0.000     .5010872    .6511383
#                 _cons |   8.38e-08   .0379585     0.00   1.000    -.0743973    .0743974
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4006515   .0613992                      .2967027    .5410184
#            var(M2[id])|   .4581607   .0621608                      .3511812    .5977289
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2225053   .0477983     4.66   0.000     .1288223    .3161883
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3120093   .0296764                      .2589444    .3759486
#          var(e.tsoshs)|   .3051254   .0487153                      .2231406    .4172326
#          var(e.griphs)|   .6281115   .0431076                      .5490581    .7185469
#          var(e.torqhs)|   .6123612   .0419582                      .5354074    .7003756
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0835422   .0198758     4.20   0.000     .0445864    .1224981
# cov(e.griphs,e.rsoshs)|   .0319356   .0618796     0.52   0.606    -.0893463    .1532174
# cov(e.torqhs,e.tsoshs)|  -.1726108   .0654496    -2.64   0.008    -.3008896   -.0443319
# cov(e.torqhs,e.griphs)|    .241014   .0316551     7.61   0.000     .1789711     .303057
# ---------------------------------------------------------------------------------------
#
#  ( 1)  [griphs]matus - [torqhs]matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0126909   .0426096    -0.30   0.766    -.0962042    .0708223
# ------------------------------------------------------------------------------
#
#  ( 1)  [griphs]cinths - [torqhs]cinths = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0016435   .0426768    -0.04   0.969    -.0852885    .0820016
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.1595197   .1494493    -1.07   0.286    -.4524349    .1333956
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]matus - [tsoshs]matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0124618   .1059093    -0.12   0.906    -.2200403    .1951166
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0348474   .0421084    -0.83   0.408    -.1173784    .0476836
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]paqps - [tsoshs]mvhhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0270438   .0498416    -0.54   0.587    -.1247314    .0706439
# ------------------------------------------------------------------------------

# %%
# %%stata --data dm
# set processors 20
#
# xtset id seq
#
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (godhs cinths matus    -> griphs,)  ///
#     (godhs cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
#
# lincom [griphs]matus - [torqhs]matus
# lincom [griphs]cinths - [torqhs]cinths
# lincom [griphs]godhs - [torqhs]godhs
#
# lincom [rsoshs]griphs - [tsoshs]torqhs
# lincom [rsoshs]matus - [tsoshs]matus
# lincom [rsoshs]ntxhs - [tsoshs]ntxhs
# lincom [rsoshs]paqps - [tsoshs]mvhhs
#
#
# *****without godin; jun25
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (cinths matus -> griphs,)  ///
#     (cinths matus -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
# Out:
#     The maximum number of processors or cores being used is changed from 32 to       panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 4
#                 delta:  1 unit
# >     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (godhs cinths matus    -> griphs,)  ///
# >     (godhs cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2050.3787  (not concave)
# Iteration 1:   log likelihood =  -1986.265
# Iteration 2:   log likelihood = -1982.0747
# Iteration 3:   log likelihood = -1971.8136
# Iteration 4:   log likelihood = -1970.9114
# Iteration 5:   log likelihood =  -1970.826
# Iteration 6:   log likelihood = -1970.8253
# Iteration 7:   log likelihood = -1970.8253
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1947.9747
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1947.9747  (not concave)
# Iteration 1:   log likelihood = -1912.1681  (not concave)
# Iteration 2:   log likelihood = -1896.1383  (not concave)
# Iteration 3:   log likelihood =  -1876.418
# Iteration 4:   log likelihood =  -1858.983
# Iteration 5:   log likelihood = -1855.2422
# Iteration 6:   log likelihood = -1854.5785
# Iteration 7:   log likelihood = -1854.5476
# Iteration 8:   log likelihood = -1854.5474
# Iteration 9:   log likelihood = -1854.5474
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1854.5474
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2419942   .1104781     2.19   0.028      .025461    .4585274
#                 matus |   .3084402   .0810276     3.81   0.000     .1496291    .4672514
#                 ntxhs |  -.1796183   .0377279    -4.76   0.000    -.2535637   -.1056729
#                 paqps |   .0545991   .0319829     1.71   0.088    -.0080863    .1172846
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183515   .0556389    -0.33   0.742    -.1274017    .0906988
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .4000205   .1233158     3.24   0.001      .158326    .6417149
#                 matus |   .3204972   .0922616     3.47   0.001     .1396678    .5013266
#                 ntxhs |  -.1429093   .0348126    -4.11   0.000    -.2111407   -.0746778
#                 mvhhs |   .0820493   .0386155     2.12   0.034     .0063644    .1577343
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264677   .0581858    -0.45   0.649    -.1405099    .0875744
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1658118   .0392836     4.22   0.000     .0888173    .2428062
#                cinths |   .1374999   .0390604     3.52   0.000     .0609429    .2140569
#                 matus |   .5999135   .0389674    15.40   0.000     .5235389    .6762882
#                 _cons |  -9.43e-08   .0376653    -0.00   1.000    -.0738228    .0738226
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .0847608   .0372795     2.27   0.023     .0116943    .1578274
#                cinths |   .1560526     .03819     4.09   0.000     .0812016    .2309036
#                 matus |   .5947456   .0389262    15.28   0.000     .5184515    .6710396
#                 _cons |   8.02e-08   .0377528     0.00   1.000    -.0739941    .0739943
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4020271   .0614952                      .2978881    .5425721
#            var(M2[id])|    .457207   .0620565                      .3504125     .596549
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2221857   .0478268     4.65   0.000      .128447    .3159244
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3112376   .0291402                      .2590578    .3739275
#          var(e.tsoshs)|   .3064253   .0494011                      .2234066     .420294
#          var(e.griphs)|   .6029383   .0413636                      .5270813    .6897125
#          var(e.torqhs)|   .6057426    .041483                      .5296578    .6927569
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0833008   .0195874     4.25   0.000     .0449102    .1216915
# cov(e.griphs,e.rsoshs)|    .028564   .0563978     0.51   0.613    -.0819736    .1391015
# cov(e.torqhs,e.tsoshs)|  -.1741782   .0658605    -2.64   0.008    -.3032625   -.0450939
# cov(e.torqhs,e.griphs)|   .2282826   .0305861     7.46   0.000     .1683349    .2882304
# ---------------------------------------------------------------------------------------
#
#  ( 1)  [griphs]matus - [torqhs]matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .0051679   .0434156     0.12   0.905    -.0799252     .090261
# ------------------------------------------------------------------------------
#
#  ( 1)  [griphs]cinths - [torqhs]cinths = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0185527   .0431666    -0.43   0.667    -.1031577    .0660524
# ------------------------------------------------------------------------------
#
#  ( 1)  [griphs]godhs - [torqhs]godhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .0810509   .0421217     1.92   0.054    -.0015061    .1636079
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.1580263   .1449688    -1.09   0.276      -.44216    .1261075
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]matus - [tsoshs]matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   -.012057   .1044831    -0.12   0.908    -.2168401    .1927261
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   -.036709   .0421717    -0.87   0.384    -.1193641     .045946
# ------------------------------------------------------------------------------
#
#  ( 1)  [rsoshs]paqps - [tsoshs]mvhhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0274502   .0498438    -0.55   0.582    -.1251422    .0702418
# ------------------------------------------------------------------------------
# . gsem ///
# >     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (cinths matus -> griphs,)  ///
# >     (cinths matus -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2061.3767  (not concave)
# Iteration 1:   log likelihood = -1996.3098
# Iteration 2:   log likelihood = -1988.1463
# Iteration 3:   log likelihood = -1980.2482
# Iteration 4:   log likelihood =  -1979.682
# Iteration 5:   log likelihood =  -1979.679
# Iteration 6:   log likelihood =  -1979.679
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1957.1282
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1957.1282  (not concave)
# Iteration 1:   log likelihood = -1920.4675  (not concave)
# Iteration 2:   log likelihood = -1903.9254  (not concave)
# Iteration 3:   log likelihood = -1884.2989
# Iteration 4:   log likelihood = -1868.0053
# Iteration 5:   log likelihood = -1864.2514
# Iteration 6:   log likelihood = -1863.5354
# Iteration 7:   log likelihood = -1863.5008
# Iteration 8:   log likelihood = -1863.5004
# Iteration 9:   log likelihood = -1863.5004
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1863.5004
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2369239   .1170688     2.02   0.043     .0074732    .4663746
#                 matus |   .3110776   .0832481     3.74   0.000     .1479143    .4742408
#                 ntxhs |  -.1787327   .0376957    -4.74   0.000     -.252615   -.1048504
#                 paqps |   .0552181   .0319636     1.73   0.084    -.0074294    .1178656
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183741   .0555845    -0.33   0.741    -.1273177    .0905696
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3964436   .1225212     3.24   0.001     .1563064    .6365807
#                 matus |   .3235394   .0915651     3.53   0.000     .1440752    .5030036
#                 ntxhs |  -.1438853   .0347486    -4.14   0.000    -.2119913   -.0757793
#                 mvhhs |   .0822619   .0386127     2.13   0.033     .0065823    .1579414
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264097   .0582056    -0.45   0.650    -.1404906    .0876712
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                cinths |   .1717336   .0389652     4.41   0.000     .0953631     .248104
#                 matus |   .5634218   .0387779    14.53   0.000     .4874184    .6394252
#                 _cons |  -8.73e-08   .0384436    -0.00   1.000    -.0753481     .075348
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                cinths |    .173377   .0378169     4.58   0.000     .0992573    .2474967
#                 matus |   .5761128    .038279    15.05   0.000     .5010872    .6511383
#                 _cons |   8.38e-08   .0379585     0.00   1.000    -.0743973    .0743974
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4006515   .0613992                      .2967027    .5410184
#            var(M2[id])|   .4581607   .0621608                      .3511812    .5977289
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2225053   .0477983     4.66   0.000     .1288223    .3161883
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3120093   .0296764                      .2589444    .3759486
#          var(e.tsoshs)|   .3051254   .0487153                      .2231406    .4172326
#          var(e.griphs)|   .6281115   .0431076                      .5490581    .7185469
#          var(e.torqhs)|   .6123612   .0419582                      .5354074    .7003756
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0835422   .0198758     4.20   0.000     .0445864    .1224981
# cov(e.griphs,e.rsoshs)|   .0319356   .0618796     0.52   0.606    -.0893463    .1532174
# cov(e.torqhs,e.tsoshs)|  -.1726108   .0654496    -2.64   0.008    -.3008896   -.0443319
# cov(e.torqhs,e.griphs)|    .241014   .0316551     7.61   0.000     .1789711     .303057
# ---------------------------------------------------------------------------------------

# %% [markdown]
# # Table 3. Constrained specification results.

# %% [markdown]
# ****without godin; june 27

# %%
# %%stata --data dm
# set processors 20
#
# constraint 1 _b[rsoshs:griphs] = _b[tsoshs:torqhs]
# constraint 2 _b[rsoshs:matus]  = _b[tsoshs:matus]
# constraint 3 _b[rsoshs:ntxhs]  = _b[tsoshs:ntxhs]
# constraint 4 _b[rsoshs:paqps]  = _b[tsoshs:mvhhs]
#
# constraint 5 _b[griphs:cinths] = _b[torqhs:cinths]
# constraint 6 _b[griphs:matus]  = _b[torqhs:matus]
#
#
# constraint 10 _b[griphs:_cons] = 0
# constraint 11 _b[torqhs:_cons] = 0
# constraint 12 _b[rsoshs:_cons] = 0
# constraint 13 _b[tsoshs:_cons] = 0
#
# constraint 14 [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
# constraint 15 [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#
# gsem ///
#     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (  cinths matus    -> griphs,)  ///
#     (  cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       constraints(1 2 3 4 5 6  10 11 12 13 14 15)
#
# ** indirect effect
# nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# ** total effect
# nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# Out:
# 'Failed to open Stata'

# %%
# %%stata --data dm
# set processors 20
#
# constraint 1 _b[rsoshs:griphs] = _b[tsoshs:torqhs]
# constraint 2 _b[rsoshs:matus]  = _b[tsoshs:matus]
# constraint 3 _b[rsoshs:ntxhs]  = _b[tsoshs:ntxhs]
# constraint 4 _b[rsoshs:paqps]  = _b[tsoshs:mvhhs]
#
# constraint 6 _b[griphs:cinths] = _b[torqhs:cinths]
# constraint 7 _b[griphs:matus]  = _b[torqhs:matus]
#
#
# constraint 10 _b[griphs:_cons] = 0
# constraint 11 _b[torqhs:_cons] = 0
# constraint 12 _b[rsoshs:_cons] = 0
# constraint 13 _b[tsoshs:_cons] = 0
#
# constraint 14 [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
# constraint 15 [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (godhs cinths matus    -> griphs,)  ///
#     (godhs cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
# matrix b = e(b)
#
# gsem ///
#     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     ( godhs cinths matus    -> griphs,)  ///
#     ( godhs cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
#       from(b, skip)
#
# ** indirect effect
# nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# ** total effect
# nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#
#
# ****without godin and paq, jun 14
#
# gsem ///
#     (M1[id]@1 griphs matus ntxhs   -> rsoshs, ) ///
#     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (  cinths matus    -> griphs,)  ///
#     (  cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       constraints(1 2 3  6 7  10 11 12 13 14 15) ///
#       from(b, skip)
#
# ** indirect effect
# nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# ** total effect
# nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# Out:
#     The maximum number of processors or cores being used is changed from 32 to>     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (godhs cinths matus    -> griphs,)  ///
# >     (godhs cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2050.3787  (not concave)
# Iteration 1:   log likelihood =  -1986.265
# Iteration 2:   log likelihood = -1982.0747
# Iteration 3:   log likelihood = -1971.8136
# Iteration 4:   log likelihood = -1970.9114
# Iteration 5:   log likelihood =  -1970.826
# Iteration 6:   log likelihood = -1970.8253
# Iteration 7:   log likelihood = -1970.8253
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1947.9747
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1947.9747  (not concave)
# Iteration 1:   log likelihood = -1912.1681  (not concave)
# Iteration 2:   log likelihood = -1896.1383  (not concave)
# Iteration 3:   log likelihood =  -1876.418
# Iteration 4:   log likelihood =  -1858.983
# Iteration 5:   log likelihood = -1855.2422
# Iteration 6:   log likelihood = -1854.5785
# Iteration 7:   log likelihood = -1854.5476
# Iteration 8:   log likelihood = -1854.5474
# Iteration 9:   log likelihood = -1854.5474
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1854.5474
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2419942   .1104781     2.19   0.028      .025461    .4585274
#                 matus |   .3084402   .0810276     3.81   0.000     .1496291    .4672514
#                 ntxhs |  -.1796183   .0377279    -4.76   0.000    -.2535637   -.1056729
#                 paqps |   .0545991   .0319829     1.71   0.088    -.0080863    .1172846
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183515   .0556389    -0.33   0.742    -.1274017    .0906988
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .4000205   .1233158     3.24   0.001      .158326    .6417149
#                 matus |   .3204972   .0922616     3.47   0.001     .1396678    .5013266
#                 ntxhs |  -.1429093   .0348126    -4.11   0.000    -.2111407   -.0746778
#                 mvhhs |   .0820493   .0386155     2.12   0.034     .0063644    .1577343
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264677   .0581858    -0.45   0.649    -.1405099    .0875744
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1658118   .0392836     4.22   0.000     .0888173    .2428062
#                cinths |   .1374999   .0390604     3.52   0.000     .0609429    .2140569
#                 matus |   .5999135   .0389674    15.40   0.000     .5235389    .6762882
#                 _cons |  -9.43e-08   .0376653    -0.00   1.000    -.0738228    .0738226
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .0847608   .0372795     2.27   0.023     .0116943    .1578274
#                cinths |   .1560526     .03819     4.09   0.000     .0812016    .2309036
#                 matus |   .5947456   .0389262    15.28   0.000     .5184515    .6710396
#                 _cons |   8.02e-08   .0377528     0.00   1.000    -.0739941    .0739943
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4020271   .0614952                      .2978881    .5425721
#            var(M2[id])|    .457207   .0620565                      .3504125     .596549
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2221857   .0478268     4.65   0.000      .128447    .3159244
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3112376   .0291402                      .2590578    .3739275
#          var(e.tsoshs)|   .3064253   .0494011                      .2234066     .420294
#          var(e.griphs)|   .6029383   .0413636                      .5270813    .6897125
#          var(e.torqhs)|   .6057426    .041483                      .5296578    .6927569
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0833008   .0195874     4.25   0.000     .0449102    .1216915
# cov(e.griphs,e.rsoshs)|    .028564   .0563978     0.51   0.613    -.0819736    .1391015
# cov(e.torqhs,e.tsoshs)|  -.1741782   .0658605    -2.64   0.008    -.3032625   -.0450939
# cov(e.torqhs,e.griphs)|   .2282826   .0305861     7.46   0.000     .1683349    .2882304
# ---------------------------------------------------------------------------------------
# >     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     ( godhs cinths matus    -> griphs,)  ///
# >     ( godhs cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
# >       from(b, skip)
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1961.1421
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1981.0712
# Iteration 1:   log likelihood = -1916.2051
# Iteration 2:   log likelihood = -1902.1131
# Iteration 3:   log likelihood =  -1901.424
# Iteration 4:   log likelihood = -1901.4187
# Iteration 5:   log likelihood = -1901.4187
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1901.4187
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#  ( 2)  [rsoshs]matus - [tsoshs]matus = 0
#  ( 3)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#  ( 4)  [rsoshs]paqps - [tsoshs]mvhhs = 0
#  ( 5)  [griphs]godhs - [torqhs]godhs = 0
#  ( 6)  [griphs]cinths - [torqhs]cinths = 0
#  ( 7)  [griphs]matus - [torqhs]matus = 0
#  ( 8)  [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
#  ( 9)  [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#  (10)  [rsoshs]_cons = 0
#  (11)  [rsoshs]M1[id] = 1
#  (12)  [tsoshs]_cons = 0
#  (13)  [tsoshs]M1[id] = 1
#  (14)  [griphs]_cons = 0
#  (15)  [torqhs]_cons = 0
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .3251902   .0966178     3.37   0.001     .1358227    .5145576
#                 matus |   .3050174   .0703016     4.34   0.000     .1672288    .4428061
#                 ntxhs |  -.1581131   .0294621    -5.37   0.000    -.2158577   -.1003684
#                 paqps |   .0480936   .0241553     1.99   0.046     .0007501    .0954371
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3251902   .0966178     3.37   0.001     .1358227    .5145576
#                 matus |   .3050174   .0703016     4.34   0.000     .1672288    .4428061
#                 ntxhs |  -.1581131   .0294621    -5.37   0.000    -.2158577   -.1003684
#                 mvhhs |   .0480936   .0241553     1.99   0.046     .0007501    .0954371
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1233443   .0325649     3.79   0.000     .0595182    .1871704
#                cinths |   .1513273   .0325372     4.65   0.000     .0875555    .2150991
#                 matus |   .6012873   .0324364    18.54   0.000     .5377131    .6648615
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .1233443   .0325649     3.79   0.000     .0595182    .1871704
#                cinths |   .1513273   .0325372     4.65   0.000     .0875555    .2150991
#                 matus |   .6012873   .0324364    18.54   0.000     .5377131    .6648615
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .3254799   .0445397                      .2489104    .4256036
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3960013   .0248239                      .3502175    .4477704
#          var(e.tsoshs)|   .3960013   .0248239                      .3502175    .4477704
#          var(e.griphs)|   .6085468   .0317137                      .5494582    .6739899
#          var(e.torqhs)|   .6085468   .0317137                      .5494582    .6739899
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|  -.0250757   .0216734    -1.16   0.247    -.0675548    .0174033
# cov(e.griphs,e.rsoshs)|   -.015549   .0481263    -0.32   0.747    -.1098747    .0787768
# cov(e.torqhs,e.tsoshs)|  -.1217269   .0509042    -2.39   0.017    -.2214973   -.0219566
# cov(e.torqhs,e.griphs)|   .2321248   .0311757     7.45   0.000     .1710216    .2932281
# ---------------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .1955327   .0592046     3.30   0.001     .0794938    .3115716
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .5207229   .1552341     3.35   0.001     .2164695    .8249762
# ------------------------------------------------------------------------------
#
# . . gsem ///
# >     (M1[id]@1 griphs matus ntxhs   -> rsoshs, ) ///
# >     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (  cinths matus    -> griphs,)  ///
# >     (  cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       constraints(1 2 3  6 7  10 11 12 13 14 15) ///
# >       from(b, skip)
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1973.5525
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1991.3818
# Iteration 1:   log likelihood = -1924.0799
# Iteration 2:   log likelihood = -1910.6192
# Iteration 3:   log likelihood = -1910.0311
# Iteration 4:   log likelihood =  -1910.027
# Iteration 5:   log likelihood =  -1910.027
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood =  -1910.027
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#  ( 2)  [rsoshs]matus - [tsoshs]matus = 0
#  ( 3)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#  ( 4)  [griphs]cinths - [torqhs]cinths = 0
#  ( 5)  [griphs]matus - [torqhs]matus = 0
#  ( 6)  [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
#  ( 7)  [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#  ( 8)  [rsoshs]_cons = 0
#  ( 9)  [rsoshs]M1[id] = 1
#  (10)  [tsoshs]_cons = 0
#  (11)  [tsoshs]M1[id] = 1
#  (12)  [griphs]_cons = 0
#  (13)  [torqhs]_cons = 0
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .3291529   .0972766     3.38   0.001     .1384942    .5198115
#                 matus |   .2989031   .0703993     4.25   0.000      .160923    .4368832
#                 ntxhs |   -.160189   .0294665    -5.44   0.000    -.2179424   -.1024357
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3291529   .0972766     3.38   0.001     .1384942    .5198115
#                 matus |   .2989031   .0703993     4.25   0.000      .160923    .4368832
#                 ntxhs |   -.160189   .0294665    -5.44   0.000    -.2179424   -.1024357
#                 mvhhs |   .0351888   .0368961     0.95   0.340    -.0371262    .1075038
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                cinths |   .1761961   .0324589     5.43   0.000     .1125778    .2398144
#                 matus |   .5734845   .0321772    17.82   0.000     .5104183    .6365507
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                cinths |   .1761961   .0324589     5.43   0.000     .1125778    .2398144
#                 matus |   .5734845   .0321772    17.82   0.000     .5104183    .6365507
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .3268991   .0447328                      .2499973    .4274566
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3983898   .0250932                      .3521227    .4507361
#          var(e.tsoshs)|   .3983898   .0250932                      .3521227    .4507361
#          var(e.griphs)|   .6230928   .0326164                      .5623359    .6904141
#          var(e.torqhs)|   .6230928   .0326164                      .5623359    .6904141
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|  -.0249076   .0218473    -1.14   0.254    -.0677275    .0179122
# cov(e.griphs,e.rsoshs)|  -.0162106   .0485303    -0.33   0.738    -.1113282     .078907
# cov(e.torqhs,e.tsoshs)|  -.1274086   .0516579    -2.47   0.014    -.2286563    -.026161
# cov(e.torqhs,e.griphs)|   .2464661   .0320492     7.69   0.000     .1836508    .3092814
# ---------------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .1887641   .0570371     3.31   0.001     .0769734    .3005547
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |    .517917   .1536875     3.37   0.001      .216695    .8191389
# ------------------------------------------------------------------------------

# %% [markdown]
# # Table 3. Sex-specific estimation results.

# %%
# %%stata --data dm
# set processors 20
#
# label define sex 0 "boys" 1 "girls
# label values gender sex
#
#
#
# constraint 10 _b[griphs:_cons] = 0
# constraint 11 _b[torqhs:_cons] = 0
# constraint 12 _b[rsoshs:_cons] = 0
# constraint 13 _b[tsoshs:_cons] = 0
#
#
# constraint 20 [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
# constraint 21 [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
# /*
# gsem ///
#     (M1[id]@1 i1.gender#c.griphs i1.gender#c.matus i1.gender#c.ntxhs i1.gender#c.paqps  -> rsoshs, ) ///
#     (M1[id]@1 i1.gender#c.torqhs i1.gender#c.matus i1.gender#c.ntxhs i1.gender#c.mvhhs  -> tsoshs, ) ///
#     ///
#     (M1[id]@1 i0.gender#c.griphs i0.gender#c.matus i0.gender#c.ntxhs i1.gender#c.paqps  -> rsoshs, ) ///
#     (M1[id]@1 i0.gender#c.torqhs i0.gender#c.matus i0.gender#c.ntxhs i0.gender#c.mvhhs  -> tsoshs, ) ///
#     ///
#     (i1.gender#c.godhs i1.gender#c.cinths i1.gender#c.matus    -> griphs,)  ///
#     (i1.gender#c.godhs i1.gender#c.cinths i1.gender#c.matus    -> torqhs,)  ///
#     ///
#     (i0.gender#c.godhs i0.gender#c.cinths i0.gender#c.matus  -> griphs,)  ///
#     (i0.gender#c.godhs i0.gender#c.cinths i0.gender#c.matus  -> torqhs,)  ///
#     , covstruct(_lexogenous, diagonal) nocapslatent ///
#     latent(M1) constraints(10 11 12 13 20 21) ///
#     cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#     cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs)
#
# estimates store t3a
# estimates save "./out/t3", replace
#
# lincom _b[rsoshs:0b.gender#c.griphs] - _b[tsoshs:0b.gender#c.torqhs]
# lincom _b[rsoshs:i1.gender#c.griphs] - _b[tsoshs:i1.gender#c.torqhs]
# lincom _b[rsoshs:0b.gender#c.matus] - _b[tsoshs:0b.gender#c.matus]
# lincom _b[rsoshs:1.gender#c.matus] - _b[tsoshs:1.gender#c.matus]
# lincom _b[rsoshs:0b.gender#c.ntxhs] - _b[tsoshs:0b.gender#c.ntxhs]
# lincom _b[rsoshs:1.gender#c.ntxhs] - _b[tsoshs:1.gender#c.ntxhs]
# lincom _b[griphs:0b.gender#c.matus] - _b[torqhs:0b.gender#c.matus]
# lincom _b[griphs:1.gender#c.matus] - _b[torqhs:1.gender#c.matus]
# */
# ***********************************************************************
# ***********************************************************************
# gsem ///
#     (M1[id]@1 i1.gender#c.griphs@b1a i1.gender#c.matus@b1b i1.gender#c.ntxhs@b1c i1.gender#c.paqps@b1d  -> rsoshs, ) ///
#     (M1[id]@1 i1.gender#c.torqhs@b1a i1.gender#c.matus@b1b i1.gender#c.ntxhs@b1c i1.gender#c.mvhhs@b1d  -> tsoshs, ) ///
#     ///
#     (M1[id]@1 i0.gender#c.griphs@b0a i0.gender#c.matus@b0b i0.gender#c.ntxhs@b0c i0.gender#c.paqps@b0d  -> rsoshs, ) ///
#     (M1[id]@1 i0.gender#c.torqhs@b0a i0.gender#c.matus@b0b i0.gender#c.ntxhs@b0c i0.gender#c.mvhhs@b0d  -> tsoshs, ) ///
#     ///
#     (i1.gender#c.godhs@m1a i1.gender#c.cinths@m1b i1.gender#c.matus@m1c    -> griphs,)  ///
#     (i1.gender#c.godhs@m1a i1.gender#c.cinths@m1b i1.gender#c.matus@m1c    -> torqhs,)  ///
#     ///
#     (i0.gender#c.godhs@m0a i0.gender#c.cinths@m0b i0.gender#c.matus@m0c  -> griphs,)  ///
#     (i0.gender#c.godhs@m0a i0.gender#c.cinths@m0b i0.gender#c.matus@m0c  -> torqhs,)  ///
#     , covstruct(_lexogenous, diagonal) nocapslatent ///
#     latent(M1) constraints(10 11 12 13 20 21) ///
#     cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#     cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs)
#
#      estimates store t3b
# estimates save "./out/t3b", replace
#
# ***********************************************************************
# ***muscle strength
#
# lincom _b[griphs:1.gender#c.matus] - _b[griphs:0.gender#c.matus]
#
# ***************************
# ***nutrition
#
# lincom _b[griphs:1.gender#c.cinths] - _b[griphs:0.gender#c.cinths]
#
# ***************************
#
# lincom _b[griphs:1.gender#c.godhs] - _b[griphs:0.gender#c.godhs]
# ***************************
# ***bone properties
#
# lincom _b[rsoshs:1.gender#c.matus] - _b[rsoshs:0.gender#c.matus]
# ***************************
#
# lincom _b[rsoshs:1.gender#c.ntxhs] - _b[rsoshs:0.gender#c.ntxhs]
# ***************************
#
# lincom _b[rsoshs:1.gender#c.griphs] - _b[rsoshs:0.gender#c.griphs]
#
# ***************************
#
# lincom _b[tsoshs:1.gender#c.mvhhs] - _b[tsoshs:0.gender#c.mvhhs]
#
# ***********************************************************************
# ****decompose effects maturation effect
#
# ****boys
# **direct effect
#
# *matu on bone
# nlcom _b[rsoshs:0b.gender#c.matus]
#
# ** indirect effect
# *grip on bone
# nlcom _b[rsoshs:0b.gender#c.griphs]
#
# *matu on grip
# nlcom _b[griphs:0b.gender#c.matus]
#
# *product (indirect effect)
# nlcom _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
# ** total effect
#
# nlcom _b[rsoshs:0b.gender#c.matus]
# nlcom _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
# nlcom _b[rsoshs:0b.gender#c.matus] + _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
# ***girls
# **direct effect
#
# *matu on bone
# nlcom _b[rsoshs:i1.gender#c.matus]
#
# ** indirect effect
# *grip on bone
# nlcom _b[rsoshs:i1.gender#c.griphs]
#
# *matu on grip
# nlcom _b[griphs:i1.gender#c.matus]
#
# *product (indirect effect)
# nlcom _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
# ** total effect
#
# nlcom _b[rsoshs:i1.gender#c.matus]
# nlcom _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
# nlcom _b[rsoshs:i1.gender#c.matus] + _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
# ************************************************************************************
# ************************************************************************************
# ************************************************************************************
#
# *estout t3a t3b , cells("b( fmt(2)) ci(par fmt(2))") interaction(:) label
# Out:
#     The maximum number of processors or cores being used is changed from 32 to
# . > gsem ///
# >     (M1[id]@1 i1.gender#c.griphs i1.gender#c.matus i1.gender#c.ntxhs i1.gender#c.paqps  -> rsoshs, ) ///
# >     (M1[id]@1 i1.gender#c.torqhs i1.gender#c.matus i1.gender#c.ntxhs i1.gender#c.mvhhs  -> tsoshs, ) ///
# >     ///
# >     (M1[id]@1 i0.gender#c.griphs i0.gender#c.matus i0.gender#c.ntxhs i1.gender#c.paqps  -> rsoshs, ) ///
# >     (M1[id]@1 i0.gender#c.torqhs i0.gender#c.matus i0.gender#c.ntxhs i0.gender#c.mvhhs  -> tsoshs, ) ///
# >     ///
# >     (i1.gender#c.godhs i1.gender#c.cinths i1.gender#c.matus    -> griphs,)  ///
# >     (i1.gender#c.godhs i1.gender#c.cinths i1.gender#c.matus    -> torqhs,)  ///
# >     ///
# >     (i0.gender#c.godhs i0.gender#c.cinths i0.gender#c.matus  -> griphs,)  ///
# >     (i0.gender#c.godhs i0.gender#c.cinths i0.gender#c.matus  -> torqhs,)  ///
# >     , covstruct(_lexogenous, diagonal) nocapslatent ///
# >     latent(M1) constraints(10 11 12 13 20 21) ///
# >     cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >     cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs)
# >
# > estimates store t3a
# > estimates save "./out/t3", replace
# >
# > lincom _b[rsoshs:0b.gender#c.griphs] - _b[tsoshs:0b.gender#c.torqhs]
# > lincom _b[rsoshs:i1.gender#c.griphs] - _b[tsoshs:i1.gender#c.torqhs]
# > lincom _b[rsoshs:0b.gender#c.matus] - _b[tsoshs:0b.gender#c.matus]
# > lincom _b[rsoshs:1.gender#c.matus] - _b[tsoshs:1.gender#c.matus]
# > lincom _b[rsoshs:0b.gender#c.ntxhs] - _b[tsoshs:0b.gender#c.ntxhs]
# > lincom _b[rsoshs:1.gender#c.ntxhs] - _b[tsoshs:1.gender#c.ntxhs]
# > lincom _b[griphs:0b.gender#c.matus] - _b[torqhs:0b.gender#c.matus]
# > lincom _b[griphs:1.gender#c.matus] - _b[torqhs:1.gender#c.matus]
# > */. ***********************************************************************>     (M1[id]@1 i1.gender#c.griphs@b1a i1.gender#c.matus@b1b i1.gender#c.ntxhs@b1c i1.gender#c.paqps@b1d  -> rsoshs, ) ///
# >     (M1[id]@1 i1.gender#c.torqhs@b1a i1.gender#c.matus@b1b i1.gender#c.ntxhs@b1c i1.gender#c.mvhhs@b1d  -> tsoshs, ) ///
# >     ///
# >     (M1[id]@1 i0.gender#c.griphs@b0a i0.gender#c.matus@b0b i0.gender#c.ntxhs@b0c i0.gender#c.paqps@b0d  -> rsoshs, ) ///
# >     (M1[id]@1 i0.gender#c.torqhs@b0a i0.gender#c.matus@b0b i0.gender#c.ntxhs@b0c i0.gender#c.mvhhs@b0d  -> tsoshs, ) ///
# >     ///
# >     (i1.gender#c.godhs@m1a i1.gender#c.cinths@m1b i1.gender#c.matus@m1c    -> griphs,)  ///
# >     (i1.gender#c.godhs@m1a i1.gender#c.cinths@m1b i1.gender#c.matus@m1c    -> torqhs,)  ///
# >     ///
# >     (i0.gender#c.godhs@m0a i0.gender#c.cinths@m0b i0.gender#c.matus@m0c  -> griphs,)  ///
# >     (i0.gender#c.godhs@m0a i0.gender#c.cinths@m0b i0.gender#c.matus@m0c  -> torqhs,)  ///
# >     , covstruct(_lexogenous, diagonal) nocapslatent ///
# >     latent(M1) constraints(10 11 12 13 20 21) ///
# >     cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >     cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2037.2117
# Iteration 1:   log likelihood =  -2002.633
# Iteration 2:   log likelihood = -1962.0028
# Iteration 3:   log likelihood =  -1961.428
# Iteration 4:   log likelihood =  -1961.426
# Iteration 5:   log likelihood =  -1961.426
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1934.4494
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1934.4494  (not concave)
# Iteration 1:   log likelihood = -1899.1152
# Iteration 2:   log likelihood = -1882.1541
# Iteration 3:   log likelihood = -1878.9688
# Iteration 4:   log likelihood = -1878.6866
# Iteration 5:   log likelihood = -1878.6864
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1878.6864
#
#  ( 1)  [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
#  ( 2)  [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#  ( 3)  [rsoshs]0b.gender#c.griphs - [tsoshs]0b.gender#c.torqhs = 0
#  ( 4)  [rsoshs]1.gender#c.griphs - [tsoshs]1.gender#c.torqhs = 0
#  ( 5)  [rsoshs]0b.gender#c.matus - [tsoshs]0b.gender#c.matus = 0
#  ( 6)  [rsoshs]1.gender#c.matus - [tsoshs]1.gender#c.matus = 0
#  ( 7)  [rsoshs]0b.gender#c.ntxhs - [tsoshs]0b.gender#c.ntxhs = 0
#  ( 8)  [rsoshs]1.gender#c.ntxhs - [tsoshs]1.gender#c.ntxhs = 0
#  ( 9)  [rsoshs]0b.gender#c.paqps - [tsoshs]0b.gender#c.mvhhs = 0
#  (10)  [rsoshs]1.gender#c.paqps - [tsoshs]1.gender#c.mvhhs = 0
#  (11)  [rsoshs]_cons = 0
#  (12)  [rsoshs]M1[id] = 1
#  (13)  [tsoshs]_cons = 0
#  (14)  [tsoshs]M1[id] = 1
#  (15)  [griphs]0b.gender#c.godhs - [torqhs]0b.gender#c.godhs = 0
#  (16)  [griphs]1.gender#c.godhs - [torqhs]1.gender#c.godhs = 0
#  (17)  [griphs]0b.gender#c.cinths - [torqhs]0b.gender#c.cinths = 0
#  (18)  [griphs]1.gender#c.cinths - [torqhs]1.gender#c.cinths = 0
#  (19)  [griphs]0b.gender#c.matus - [torqhs]0b.gender#c.matus = 0
#  (20)  [griphs]1.gender#c.matus - [torqhs]1.gender#c.matus = 0
#  (21)  [griphs]_cons = 0
#  (22)  [torqhs]_cons = 0
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#       gender#c.griphs |
#                 boys  |   .3041244   .0914057     3.33   0.001     .1249726    .4832762
#                girls  |    .465944   .0994652     4.68   0.000     .2709957    .6608922
#                       |
#        gender#c.matus |
#                 boys  |   .1739576   .0795728     2.19   0.029     .0179977    .3299174
#                girls  |   .4544253   .0789447     5.76   0.000     .2996966     .609154
#                       |
#        gender#c.ntxhs |
#                 boys  |  -.1334438   .0428086    -3.12   0.002    -.2173472   -.0495404
#                girls  |  -.1184164   .0383105    -3.09   0.002    -.1935036   -.0433293
#                       |
#        gender#c.paqps |
#                 boys  |   .0856247   .0319346     2.68   0.007     .0230341    .1482153
#                girls  |  -.0035817   .0353033    -0.10   0.919    -.0727748    .0656115
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#       gender#c.torqhs |
#                 boys  |   .3041244   .0914057     3.33   0.001     .1249726    .4832762
#                girls  |    .465944   .0994652     4.68   0.000     .2709957    .6608922
#                       |
#        gender#c.matus |
#                 boys  |   .1739576   .0795728     2.19   0.029     .0179977    .3299174
#                girls  |   .4544253   .0789447     5.76   0.000     .2996966     .609154
#                       |
#        gender#c.ntxhs |
#                 boys  |  -.1334438   .0428086    -3.12   0.002    -.2173472   -.0495404
#                girls  |  -.1184164   .0383105    -3.09   0.002    -.1935036   -.0433293
#                       |
#        gender#c.mvhhs |
#                 boys  |   .0856247   .0319346     2.68   0.007     .0230341    .1482153
#                girls  |  -.0035817   .0353033    -0.10   0.919    -.0727748    .0656115
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#        gender#c.godhs |
#                 boys  |   .1508027   .0401294     3.76   0.000     .0721505    .2294548
#                girls  |   .0847206    .054869     1.54   0.123    -.0228207     .192262
#                       |
#       gender#c.cinths |
#                 boys  |   .1159387   .0421974     2.75   0.006     .0332333    .1986442
#                girls  |   .1759683   .0501637     3.51   0.000     .0776493    .2742873
#                       |
#        gender#c.matus |
#                 boys  |   .6957648   .0436985    15.92   0.000     .6101174    .7814123
#                girls  |   .4899863   .0479046    10.23   0.000      .396095    .5838777
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#        gender#c.godhs |
#                 boys  |   .1508027   .0401294     3.76   0.000     .0721505    .2294548
#                girls  |   .0847206    .054869     1.54   0.123    -.0228207     .192262
#                       |
#       gender#c.cinths |
#                 boys  |   .1159387   .0421974     2.75   0.006     .0332333    .1986442
#                girls  |   .1759683   .0501637     3.51   0.000     .0776493    .2742873
#                       |
#        gender#c.matus |
#                 boys  |   .6957648   .0436985    15.92   0.000     .6101174    .7814123
#                girls  |   .4899863   .0479046    10.23   0.000      .396095    .5838777
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .3355242   .0453691                      .2574101     .437343
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3775295   .0243649                       .332672    .4284356
#          var(e.tsoshs)|   .3775295   .0243649                       .332672    .4284356
#          var(e.griphs)|   .6012783   .0313334                       .542898    .6659364
#          var(e.torqhs)|   .6012783   .0313334                       .542898    .6659364
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|  -.0429869   .0203643    -2.11   0.035    -.0829003   -.0030736
# cov(e.griphs,e.rsoshs)|  -.0189577    .045473    -0.42   0.677     -.108083    .0701677
# cov(e.torqhs,e.tsoshs)|  -.1397938   .0463328    -3.02   0.003    -.2306044   -.0489832
# cov(e.torqhs,e.griphs)|   .2275266   .0306472     7.42   0.000     .1674592    .2875941
# ---------------------------------------------------------------------------------------
# file ./out/t3b.ster saved
# . ***muscle strength
#  ( 1)  - [griphs]0b.gender#c.matus + [griphs]1.gender#c.matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.2057785   .0648605    -3.17   0.002    -.3329027   -.0786542
# ------------------------------------------------------------------------------
# . ***nutrition. lincom _b[griphs:1.gender#c.cinths] - _b[griphs:0.gender#c.cinths]
#
#  ( 1)  - [griphs]0b.gender#c.cinths + [griphs]1.gender#c.cinths = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .0600296   .0653802     0.92   0.359    -.0681133    .1881725
# ------------------------------------------------------------------------------
# . ***************************. lincom _b[griphs:1.gender#c.godhs] - _b[griphs:0.gender#c.godhs]
#
#  ( 1)  - [griphs]0b.gender#c.godhs + [griphs]1.gender#c.godhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   -.066082    .067981    -0.97   0.331    -.1993222    .0671582
# ------------------------------------------------------------------------------
# . ***bone properties. lincom _b[rsoshs:1.gender#c.matus] - _b[rsoshs:0.gender#c.matus]
#
#  ( 1)  - [rsoshs]0b.gender#c.matus + [rsoshs]1.gender#c.matus = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .2804678   .0895242     3.13   0.002     .1050035     .455932
# ------------------------------------------------------------------------------
# .
#  ( 1)  - [rsoshs]0b.gender#c.ntxhs + [rsoshs]1.gender#c.ntxhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .0150273   .0573281     0.26   0.793    -.0973337    .1273884
# ------------------------------------------------------------------------------
# .
#  ( 1)  - [rsoshs]0b.gender#c.griphs + [rsoshs]1.gender#c.griphs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |   .1618196   .0733855     2.21   0.027     .0179866    .3056525
# ------------------------------------------------------------------------------
# . ***************************
#  ( 1)  - [tsoshs]0b.gender#c.mvhhs + [tsoshs]1.gender#c.mvhhs = 0
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          (1) |  -.0892063   .0476934    -1.87   0.061    -.1826836     .004271
# ------------------------------------------------------------------------------
# . ***********************************************************************.           . **direct effect. *matu on bone
#        _nl_1:  _b[rsoshs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .1739576   .0795728     2.19   0.029     .0179977    .3299174
# ------------------------------------------------------------------------------
# . ** indirect effect . nlcom _b[rsoshs:0b.gender#c.griphs]
#
#        _nl_1:  _b[rsoshs:0b.gender#c.griphs]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .3041244   .0914057     3.33   0.001     .1249726    .4832762
# ------------------------------------------------------------------------------
# . nlcom _b[griphs:0b.gender#c.matus]
#
#        _nl_1:  _b[griphs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .6957648   .0436985    15.92   0.000     .6101174    .7814123
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
#        _nl_1:  _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .2115991    .065323     3.24   0.001     .0835684    .3396297
# ------------------------------------------------------------------------------
# . ** total effect      . nlcom _b[rsoshs:0b.gender#c.matus]
#
#        _nl_1:  _b[rsoshs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .1739576   .0795728     2.19   0.029     .0179977    .3299174
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .2115991    .065323     3.24   0.001     .0835684    .3396297
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[rsoshs:0b.gender#c.matus] + _b[rsoshs:0b.gender#c.griphs]*_b[griphs:0b.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .3855566   .0506247     7.62   0.000     .2863339    .4847793
# ------------------------------------------------------------------------------
# . **direct effect. *matu on bone
#        _nl_1:  _b[rsoshs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .4544253   .0789447     5.76   0.000     .2996966     .609154
# ------------------------------------------------------------------------------
# . ** indirect effect . nlcom _b[rsoshs:i1.gender#c.griphs]
#
#        _nl_1:  _b[rsoshs:i1.gender#c.griphs]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |    .465944   .0994652     4.68   0.000     .2709957    .6608922
# ------------------------------------------------------------------------------
# . nlcom _b[griphs:i1.gender#c.matus]
#
#        _nl_1:  _b[griphs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .4899863   .0479046    10.23   0.000      .396095    .5838777
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
#        _nl_1:  _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .2283062   .0534051     4.27   0.000     .1236341    .3329782
# ------------------------------------------------------------------------------
# . ** total effect      . nlcom _b[rsoshs:i1.gender#c.matus]
#
#        _nl_1:  _b[rsoshs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .4544253   .0789447     5.76   0.000     .2996966     .609154
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .2283062   .0534051     4.27   0.000     .1236341    .3329782
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[rsoshs:i1.gender#c.matus] + _b[rsoshs:i1.gender#c.griphs]*_b[griphs:i1.gender#c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .6827315   .0633261    10.78   0.000     .5586146    .8068484
# ------------------------------------------------------------------------------
# . ************************************************************************************. ************************************************************************************. *estout t3a t3b , cells("b( fmt(2)) ci(par fmt(2))") interaction(:) label

# %% [markdown]
# # Table 3a. Male-specific results.

# %%
# %%stata --data dm
# set processors 20
#
# constraint 1 _b[rsoshs:griphs] = _b[tsoshs:torqhs]
# constraint 2 _b[rsoshs:matus]  = _b[tsoshs:matus]
# constraint 3 _b[rsoshs:ntxhs]  = _b[tsoshs:ntxhs]
# constraint 4 _b[rsoshs:paqps]  = _b[tsoshs:mvhhs]
#
# constraint 5 _b[griphs:godhs]  = _b[torqhs:godhs]
# constraint 6 _b[griphs:cinths] = _b[torqhs:cinths]
# constraint 7 _b[griphs:matus]  = _b[torqhs:matus]
#
#
# constraint 10 _b[griphs:_cons] = 0
# constraint 11 _b[torqhs:_cons] = 0
# constraint 12 _b[rsoshs:_cons] = 0
# constraint 13 _b[tsoshs:_cons] = 0
#
# constraint 14 [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
# constraint 15 [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (godhs cinths matus    -> griphs,)  ///
#     (godhs cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
# matrix b = e(b)
#
# gsem ///
#     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     ( godhs cinths matus    -> griphs,)  ///
#     ( godhs cinths matus    -> torqhs,)  ///
#      if gender==0, covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
#       from(b, skip)
# Out:
#     The maximum number of processors or cores being used is changed from 32 to>     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (godhs cinths matus    -> griphs,)  ///
# >     (godhs cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2050.3787  (not concave)
# Iteration 1:   log likelihood =  -1986.265
# Iteration 2:   log likelihood = -1982.0747
# Iteration 3:   log likelihood = -1971.8136
# Iteration 4:   log likelihood = -1970.9114
# Iteration 5:   log likelihood =  -1970.826
# Iteration 6:   log likelihood = -1970.8253
# Iteration 7:   log likelihood = -1970.8253
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1947.9747
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1947.9747  (not concave)
# Iteration 1:   log likelihood = -1912.1681  (not concave)
# Iteration 2:   log likelihood = -1896.1383  (not concave)
# Iteration 3:   log likelihood =  -1876.418
# Iteration 4:   log likelihood =  -1858.983
# Iteration 5:   log likelihood = -1855.2422
# Iteration 6:   log likelihood = -1854.5785
# Iteration 7:   log likelihood = -1854.5476
# Iteration 8:   log likelihood = -1854.5474
# Iteration 9:   log likelihood = -1854.5474
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1854.5474
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2419942   .1104781     2.19   0.028      .025461    .4585274
#                 matus |   .3084402   .0810276     3.81   0.000     .1496291    .4672514
#                 ntxhs |  -.1796183   .0377279    -4.76   0.000    -.2535637   -.1056729
#                 paqps |   .0545991   .0319829     1.71   0.088    -.0080863    .1172846
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183515   .0556389    -0.33   0.742    -.1274017    .0906988
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .4000205   .1233158     3.24   0.001      .158326    .6417149
#                 matus |   .3204972   .0922616     3.47   0.001     .1396678    .5013266
#                 ntxhs |  -.1429093   .0348126    -4.11   0.000    -.2111407   -.0746778
#                 mvhhs |   .0820493   .0386155     2.12   0.034     .0063644    .1577343
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264677   .0581858    -0.45   0.649    -.1405099    .0875744
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1658118   .0392836     4.22   0.000     .0888173    .2428062
#                cinths |   .1374999   .0390604     3.52   0.000     .0609429    .2140569
#                 matus |   .5999135   .0389674    15.40   0.000     .5235389    .6762882
#                 _cons |  -9.43e-08   .0376653    -0.00   1.000    -.0738228    .0738226
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .0847608   .0372795     2.27   0.023     .0116943    .1578274
#                cinths |   .1560526     .03819     4.09   0.000     .0812016    .2309036
#                 matus |   .5947456   .0389262    15.28   0.000     .5184515    .6710396
#                 _cons |   8.02e-08   .0377528     0.00   1.000    -.0739941    .0739943
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4020271   .0614952                      .2978881    .5425721
#            var(M2[id])|    .457207   .0620565                      .3504125     .596549
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2221857   .0478268     4.65   0.000      .128447    .3159244
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3112376   .0291402                      .2590578    .3739275
#          var(e.tsoshs)|   .3064253   .0494011                      .2234066     .420294
#          var(e.griphs)|   .6029383   .0413636                      .5270813    .6897125
#          var(e.torqhs)|   .6057426    .041483                      .5296578    .6927569
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0833008   .0195874     4.25   0.000     .0449102    .1216915
# cov(e.griphs,e.rsoshs)|    .028564   .0563978     0.51   0.613    -.0819736    .1391015
# cov(e.torqhs,e.tsoshs)|  -.1741782   .0658605    -2.64   0.008    -.3032625   -.0450939
# cov(e.torqhs,e.griphs)|   .2282826   .0305861     7.46   0.000     .1683349    .2882304
# ---------------------------------------------------------------------------------------
# >     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     ( godhs cinths matus    -> griphs,)  ///
# >     ( godhs cinths matus    -> torqhs,)  ///
# >      if gender==0, covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
# >       from(b, skip)
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1097.1228
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1107.3718
# Iteration 1:   log likelihood = -1067.8586
# Iteration 2:   log likelihood = -1048.1544
# Iteration 3:   log likelihood =  -1047.456
# Iteration 4:   log likelihood = -1047.4491
# Iteration 5:   log likelihood = -1047.4491
#
# Generalized structural equation model           Number of obs     =        226
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1047.4491
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#  ( 2)  [rsoshs]matus - [tsoshs]matus = 0
#  ( 3)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#  ( 4)  [rsoshs]paqps - [tsoshs]mvhhs = 0
#  ( 5)  [griphs]godhs - [torqhs]godhs = 0
#  ( 6)  [griphs]cinths - [torqhs]cinths = 0
#  ( 7)  [griphs]matus - [torqhs]matus = 0
#  ( 8)  [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
#  ( 9)  [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#  (10)  [rsoshs]_cons = 0
#  (11)  [rsoshs]M1[id] = 1
#  (12)  [tsoshs]_cons = 0
#  (13)  [tsoshs]M1[id] = 1
#  (14)  [griphs]_cons = 0
#  (15)  [torqhs]_cons = 0
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .3761096   .1083507     3.47   0.001     .1637461    .5884731
#                 matus |    .120765   .0876767     1.38   0.168    -.0510782    .2926082
#                 ntxhs |  -.1282277     .04183    -3.07   0.002    -.2102131   -.0462423
#                 paqps |   .0799087   .0323909     2.47   0.014     .0164237    .1433937
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3761096   .1083507     3.47   0.001     .1637461    .5884731
#                 matus |    .120765   .0876767     1.38   0.168    -.0510782    .2926082
#                 ntxhs |  -.1282277     .04183    -3.07   0.002    -.2102131   -.0462423
#                 mvhhs |   .0799087   .0323909     2.47   0.014     .0164237    .1433937
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1517593   .0447192     3.39   0.001     .0641114    .2394072
#                cinths |   .1070915   .0479106     2.24   0.025     .0131886    .2009945
#                 matus |   .7018917   .0492742    14.24   0.000     .6053161    .7984674
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .1517593   .0447192     3.39   0.001     .0641114    .2394072
#                cinths |   .1070915   .0479106     2.24   0.025     .0131886    .2009945
#                 matus |   .7018917   .0492742    14.24   0.000     .6053161    .7984674
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .3120949   .0560542                      .2194853    .4437802
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .4081015   .0412557                      .3347486    .4975281
#          var(e.tsoshs)|   .4081015   .0412557                      .3347486    .4975281
#          var(e.griphs)|   .7574656   .0546276                      .6576203    .8724703
#          var(e.torqhs)|   .7574656   .0546276                      .6576203    .8724703
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   -.062827   .0288021    -2.18   0.029     -.119278    -.006376
# cov(e.griphs,e.rsoshs)|  -.0416767   .0693461    -0.60   0.548    -.1775925    .0942391
# cov(e.torqhs,e.tsoshs)|  -.2403749     .06956    -3.46   0.001    -.3767099   -.1040398
# cov(e.torqhs,e.griphs)|    .307532   .0521697     5.89   0.000     .2052813    .4097827
# ---------------------------------------------------------------------------------------
# . **direct effect
#        _nl_1:  _b[rsoshs:griphs]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .3761096   .1083507     3.47   0.001     .1637461    .5884731
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:griphs]
#
#        _nl_1:  _b[rsoshs:griphs]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .3761096   .1083507     3.47   0.001     .1637461    .5884731
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[griphs:matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .7018917   .0492742    14.24   0.000     .6053161    .7984674
# ------------------------------------------------------------------------------
#
#        _nl_1:  _b[rsoshs:griphs]* _b[griphs:matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .2639882   .0788486     3.35   0.001     .1094478    .4185287
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:griphs] + _b[rsoshs:griphs]*_b[griphs:matus]
#
#        _nl_1:  _b[rsoshs:griphs] + _b[rsoshs:griphs]*_b[griphs:matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .6400978   .1859178     3.44   0.001     .2757057     1.00449
# ------------------------------------------------------------------------------

# %% [markdown]
# # Table 3b. Girl-specific results.

# %%
# %%stata --data dm
# set processors 20
#
# constraint 1 _b[rsoshs:griphs] = _b[tsoshs:torqhs]
# constraint 2 _b[rsoshs:matus]  = _b[tsoshs:matus]
# constraint 3 _b[rsoshs:ntxhs]  = _b[tsoshs:ntxhs]
# constraint 4 _b[rsoshs:paqps]  = _b[tsoshs:mvhhs]
#
# constraint 5 _b[griphs:godhs]  = _b[torqhs:godhs]
# constraint 6 _b[griphs:cinths] = _b[torqhs:cinths]
# constraint 7 _b[griphs:matus]  = _b[torqhs:matus]
#
# constraint 10 _b[griphs:_cons] = 0
# constraint 11 _b[torqhs:_cons] = 0
# constraint 12 _b[rsoshs:_cons] = 0
# constraint 13 _b[tsoshs:_cons] = 0
#
# constraint 14 [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
# constraint 15 [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#
# gsem ///
#     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     (godhs cinths matus    -> griphs,)  ///
#     (godhs cinths matus    -> torqhs,)  ///
#      , covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       cov(M1[id]*M2[id])
# matrix b = e(b)
#
# gsem ///
#     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
#     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
#     ( godhs cinths matus    -> griphs,)  ///
#     ( godhs cinths matus    -> torqhs,)  ///
#      if gender==1, covstruct(_lexogenous, diagonal) nocapslatent ///
#       latent(M1 M2)   ///
#       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
#       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
#       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
#       from(b, skip)
#
# ** indirect effect
# nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# ** total effect
# nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
# Out:
#     The maximum number of processors or cores being used is changed from 32 to>     (M1[id] griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M2[id] torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     (godhs cinths matus    -> griphs,)  ///
# >     (godhs cinths matus    -> torqhs,)  ///
# >      , covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       cov(M1[id]*M2[id])
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2050.3787  (not concave)
# Iteration 1:   log likelihood =  -1986.265
# Iteration 2:   log likelihood = -1982.0747
# Iteration 3:   log likelihood = -1971.8136
# Iteration 4:   log likelihood = -1970.9114
# Iteration 5:   log likelihood =  -1970.826
# Iteration 6:   log likelihood = -1970.8253
# Iteration 7:   log likelihood = -1970.8253
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -1947.9747
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -1947.9747  (not concave)
# Iteration 1:   log likelihood = -1912.1681  (not concave)
# Iteration 2:   log likelihood = -1896.1383  (not concave)
# Iteration 3:   log likelihood =  -1876.418
# Iteration 4:   log likelihood =  -1858.983
# Iteration 5:   log likelihood = -1855.2422
# Iteration 6:   log likelihood = -1854.5785
# Iteration 7:   log likelihood = -1854.5476
# Iteration 8:   log likelihood = -1854.5474
# Iteration 9:   log likelihood = -1854.5474
#
# Generalized structural equation model           Number of obs     =        425
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -1854.5474
#
#  ( 1)  [rsoshs]M1[id] = 1
#  ( 2)  [tsoshs]M2[id] = 1
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .2419942   .1104781     2.19   0.028      .025461    .4585274
#                 matus |   .3084402   .0810276     3.81   0.000     .1496291    .4672514
#                 ntxhs |  -.1796183   .0377279    -4.76   0.000    -.2535637   -.1056729
#                 paqps |   .0545991   .0319829     1.71   0.088    -.0080863    .1172846
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |  -.0183515   .0556389    -0.33   0.742    -.1274017    .0906988
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .4000205   .1233158     3.24   0.001      .158326    .6417149
#                 matus |   .3204972   .0922616     3.47   0.001     .1396678    .5013266
#                 ntxhs |  -.1429093   .0348126    -4.11   0.000    -.2111407   -.0746778
#                 mvhhs |   .0820493   .0386155     2.12   0.034     .0063644    .1577343
#                       |
#                M2[id] |          1  (constrained)
#                       |
#                 _cons |  -.0264677   .0581858    -0.45   0.649    -.1405099    .0875744
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .1658118   .0392836     4.22   0.000     .0888173    .2428062
#                cinths |   .1374999   .0390604     3.52   0.000     .0609429    .2140569
#                 matus |   .5999135   .0389674    15.40   0.000     .5235389    .6762882
#                 _cons |  -9.43e-08   .0376653    -0.00   1.000    -.0738228    .0738226
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .0847608   .0372795     2.27   0.023     .0116943    .1578274
#                cinths |   .1560526     .03819     4.09   0.000     .0812016    .2309036
#                 matus |   .5947456   .0389262    15.28   0.000     .5184515    .6710396
#                 _cons |   8.02e-08   .0377528     0.00   1.000    -.0739941    .0739943
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|   .4020271   .0614952                      .2978881    .5425721
#            var(M2[id])|    .457207   .0620565                      .3504125     .596549
# ----------------------+----------------------------------------------------------------
#     cov(M2[id],M1[id])|   .2221857   .0478268     4.65   0.000      .128447    .3159244
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3112376   .0291402                      .2590578    .3739275
#          var(e.tsoshs)|   .3064253   .0494011                      .2234066     .420294
#          var(e.griphs)|   .6029383   .0413636                      .5270813    .6897125
#          var(e.torqhs)|   .6057426    .041483                      .5296578    .6927569
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|   .0833008   .0195874     4.25   0.000     .0449102    .1216915
# cov(e.griphs,e.rsoshs)|    .028564   .0563978     0.51   0.613    -.0819736    .1391015
# cov(e.torqhs,e.tsoshs)|  -.1741782   .0658605    -2.64   0.008    -.3032625   -.0450939
# cov(e.torqhs,e.griphs)|   .2282826   .0305861     7.46   0.000     .1683349    .2882304
# ---------------------------------------------------------------------------------------
# >     (M1[id]@1 griphs matus ntxhs paqps  -> rsoshs, ) ///
# >     (M1[id]@1 torqhs matus ntxhs mvhhs  -> tsoshs, ) ///
# >     ( godhs cinths matus    -> griphs,)  ///
# >     ( godhs cinths matus    -> torqhs,)  ///
# >      if gender==1, covstruct(_lexogenous, diagonal) nocapslatent ///
# >       latent(M1 M2)   ///
# >       cov(e.rsoshs*e.tsoshs)  cov(e.torqhs*e.griphs)  ///
# >       cov(e.rsoshs*e.griphs)  cov(e.tsoshs*e.torqhs) ///
# >       constraints(1 2 3 4 5 6 7  10 11 12 13 14 15) ///
# >       from(b, skip)
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -864.01932
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -873.69941
# Iteration 1:   log likelihood = -838.75352
# Iteration 2:   log likelihood = -815.82839
# Iteration 3:   log likelihood = -813.93004
# Iteration 4:   log likelihood = -813.84478
# Iteration 5:   log likelihood = -813.84378
# Iteration 6:   log likelihood = -813.84378
#
# Generalized structural equation model           Number of obs     =        199
#
# Response       : rsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : tsoshs
# Family         : Gaussian
# Link           : identity
#
# Response       : griphs
# Family         : Gaussian
# Link           : identity
#
# Response       : torqhs
# Family         : Gaussian
# Link           : identity
#
# Log likelihood = -813.84378
#
#  ( 1)  [rsoshs]griphs - [tsoshs]torqhs = 0
#  ( 2)  [rsoshs]matus - [tsoshs]matus = 0
#  ( 3)  [rsoshs]ntxhs - [tsoshs]ntxhs = 0
#  ( 4)  [rsoshs]paqps - [tsoshs]mvhhs = 0
#  ( 5)  [griphs]godhs - [torqhs]godhs = 0
#  ( 6)  [griphs]cinths - [torqhs]cinths = 0
#  ( 7)  [griphs]matus - [torqhs]matus = 0
#  ( 8)  [var(e.rsoshs)]_cons - [var(e.tsoshs)]_cons = 0
#  ( 9)  [var(e.griphs)]_cons - [var(e.torqhs)]_cons = 0
#  (10)  [rsoshs]_cons = 0
#  (11)  [rsoshs]M1[id] = 1
#  (12)  [tsoshs]_cons = 0
#  (13)  [tsoshs]M1[id] = 1
#  (14)  [griphs]_cons = 0
#  (15)  [torqhs]_cons = 0
# ---------------------------------------------------------------------------------------
#                       |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# ----------------------+----------------------------------------------------------------
# rsoshs <-             |
#                griphs |   .3739254   .1529955     2.44   0.015     .0740597    .6737911
#                 matus |   .4990602   .1008376     4.95   0.000     .3014222    .6966982
#                 ntxhs |  -.1226262   .0392194    -3.13   0.002    -.1994947   -.0457577
#                 paqps |  -.0058191   .0348583    -0.17   0.867    -.0741401    .0625019
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# tsoshs <-             |
#                torqhs |   .3739254   .1529955     2.44   0.015     .0740597    .6737911
#                 matus |   .4990602   .1008376     4.95   0.000     .3014222    .6966982
#                 ntxhs |  -.1226262   .0392194    -3.13   0.002    -.1994947   -.0457577
#                 mvhhs |  -.0058191   .0348583    -0.17   0.867    -.0741401    .0625019
#                       |
#                M1[id] |          1  (constrained)
#                       |
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# griphs <-             |
#                 godhs |   .0931388   .0459522     2.03   0.043     .0030742    .1832034
#                cinths |   .1743865   .0419483     4.16   0.000     .0921695    .2566036
#                 matus |   .4914031   .0398279    12.34   0.000     .4133419    .5694643
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
# torqhs <-             |
#                 godhs |   .0931388   .0459522     2.03   0.043     .0030742    .1832034
#                cinths |   .1743865   .0419483     4.16   0.000     .0921695    .2566036
#                 matus |   .4914031   .0398279    12.34   0.000     .4133419    .5694643
#                 _cons |          0  (omitted)
# ----------------------+----------------------------------------------------------------
#            var(M1[id])|    .364409   .0748122                      .2436912    .5449271
# ----------------------+----------------------------------------------------------------
#          var(e.rsoshs)|   .3533271   .0297859                      .2995157    .4168062
#          var(e.tsoshs)|   .3533271   .0297859                      .2995157    .4168062
#          var(e.griphs)|   .4277594   .0319909                      .3694373    .4952887
#          var(e.torqhs)|   .4277594   .0319909                      .3694373    .4952887
# ----------------------+----------------------------------------------------------------
# cov(e.tsoshs,e.rsoshs)|  -.0228152   .0294423    -0.77   0.438     -.080521    .0348906
# cov(e.griphs,e.rsoshs)|  -.0043186   .0599856    -0.07   0.943    -.1218883     .113251
# cov(e.torqhs,e.tsoshs)|  -.0404097   .0594095    -0.68   0.496    -.1568503    .0760308
# cov(e.torqhs,e.griphs)|   .1401544   .0320436     4.37   0.000     .0773501    .2029587
# ---------------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .1837481   .0764357     2.40   0.016     .0339369    .3335593
# ------------------------------------------------------------------------------
# . nlcom _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
#        _nl_1:  _b[rsoshs:c.griphs] + _b[rsoshs:c.griphs]*_b[griphs:c.matus]
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _nl_1 |   .5576735   .2284524     2.44   0.015     .1099149    1.005432
# ------------------------------------------------------------------------------
