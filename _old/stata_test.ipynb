# %%
import ipystata
# Out:
# IPyStata is loaded in batch mode.

# %%
# %%stata
#
# display "Hello"
# clear all
# cd "~/Documents/bone"
#
# import delimited ./data/IzzyLongitudinalWorkingMarch2015.csv,  case(lower) clear
# order id session sequence
# sort id sequence
# save ./out/di, replace
#
# import delimited ./data/torque.csv, case(lower) clear
# drop if session==0
# drop sequence
# rename new_sequence sequence
# order id session sequence
# sort id  sequence
# foreach var in ptiso pt60 pt240 {
# replace `var' = . if `var'==-9999
# }
# save ./out/dt, replace
#
# ** Identify potentially data with errors
# * Nota: July  2016
# import delimited ./data/NegativeIDs.csv, case(lower) clear
# keep nota id sequence
# keep if nota==1
# save ./out/db1, replace
#
# * Baraket: Nov 2016
# import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# keep falk id sequence
# keep if falk==1
# save ./out/db2, replace
#
# * merge
# use ./out/di, clear
# sort id sequence
# merge 1:1 id sequence using ./out/dt,  nogen
# merge 1:1 id sequence using ./out/db1, nogen
# merge 1:1 id sequence using ./out/db2, nogen
#
# rename radius_sos rsos
# rename tibial_sos tsos
#
# rename grip_strength_best grip
# rename mat_offset_new matu
#
# rename godin_pa godin
# rename ntxcreat ntxc
# rename caloricintake cint
# renam calcium calc
# rename vitd vitd
# rename v48 vitd2
# rename paq_total_score paq
# rename totmvh mvh
#
# global U id session sequence
# global Y rsos tsos
# global X grip ptiso pt60 godin paq ntxc cint calc vitd vitd2 mvh
# global Z matu age gender
# global D nota falk
#
# keep $U $Y $X $Z $D
#
#
# ***grip only
#
# drop if missing(rsos)
# *drop if missing(tsos)
# drop if missing(grip)
# *drop if missing(ptiso)
# drop if matu>5
# drop if id==517 & sequence==7
#
# sort id sequence
# by id: egen seq = seq()
# global U id session sequence seq
#
# order $U $D $Y $X $Z
#
# xtset id seq
# foreach var in rsos grip matu godin {
# gen d`var' = `var' - l.`var', after(falk)
# }
#
#
# gsem (rsos <- grip matu  M1[id] )
# sum drsos dgrip dmatu
# gen prsos = drsos / rsos
# gen pgrip = dgrip / grip
#
# reg rsos id
# sum  rsos grip matu drsos dgrip prsos pgrip
# corr rsos grip matu
# corr tsos ptiso matu
#
# xtsum rsos grip matu
# xtdescribe
#
# xtmixed rsos id || id:
# gsem (rsos <- M[id])
# gsem (rsos <- )
# xtreg rsos  , re
# Out:
# Hello
# /home/vmuser/Documents/bone
# (70 vars, 427 obs)
# file ./out/di.dta saved
# (14 vars, 421 obs)
# (40 observations deleted)(65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# (65 real changes made, 65 to missing)
# file ./out/dt.dta saved
# . * Nota: July  2016(32 vars, 109 obs)
# (59 observations deleted)
# file ./out/db1.dta saved
# . import delimited ./data/data_examine_falk_nov2016.csv, case(lower) clear
# (34 vars, 473 obs)
# (460 observations deleted)
# file ./out/db2.dta saved
# . use ./out/di, clear
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                            58
#         from master                        52
#         from using                          6
#
#     matched                               375
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           383
#         from master                       383
#         from using                          0
#
#     matched                                50
#     -----------------------------------------
#
#     Result                           # of obs.
#     -----------------------------------------
#     not matched                           420
#         from master                       420
#         from using                          0
#
#     matched                                13
#     -----------------------------------------
#   (all newnames==oldnames)
# . drop if missing(rsos)
# (16 observations deleted)
# . drop if missing(grip)
# (46 observations deleted)
# . drop if matu>5
# (1 observation deleted)
# (1 observation deleted)
#        panel variable:  id (unbalanced)
#         time variable:  seq, 1 to 3
#                 delta:  1 unit(171 missing values generated)
# (171 missing values generated)
# (171 missing values generated)
# (171 missing values generated)
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2191.6152
# Iteration 1:   log likelihood = -2191.6152
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -2179.5467
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -2179.5467  (not concave)
# Iteration 1:   log likelihood = -2137.6256
# Iteration 2:   log likelihood = -2132.9378
# Iteration 3:   log likelihood = -2132.7139
# Iteration 4:   log likelihood = -2132.7131
# Iteration 5:   log likelihood = -2132.7131
#
# Generalized structural equation model           Number of obs     =        369
# Response       : rsos
# Family         : Gaussian
# Link           : identity
# Log likelihood = -2132.7131
#
#  ( 1)  [rsos]M1[id] = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsos <-      |
#         grip |   3.137218   .9468991     3.31   0.001      1.28133    4.993106
#         matu |   14.96871   3.836785     3.90   0.000     7.448751    22.48867
#              |
#       M1[id] |          1  (constrained)
#              |
#        _cons |   3755.332   25.37704   147.98   0.000     3705.594     3805.07
# -------------+----------------------------------------------------------------
#   var(M1[id])|    5409.75   768.1026                      4095.618    7145.537
# -------------+----------------------------------------------------------------
#   var(e.rsos)|   3003.432   300.9282                      2467.925    3655.138
# ------------------------------------------------------------------------------
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#        drsos |        198    35.19192    70.43133       -136        444
#        dgrip |        198    4.089798    3.079337         -2       17.5
#        dmatu |        198    .9961616    .2585265        .11        2.2
# (171 missing values generated)
# (171 missing values generated)
#
#       Source |       SS           df       MS      Number of obs   =       369
# -------------+----------------------------------   F(1, 367)       =      6.97
#        Model |  71037.3394         1  71037.3394   Prob > F        =    0.0086
#     Residual |  3738311.22       367  10186.1341   R-squared       =    0.0186
# -------------+----------------------------------   Adj R-squared   =    0.0160
#        Total |  3809348.56       368  10351.4906   Root MSE        =    100.93
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#           id |   .0705288   .0267072     2.64   0.009     .0180105    .1230471
#        _cons |   3793.242   10.35383   366.36   0.000     3772.881    3813.602
# ------------------------------------------------------------------------------
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#         rsos |        369    3816.802    101.7423       3542       4140
#         grip |        369    23.48653     7.40112          9         53
#         matu |        369   -.7829268    1.983785       -5.3       4.95
#        drsos |        198    35.19192    70.43133       -136        444
#        dgrip |        198    4.089798    3.079337         -2       17.5
# -------------+---------------------------------------------------------
#        prsos |        198    .0089755     .018219  -.0361606   .1109445
#        pgrip |        198    .1537801    .0915172       -.08   .4929577
# (obs=369)
#
#              |     rsos     grip     matu
# -------------+---------------------------
#         rsos |   1.0000
#         grip |   0.3489   1.0000
#         matu |   0.4134   0.6458   1.0000
#
# (obs=260)
#
#              |     tsos    ptiso     matu
# -------------+---------------------------
#         tsos |   1.0000
#        ptiso |   0.3094   1.0000
#         matu |   0.4899   0.6522   1.0000
#
#
# Variable         |      Mean   Std. Dev.       Min        Max |    Observations
# -----------------+--------------------------------------------+----------------
# rsos     overall |  3816.802   101.7423       3542       4140 |     N =     369
#          between |             89.47651       3588       4119 |     n =     171
#          within  |             46.96615   3496.802   4012.802 | T-bar = 2.15789
#                  |                                            |
# grip     overall |  23.48653    7.40112          9         53 |     N =     369
#          between |             6.962083   10.83333      47.25 |     n =     171
#          within  |             3.262583   9.486531   36.98653 | T-bar = 2.15789
#                  |                                            |
# matu     overall | -.7829268   1.983785       -5.3       4.95 |     N =     369
#          between |             1.935747      -4.77        4.5 |     n =     171
#          within  |             .6738738   -1.98626   .5537398 | T-bar = 2.15789
#
#       id:  100, 102, ..., 583                                n =        171
#      seq:  1, 2, ..., 3                                      T =          3
#            Delta(seq) = 1 unit
#            Span(seq)  = 3 periods
#            (id*seq uniquely identifies each observation)
#
# Distribution of T_i:   min      5%     25%       50%       75%     95%     max
#                          1       1       2         2         3       3       3
#
#      Freq.  Percent    Cum. |  Pattern
#  ---------------------------+---------
#        66     38.60   38.60 |       39     22.81  100.00 |  1..
#  ---------------------------+---------
#       171    100.00         |  XXX
#
# Performing EM optimization:
#
# Performing gradient-based optimization:
#
# Iteration 0:   log likelihood = -2173.2829
# Iteration 1:   log likelihood = -2173.2829
#
# Computing standard errors:
#
# Mixed-effects ML regression                     Number of obs     =        369
# Group variable: id                              Number of groups  =        171
#
#                                                 Obs per group:
#                                                               min =          1
#                                                               avg =        2.2
#                                                               max =          3
#
#                                                 Wald chi2(1)      =       4.55
# Log likelihood = -2173.2829                     Prob > chi2       =     0.0328
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#           id |   .0742193   .0347801     2.13   0.033     .0060515    .1423871
#        _cons |   3792.297   13.51132   280.68   0.000     3765.815    3818.779
# ------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------
#   Random-effects Parameters  |   Estimate   Std. Err.     [95% Conf. Interval]
# -----------------------------+------------------------------------------------
# id: Identity                 |
#                    sd(_cons) |   76.65943   5.605614      66.42364    88.47255
# -----------------------------+------------------------------------------------
#                 sd(Residual) |   63.47637    3.12814      57.63211    69.91327
# ------------------------------------------------------------------------------
# LR test vs. linear model: chibar2(01) = 104.03        Prob >= chibar2 = 0.0000
#
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood = -2228.7691
# Iteration 1:   log likelihood = -2228.7691
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -2217.3084
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -2217.3084  (not concave)
# Iteration 1:   log likelihood = -2179.0985
# Iteration 2:   log likelihood = -2175.5793
# Iteration 3:   log likelihood =  -2175.532
# Iteration 4:   log likelihood = -2175.5319
#
# Generalized structural equation model           Number of obs     =        369
# Response       : rsos
# Family         : Gaussian
# Link           : identity
# Log likelihood = -2175.5319
#
#  ( 1)  [rsos]M[id] = 1
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsos <-      |
#        M[id] |          1  (constrained)
#              |
#        _cons |   3817.173   6.915636   551.96   0.000     3803.619    3830.727
# -------------+----------------------------------------------------------------
#    var(M[id])|   6074.978   882.2604                      4570.102     8075.39
# -------------+----------------------------------------------------------------
#   var(e.rsos)|   4034.208   398.1084                       3324.75    4895.055
# ------------------------------------------------------------------------------
#
# Iteration 0:   log likelihood = -2228.7691
# Iteration 1:   log likelihood = -2228.7691
#
# Generalized structural equation model           Number of obs     =        369
# Response       : rsos
# Family         : Gaussian
# Link           : identity
# Log likelihood = -2228.7691
#
# ------------------------------------------------------------------------------
#              |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
# rsos <-      |
#        _cons |   3816.802    5.28931   721.61   0.000     3806.435    3827.169
# -------------+----------------------------------------------------------------
#   var(e.rsos)|   10323.44    760.022                      8936.306    11925.89
# ------------------------------------------------------------------------------
#
# Random-effects GLS regression                   Number of obs     =        369
# Group variable: id                              Number of groups  =        171
#
# R-sq:                                           Obs per group:
#      within  = 0.0000                                         min =          1
#      between = 0.0000                                         avg =        2.2
#      overall = 0.0000                                         max =          3
#
#                                                 Wald chi2(0)      =          .
# corr(u_i, X)   = 0 (assumed)                    Prob > chi2       =          .
#
# ------------------------------------------------------------------------------
#         rsos |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#        _cons |   3817.179   6.827969   559.05   0.000     3803.796    3830.561
# -------------+----------------------------------------------------------------
#      sigma_u |  75.844621
#      sigma_e |  64.028935
#          rho |  .58387552   (fraction of variance due to u_i)
# ------------------------------------------------------------------------------
